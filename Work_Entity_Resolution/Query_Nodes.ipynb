# %%
from neo4j import GraphDatabase
import json
import networkx as nx

# Neo4j connection details
uri = "bolt://localhost:7687"  
user = "neo4j"                 
password = "123456789"          

# Initialize the Neo4j driver
driver = GraphDatabase.driver(uri, auth=(user, password))

# Function to run a query and return the results
def run_query(query):
    with driver.session() as session:
        result = session.run(query)
        return [record.data() for record in result]


# Function to extract nodes and relationships with labels and properties
def extract_graph_data():
    nodes_query = """
    MATCH (n) 
    RETURN id(n) as id, labels(n) as labels, properties(n) as properties
    """
    relationships_query = """
    MATCH ()-[r]->() 
    RETURN id(r) as id, type(r) as type, properties(r) as properties, 
           id(startNode(r)) as start_id, id(endNode(r)) as end_id
    """

    nodes = run_query(nodes_query)
    relationships = run_query(relationships_query)
    
    return nodes, relationships

# Function to save data to JSON file
def save_to_json(data, file_path):
    with open(file_path, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=4)

# Main function to extract data and save it as JSON
def main():
    nodes, relationships = extract_graph_data()
    graph_data = {
        "nodes": nodes,
        "relationships": relationships
    }
    #save_to_json(graph_data, 'graph_data_1.json')
    print("Data extraction complete. JSON file saved as graph_data.json")

# %%
nodes, relationships = extract_graph_data()
graph_data = {
    "nodes": nodes,
    "relationships": relationships
}

# %%
for item in graph_data["relationships"]: 
    print(item)
# Out:
# {'id': 3339, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 211}
# {'id': 3761, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 633}
# {'id': 3828, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 700}
# {'id': 3961, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 833}
# {'id': 3842, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 714}
# {'id': 3785, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 657}
# {'id': 3750, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 622}
# {'id': 3882, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 754}
# {'id': 3754, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 626}
# {'id': 3927, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 799}
# {'id': 3942, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 814}
# {'id': 3966, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 838}
# {'id': 3876, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 748}
# {'id': 3989, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 861}
# {'id': 3949, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 821}
# {'id': 3753, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 625}
# {'id': 3884, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 756}
# {'id': 3851, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 723}
# {'id': 3766, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 638}
# {'id': 3886, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 758}
# {'id': 3950, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 822}
# {'id': 3803, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 675}
# {'id': 3925, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 797}
# {'id': 3821, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 693}
# {'id': 3959, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 831}
# {'id': 3878, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 750}
# {'id': 3795, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 667}
# {'id': 3853, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 725}
# {'id': 3914, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 786}
# {'id': 3896, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 768}
# {'id': 3962, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 834}
# {'id': 3865, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 737}
# {'id': 3760, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 632}
# {'id': 3758, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 630}
# {'id': 3775, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 647}
# {'id': 4008, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 880}
# {'id': 3902, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 774}
# {'id': 3898, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 770}
# {'id': 3916, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 788}
# {'id': 4022, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 894}
# {'id': 3855, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 727}
# {'id': 3800, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 672}
# {'id': 3975, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 847}
# {'id': 3813, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 685}
# {'id': 3906, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 778}
# {'id': 3763, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 635}
# {'id': 3747, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 619}
# {'id': 3939, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 811}
# {'id': 3814, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 686}
# {'id': 3784, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 656}
# {'id': 4018, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 890}
# {'id': 3972, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 844}
# {'id': 3953, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 825}
# {'id': 4006, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 878}
# {'id': 3789, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 661}
# {'id': 3796, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 668}
# {'id': 4031, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 903}
# {'id': 4002, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 874}
# {'id': 3979, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 851}
# {'id': 3852, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 724}
# {'id': 3999, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 871}
# {'id': 3847, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 719}
# {'id': 3957, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 829}
# {'id': 3818, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 690}
# {'id': 3743, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 615}
# {'id': 3905, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 777}
# {'id': 3830, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 702}
# {'id': 4004, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 876}
# {'id': 3985, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 857}
# {'id': 3946, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 818}
# {'id': 3811, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 683}
# {'id': 3903, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 775}
# {'id': 3820, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 692}
# {'id': 3970, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 842}
# {'id': 3751, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 623}
# {'id': 3909, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 781}
# {'id': 4034, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 906}
# {'id': 4024, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 896}
# {'id': 3964, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 836}
# {'id': 3816, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 688}
# {'id': 3837, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 709}
# {'id': 4011, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 883}
# {'id': 4038, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 910}
# {'id': 4015, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 887}
# {'id': 3887, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 759}
# {'id': 3874, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 746}
# {'id': 3951, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 823}
# {'id': 3831, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 703}
# {'id': 3812, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 684}
# {'id': 3756, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 628}
# {'id': 3825, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 697}
# {'id': 3807, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 679}
# {'id': 4005, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 877}
# {'id': 4016, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 888}
# {'id': 3987, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 859}
# {'id': 3817, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 689}
# {'id': 3779, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 651}
# {'id': 3872, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 744}
# {'id': 3922, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 794}
# {'id': 3793, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 665}
# {'id': 3929, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 801}
# {'id': 3765, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 637}
# {'id': 4019, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 891}
# {'id': 4010, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 882}
# {'id': 3815, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 687}
# {'id': 3861, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 733}
# {'id': 3994, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 866}
# {'id': 3854, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 726}
# {'id': 3797, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 669}
# {'id': 4000, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 872}
# {'id': 3879, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 751}
# {'id': 3757, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 629}
# {'id': 4037, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 909}
# {'id': 3982, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 854}
# {'id': 4014, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 886}
# {'id': 3762, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 634}
# {'id': 3889, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 761}
# {'id': 3808, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 680}
# {'id': 3859, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 731}
# {'id': 3983, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 855}
# {'id': 4001, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 873}
# {'id': 3798, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 670}
# {'id': 3787, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 659}
# {'id': 3920, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 792}
# {'id': 3938, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 810}
# {'id': 3746, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 618}
# {'id': 4030, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 902}
# {'id': 3981, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 853}
# {'id': 3918, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 790}
# {'id': 3790, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 662}
# {'id': 3907, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 779}
# {'id': 3804, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 676}
# {'id': 3944, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 816}
# {'id': 3845, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 717}
# {'id': 4033, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 905}
# {'id': 3968, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 840}
# {'id': 3772, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 644}
# {'id': 3773, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 645}
# {'id': 4028, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 900}
# {'id': 4012, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 884}
# {'id': 3921, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 793}
# {'id': 3799, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 671}
# {'id': 3973, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 845}
# {'id': 3863, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 735}
# {'id': 3792, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 664}
# {'id': 3933, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 805}
# {'id': 3823, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 695}
# {'id': 4009, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 881}
# {'id': 3883, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 755}
# {'id': 3864, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 736}
# {'id': 3781, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 653}
# {'id': 3941, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 813}
# {'id': 3984, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 856}
# {'id': 3971, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 843}
# {'id': 3858, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 730}
# {'id': 3788, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 660}
# {'id': 3890, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 762}
# {'id': 4035, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 907}
# {'id': 3856, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 728}
# {'id': 3850, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 722}
# {'id': 3755, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 627}
# {'id': 3829, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 701}
# {'id': 3819, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 691}
# {'id': 3958, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 830}
# {'id': 4007, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 879}
# {'id': 3832, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 704}
# {'id': 3897, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 769}
# {'id': 3934, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 806}
# {'id': 3935, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 807}
# {'id': 4029, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 901}
# {'id': 4021, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 893}
# {'id': 3955, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 827}
# {'id': 3936, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 808}
# {'id': 3767, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 639}
# {'id': 3911, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 783}
# {'id': 3976, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 848}
# {'id': 3954, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 826}
# {'id': 3956, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 828}
# {'id': 3894, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 766}
# {'id': 4036, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 908}
# {'id': 3810, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 682}
# {'id': 3786, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 658}
# {'id': 3980, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 852}
# {'id': 3881, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 753}
# {'id': 3866, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 738}
# {'id': 3974, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 846}
# {'id': 3969, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 841}
# {'id': 3888, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 760}
# {'id': 3910, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 782}
# {'id': 3857, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 729}
# {'id': 3752, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 624}
# {'id': 3978, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 850}
# {'id': 3991, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 863}
# {'id': 3917, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 789}
# {'id': 3947, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 819}
# {'id': 3998, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 870}
# {'id': 3867, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 739}
# {'id': 3862, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 734}
# {'id': 3841, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 713}
# {'id': 3748, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 620}
# {'id': 3834, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 706}
# {'id': 4020, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 892}
# {'id': 3990, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 862}
# {'id': 3870, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 742}
# {'id': 3923, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 795}
# {'id': 3840, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 712}
# {'id': 4013, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 885}
# {'id': 3759, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 631}
# {'id': 3836, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 708}
# {'id': 3826, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 698}
# {'id': 3919, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 791}
# {'id': 3977, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 849}
# {'id': 3945, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 817}
# {'id': 3849, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 721}
# {'id': 3805, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 677}
# {'id': 4040, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 912}
# {'id': 3900, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 772}
# {'id': 3749, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 621}
# {'id': 3770, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 642}
# {'id': 3742, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 614}
# {'id': 3778, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 650}
# {'id': 3794, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 666}
# {'id': 3960, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 832}
# {'id': 3776, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 648}
# {'id': 3844, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 716}
# {'id': 3904, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 776}
# {'id': 3839, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 711}
# {'id': 3833, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 705}
# {'id': 3877, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 749}
# {'id': 3782, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 654}
# {'id': 3926, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 798}
# {'id': 3880, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 752}
# {'id': 3791, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 663}
# {'id': 3771, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 643}
# {'id': 3774, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 646}
# {'id': 3901, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 773}
# {'id': 3992, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 864}
# {'id': 3893, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 765}
# {'id': 3937, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 809}
# {'id': 4023, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 895}
# {'id': 3943, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 815}
# {'id': 3892, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 764}
# {'id': 4027, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 899}
# {'id': 4025, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 897}
# {'id': 3895, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 767}
# {'id': 3967, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 839}
# {'id': 3777, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 649}
# {'id': 3924, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 796}
# {'id': 3875, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 747}
# {'id': 3744, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 616}
# {'id': 3996, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 868}
# {'id': 3848, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 720}
# {'id': 3997, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 869}
# {'id': 3930, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 802}
# {'id': 3824, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 696}
# {'id': 3868, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 740}
# {'id': 3873, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 745}
# {'id': 3780, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 652}
# {'id': 3912, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 784}
# {'id': 3846, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 718}
# {'id': 4026, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 898}
# {'id': 3993, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 865}
# {'id': 3745, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 617}
# {'id': 3995, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 867}
# {'id': 3801, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 673}
# {'id': 3806, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 678}
# {'id': 3838, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 710}
# {'id': 4003, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 875}
# {'id': 3741, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 613}
# {'id': 3932, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 804}
# {'id': 3891, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 763}
# {'id': 3869, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 741}
# {'id': 3988, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 860}
# {'id': 3871, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 743}
# {'id': 3885, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 757}
# {'id': 3769, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 641}
# {'id': 3802, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 674}
# {'id': 3915, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 787}
# {'id': 3809, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 681}
# {'id': 3908, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 780}
# {'id': 3822, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 694}
# {'id': 3827, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 699}
# {'id': 3764, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 636}
# {'id': 4039, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 911}
# {'id': 3843, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 715}
# {'id': 3768, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 640}
# {'id': 3783, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 655}
# {'id': 3931, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 803}
# {'id': 4032, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 904}
# {'id': 3928, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 800}
# {'id': 3835, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 707}
# {'id': 3952, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 824}
# {'id': 3940, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 812}
# {'id': 3986, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 858}
# {'id': 3899, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 771}
# {'id': 3948, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 820}
# {'id': 4017, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 889}
# {'id': 3913, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 785}
# {'id': 3860, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 732}
# {'id': 3965, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 837}
# {'id': 3963, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 835}
# {'id': 3559, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 432}
# {'id': 3472, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 345}
# {'id': 3683, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 556}
# {'id': 3634, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 507}
# {'id': 3528, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 401}
# {'id': 3587, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 460}
# {'id': 3484, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 357}
# {'id': 3622, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 495}
# {'id': 3659, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 532}
# {'id': 3703, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 576}
# {'id': 3721, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 594}
# {'id': 3706, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 579}
# {'id': 3672, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 545}
# {'id': 3552, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 425}
# {'id': 3474, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 347}
# {'id': 3447, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 320}
# {'id': 3627, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 500}
# {'id': 3583, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 456}
# {'id': 3688, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 561}
# {'id': 3680, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 553}
# {'id': 3593, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 466}
# {'id': 3568, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 441}
# {'id': 3711, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 584}
# {'id': 3594, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 467}
# {'id': 3664, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 537}
# {'id': 3618, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 491}
# {'id': 3521, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 394}
# {'id': 3712, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 585}
# {'id': 3533, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 406}
# {'id': 3710, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 583}
# {'id': 3724, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 597}
# {'id': 3509, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 382}
# {'id': 3603, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 476}
# {'id': 3555, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 428}
# {'id': 3462, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 335}
# {'id': 3700, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 573}
# {'id': 3665, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 538}
# {'id': 3475, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 348}
# {'id': 3609, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 482}
# {'id': 3647, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 520}
# {'id': 3546, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 419}
# {'id': 3633, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 506}
# {'id': 3547, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 420}
# {'id': 3531, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 404}
# {'id': 3492, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 365}
# {'id': 3671, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 544}
# {'id': 3648, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 521}
# {'id': 3728, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 601}
# {'id': 3653, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 526}
# {'id': 3689, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 562}
# {'id': 3481, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 354}
# {'id': 3519, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 392}
# {'id': 3557, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 430}
# {'id': 3667, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 540}
# {'id': 3597, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 470}
# {'id': 3539, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 412}
# {'id': 3485, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 358}
# {'id': 3682, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 555}
# {'id': 3503, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 376}
# {'id': 3655, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 528}
# {'id': 3477, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 350}
# {'id': 3736, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 609}
# {'id': 3699, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 572}
# {'id': 3534, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 407}
# {'id': 3678, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 551}
# {'id': 3445, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 318}
# {'id': 3660, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 533}
# {'id': 3592, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 465}
# {'id': 3452, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 325}
# {'id': 3740, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 913}
# {'id': 3581, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 454}
# {'id': 3465, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 338}
# {'id': 3638, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 511}
# {'id': 3466, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 339}
# {'id': 3502, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 375}
# {'id': 3601, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 474}
# {'id': 3535, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 408}
# {'id': 3442, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 315}
# {'id': 3615, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 488}
# {'id': 3590, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 463}
# {'id': 3565, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 438}
# {'id': 3536, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 409}
# {'id': 3449, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 322}
# {'id': 3692, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 565}
# {'id': 3662, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 535}
# {'id': 3458, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 331}
# {'id': 3608, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 481}
# {'id': 3677, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 550}
# {'id': 3456, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 329}
# {'id': 3469, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 342}
# {'id': 3635, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 508}
# {'id': 3578, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 451}
# {'id': 3718, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 591}
# {'id': 3508, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 381}
# {'id': 3695, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 568}
# {'id': 3529, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 402}
# {'id': 3500, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 373}
# {'id': 3468, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 341}
# {'id': 3584, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 457}
# {'id': 3579, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 452}
# {'id': 3464, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 337}
# {'id': 3642, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 515}
# {'id': 3708, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 581}
# {'id': 3498, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 371}
# {'id': 3605, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 478}
# {'id': 3630, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 503}
# {'id': 3537, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 410}
# {'id': 3645, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 518}
# {'id': 3723, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 596}
# {'id': 3714, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 587}
# {'id': 3631, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 504}
# {'id': 3612, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 485}
# {'id': 3541, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 414}
# {'id': 3650, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 523}
# {'id': 3496, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 369}
# {'id': 3495, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 368}
# {'id': 3628, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 501}
# {'id': 3713, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 586}
# {'id': 3512, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 385}
# {'id': 3611, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 484}
# {'id': 3719, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 592}
# {'id': 3598, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 471}
# {'id': 3614, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 487}
# {'id': 3525, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 398}
# {'id': 3566, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 439}
# {'id': 3715, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 588}
# {'id': 3616, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 489}
# {'id': 3573, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 446}
# {'id': 3451, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 324}
# {'id': 3467, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 340}
# {'id': 3473, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 346}
# {'id': 3720, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 593}
# {'id': 3596, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 469}
# {'id': 3686, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 559}
# {'id': 3674, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 547}
# {'id': 3588, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 461}
# {'id': 3722, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 595}
# {'id': 3641, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 514}
# {'id': 3586, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 459}
# {'id': 3670, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 543}
# {'id': 3663, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 536}
# {'id': 3675, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 548}
# {'id': 3540, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 413}
# {'id': 3455, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 328}
# {'id': 3463, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 336}
# {'id': 3523, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 396}
# {'id': 3487, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 360}
# {'id': 3450, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 323}
# {'id': 3441, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 314}
# {'id': 3619, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 492}
# {'id': 3562, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 435}
# {'id': 3737, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 610}
# {'id': 3640, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 513}
# {'id': 3709, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 582}
# {'id': 3580, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 453}
# {'id': 3651, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 524}
# {'id': 3636, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 509}
# {'id': 3457, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 330}
# {'id': 3595, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 468}
# {'id': 3624, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 497}
# {'id': 3576, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 449}
# {'id': 3504, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 377}
# {'id': 3585, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 458}
# {'id': 3549, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 422}
# {'id': 3732, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 605}
# {'id': 3717, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 590}
# {'id': 3654, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 527}
# {'id': 3526, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 399}
# {'id': 3511, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 384}
# {'id': 3548, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 421}
# {'id': 3561, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 434}
# {'id': 3494, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 367}
# {'id': 3705, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 578}
# {'id': 3506, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 379}
# {'id': 3617, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 490}
# {'id': 3607, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 480}
# {'id': 3545, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 418}
# {'id': 3693, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 566}
# {'id': 3730, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 603}
# {'id': 3520, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 393}
# {'id': 3656, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 529}
# {'id': 3733, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 606}
# {'id': 3704, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 577}
# {'id': 3556, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 429}
# {'id': 3567, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 440}
# {'id': 3488, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 361}
# {'id': 3480, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 353}
# {'id': 3493, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 366}
# {'id': 3443, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 316}
# {'id': 3444, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 317}
# {'id': 3701, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 574}
# {'id': 3591, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 464}
# {'id': 3702, 'type': 'GENERIC_ALL', 'properties': {'isacl': True}, 'start_id': 0, 'end_id': 575}
# ...
# {'id': 4467, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 429}
# {'id': 4479, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 499}
# {'id': 4472, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 335}
# {'id': 4461, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 339}
# {'id': 4464, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 573}
# {'id': 4473, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 383}
# {'id': 4471, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 571}
# {'id': 4483, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 439}
# {'id': 4487, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 416}
# {'id': 4474, 'type': 'CONTAINS', 'properties': {}, 'start_id': 928, 'end_id': 550}
# {'id': 4514, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 555}
# {'id': 4498, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 385}
# {'id': 4508, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 542}
# {'id': 4504, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 398}
# {'id': 4511, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 331}
# {'id': 4506, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 320}
# {'id': 4517, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 387}
# {'id': 4503, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 537}
# {'id': 4500, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 483}
# {'id': 4510, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 476}
# {'id': 4493, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 523}
# {'id': 4501, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 520}
# {'id': 4497, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 366}
# {'id': 4502, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 593}
# {'id': 4519, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 455}
# {'id': 4509, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 363}
# {'id': 4492, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 606}
# {'id': 4496, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 459}
# {'id': 4499, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 509}
# {'id': 4520, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 410}
# {'id': 4494, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 464}
# {'id': 4495, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 318}
# {'id': 4512, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 454}
# {'id': 4491, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 612}
# {'id': 4505, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 361}
# {'id': 4518, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 474}
# {'id': 4507, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 528}
# {'id': 4513, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 500}
# {'id': 4516, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 511}
# {'id': 4515, 'type': 'CONTAINS', 'properties': {}, 'start_id': 929, 'end_id': 338}
# {'id': 4541, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 582}
# {'id': 4539, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 475}
# {'id': 4530, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 470}
# {'id': 4542, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 532}
# {'id': 4528, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 553}
# {'id': 4545, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 522}
# {'id': 4548, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 401}
# {'id': 4536, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 477}
# {'id': 4537, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 587}
# {'id': 4540, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 364}
# {'id': 4546, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 497}
# {'id': 4550, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 515}
# {'id': 4521, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 479}
# {'id': 4531, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 386}
# {'id': 4526, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 564}
# {'id': 4525, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 597}
# {'id': 4535, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 568}
# {'id': 4532, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 319}
# {'id': 4522, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 390}
# {'id': 4549, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 452}
# {'id': 4547, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 323}
# {'id': 4543, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 539}
# {'id': 4529, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 519}
# {'id': 4533, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 334}
# {'id': 4527, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 444}
# {'id': 4523, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 325}
# {'id': 4534, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 604}
# {'id': 4538, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 594}
# {'id': 4524, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 322}
# {'id': 4544, 'type': 'CONTAINS', 'properties': {}, 'start_id': 930, 'end_id': 379}
# {'id': 4560, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 566}
# {'id': 4579, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 574}
# {'id': 4574, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 565}
# {'id': 4564, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 603}
# {'id': 4571, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 585}
# {'id': 4555, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 341}
# {'id': 4561, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 531}
# {'id': 4573, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 507}
# {'id': 4565, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 328}
# {'id': 4567, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 495}
# {'id': 4570, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 403}
# {'id': 4554, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 498}
# {'id': 4559, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 435}
# {'id': 4576, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 393}
# {'id': 4580, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 395}
# {'id': 4553, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 559}
# {'id': 4578, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 526}
# {'id': 4568, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 317}
# {'id': 4569, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 397}
# {'id': 4563, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 353}
# {'id': 4556, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 460}
# {'id': 4552, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 510}
# {'id': 4572, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 371}
# {'id': 4558, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 504}
# {'id': 4562, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 517}
# {'id': 4566, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 563}
# {'id': 4575, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 501}
# {'id': 4551, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 372}
# {'id': 4557, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 508}
# {'id': 4577, 'type': 'CONTAINS', 'properties': {}, 'start_id': 931, 'end_id': 560}
# {'id': 4601, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 391}
# {'id': 4581, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 343}
# {'id': 4582, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 484}
# {'id': 4608, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 394}
# {'id': 4597, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 534}
# {'id': 4591, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 570}
# {'id': 4585, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 525}
# {'id': 4587, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 321}
# {'id': 4586, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 424}
# {'id': 4592, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 349}
# {'id': 4599, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 402}
# {'id': 4603, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 315}
# {'id': 4589, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 513}
# {'id': 4604, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 557}
# {'id': 4602, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 595}
# {'id': 4606, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 456}
# {'id': 4584, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 548}
# {'id': 4607, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 608}
# {'id': 4610, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 369}
# {'id': 4600, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 412}
# {'id': 4593, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 556}
# {'id': 4595, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 465}
# {'id': 4598, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 481}
# {'id': 4583, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 434}
# {'id': 4594, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 413}
# {'id': 4590, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 423}
# {'id': 4588, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 362}
# {'id': 4609, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 569}
# {'id': 4605, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 487}
# {'id': 4596, 'type': 'CONTAINS', 'properties': {}, 'start_id': 932, 'end_id': 433}
# {'id': 4613, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 354}
# {'id': 4630, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 492}
# {'id': 4627, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 461}
# {'id': 4632, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 441}
# {'id': 4631, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 396}
# {'id': 4629, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 355}
# {'id': 4623, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 533}
# {'id': 4634, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 384}
# {'id': 4624, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 358}
# {'id': 4633, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 521}
# {'id': 4619, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 340}
# {'id': 4616, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 430}
# {'id': 4628, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 540}
# {'id': 4640, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 421}
# {'id': 4626, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 605}
# {'id': 4617, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 514}
# {'id': 4636, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 449}
# {'id': 4614, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 365}
# {'id': 4625, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 408}
# {'id': 4622, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 600}
# {'id': 4620, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 414}
# {'id': 4639, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 581}
# {'id': 4615, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 536}
# {'id': 4612, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 502}
# {'id': 4635, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 447}
# {'id': 4611, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 438}
# {'id': 4621, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 337}
# {'id': 4618, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 491}
# {'id': 4638, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 590}
# {'id': 4637, 'type': 'CONTAINS', 'properties': {}, 'start_id': 933, 'end_id': 913}
# {'id': 4663, 'type': 'GP_LINK', 'properties': {}, 'start_id': 934, 'end_id': 917}
# {'id': 4662, 'type': 'GP_LINK', 'properties': {}, 'start_id': 934, 'end_id': 923}
# {'id': 4661, 'type': 'GP_LINK', 'properties': {}, 'start_id': 934, 'end_id': 920}
# {'id': 4664, 'type': 'GP_LINK', 'properties': {}, 'start_id': 935, 'end_id': 931}
# {'id': 4665, 'type': 'GP_LINK', 'properties': {}, 'start_id': 935, 'end_id': 933}
# {'id': 4667, 'type': 'GP_LINK', 'properties': {}, 'start_id': 936, 'end_id': 931}
# {'id': 4666, 'type': 'GP_LINK', 'properties': {}, 'start_id': 936, 'end_id': 922}
# {'id': 4668, 'type': 'GP_LINK', 'properties': {}, 'start_id': 937, 'end_id': 925}
# {'id': 4669, 'type': 'GP_LINK', 'properties': {}, 'start_id': 937, 'end_id': 916}
# {'id': 4670, 'type': 'GP_LINK', 'properties': {}, 'start_id': 938, 'end_id': 928}
# {'id': 4671, 'type': 'GP_LINK', 'properties': {}, 'start_id': 939, 'end_id': 924}
# {'id': 4673, 'type': 'GP_LINK', 'properties': {}, 'start_id': 939, 'end_id': 927}
# {'id': 4672, 'type': 'GP_LINK', 'properties': {}, 'start_id': 939, 'end_id': 916}
# {'id': 4674, 'type': 'GP_LINK', 'properties': {}, 'start_id': 940, 'end_id': 927}
# {'id': 4675, 'type': 'GP_LINK', 'properties': {}, 'start_id': 941, 'end_id': 931}
# {'id': 4676, 'type': 'GP_LINK', 'properties': {}, 'start_id': 941, 'end_id': 928}
# {'id': 4677, 'type': 'GP_LINK', 'properties': {}, 'start_id': 942, 'end_id': 923}
# {'id': 4678, 'type': 'GP_LINK', 'properties': {}, 'start_id': 943, 'end_id': 919}
# {'id': 4679, 'type': 'GP_LINK', 'properties': {}, 'start_id': 944, 'end_id': 927}
# {'id': 4680, 'type': 'GP_LINK', 'properties': {}, 'start_id': 945, 'end_id': 919}
# {'id': 4681, 'type': 'GP_LINK', 'properties': {}, 'start_id': 946, 'end_id': 918}
# {'id': 4682, 'type': 'GP_LINK', 'properties': {}, 'start_id': 947, 'end_id': 933}
# {'id': 4683, 'type': 'GP_LINK', 'properties': {}, 'start_id': 947, 'end_id': 931}
# {'id': 4684, 'type': 'GP_LINK', 'properties': {}, 'start_id': 947, 'end_id': 926}
# {'id': 4685, 'type': 'GP_LINK', 'properties': {}, 'start_id': 948, 'end_id': 917}
# {'id': 4686, 'type': 'GP_LINK', 'properties': {}, 'start_id': 949, 'end_id': 928}
# {'id': 4687, 'type': 'GP_LINK', 'properties': {}, 'start_id': 949, 'end_id': 924}
# {'id': 4688, 'type': 'GP_LINK', 'properties': {}, 'start_id': 949, 'end_id': 930}
# {'id': 4689, 'type': 'GP_LINK', 'properties': {}, 'start_id': 950, 'end_id': 925}
# {'id': 4690, 'type': 'GP_LINK', 'properties': {}, 'start_id': 951, 'end_id': 922}
# {'id': 4691, 'type': 'GP_LINK', 'properties': {}, 'start_id': 951, 'end_id': 932}
# {'id': 4693, 'type': 'GP_LINK', 'properties': {}, 'start_id': 952, 'end_id': 928}
# {'id': 4692, 'type': 'GP_LINK', 'properties': {}, 'start_id': 952, 'end_id': 918}

# %%
class Neo4jDatabase:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def get_node_info(self, label):
        with self.driver.session() as session:
            result = session.read_transaction(self._get_node_info, label)
            return result

    @staticmethod
    def _get_node_info(tx, label):
        query = f"""
        MATCH (d:{label})-[r]-(n)
        RETURN d, r, n
        """
        result = tx.run(query)
        nodes = []
        for record in result:
            node_info = {
                'domain_node': record['d'],
                'relationship': record['r'],
                'connected_node': record['n']
            }
            nodes.append(node_info)
        return nodes

# %% [markdown]
# ### Get information related to nodes with a specific label to process¶

# %%
def get_nodes_with_label(label):
    nodes, relationships = extract_graph_data()
    result = []

    # Find all nodes with the given label
    nodes_with_label = [node for node in nodes if label in node['labels']]
    node_dict = {node['id']: node for node in nodes}  # Dictionary for fast node lookup by ID

    for node in nodes_with_label:
        node_id = node['id']
        node_label = node['labels'][0]
        node_props = node['properties']
        
        # Format node properties
        node_info = f"Node [{node_label}] {node_id}:\n"
        for prop, value in node_props.items():
            node_info += f" - {prop}: {value}\n"
        
        # Filter relationships involving this node
        related_relationships = [rel for rel in relationships if rel['start_id'] == node_id or rel['end_id'] == node_id]
        for rel in related_relationships:
            connected_node_id = rel['end_id'] if rel['start_id'] == node_id else rel['start_id']
            connected_node = node_dict.get(connected_node_id)
            if connected_node:
                connected_node_label = connected_node['labels'][0]
                roles = rel['properties']
                node_info += f"Node [{node_label}] {node_id} is connected to node  [{connected_node_label}] {connected_node_id}  with edge {rel['type']} (roles: {roles}).\n"
        
        result.append(node_info.strip())
    
    return "\n".join(result)

# %% [markdown]
# ### Split the data into chunks with a length limit

# %%
# Function to split the data into chunks with a length limit
def split_data_into_chunks(details, max_length, label_node):
    nodes = details.split(f"Node [{label_node}]")
    nodes = [f"Node [{label_node}]" + node for node in nodes if node]  # Reconstruct each node detail

    chunks = []
    current_chunk = ""
    
    for node in nodes:
        if len(current_chunk) + len(node) > max_length:
            chunks.append(current_chunk.strip())
            current_chunk = ""
        current_chunk += node + "\n"
    
    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

# %% [markdown]
# #### Generate rules

# %%
import os

from groq import Groq

client = Groq(
    api_key= "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",
)

def generator(query, context, model): 
    chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": context + "\n" + query,
        }
    ],
    model= model,
    )

    return chat_completion.choices[0].message.content

# %% [markdown]
# ### Perform

# %%
def _perform_function(max_length, label_node, model):
    contents = get_nodes_with_label(label_node)
    chunks = split_data_into_chunks(contents, max_length, label_node)
    rules = []
    for chunk in chunks: 
        prompt =  f"""From this data, learn patterns and infer consistency rules related node {label_node}. 
        The goal is to ensure that the graph data is accurate, coherent, and follows the expected schema. 
        For each consistency rule you identify, provide a clear description of the rule and the corresponding Cypher query that can be used to check for violations of that rule in the dataset """
        rule = generator(chunk, prompt, model)
        rules.append(rule)
    return rules

# %% [markdown]
# ### Domain

# %%
rules_domain = _perform_function(8100, "Domain", "llama3-70b-8192")

# %%
for rule in rules_domain: 
    print(rule)
# Out:
# Based on the provided data, I identified the following patterns and consistency rules related to the `Domain` node:
#
# **Rule 1: Domain name and domain property consistency**
# The `name` property of a `Domain` node should match the `domain` property.
#
# Cypher query to check for violations:
# ```
# MATCH (d:Domain) WHERE d.name <> d.domain RETURN d
# ```
# **Rule 2: High-value domains have specific relationships**
# A `Domain` node with `highvalue` set to `True` should have relationships with `Group` nodes with specific edge types (e.g., `WRITE_OWNER`, `WRITE_DACL`, `DC_SYNC`, etc.).
#
# Cypher query to check for violations:
# ```
# MATCH (d:Domain {highvalue: true}) WHERE NOT (d)-[:WRITE_OWNER|WRITE_DACL|DC_SYNC]->(:Group) RETURN d
# ```
# **Rule 3: Domain-Group relationships have consistent roles**
# The roles associated with the relationships between a `Domain` node and a `Group` node should be consistent (e.g., `isacl` is always `True`).
#
# Cypher query to check for violations:
# ```
# MATCH (d:Domain)-[r]->(g:Group) WHERE r.roles.isacl IS NULL OR r.roles.isacl <> true RETURN d, r, g
# ```
# **Rule 4: Domain-OU relationships have consistent edge types**
# A `Domain` node should have `CONTAINS` relationships with `OU` nodes, and the roles property should be empty.
#
# Cypher query to check for violations:
# ```
# MATCH (d:Domain)-[r:CONTAINS]->(ou:OU) WHERE r.roles IS NOT NULL RETURN d, r, ou
# ```
# **Rule 5: Domain-GPO relationships have consistent edge types and roles**
# A `Domain` node should have a `GP_LINK` relationship with a `GPO` node, and the roles property should contain `enforced` and `isacl` with consistent values.
#
# Cypher query to check for violations:
# ```
# MATCH (d:Domain)-[r:GP_LINK]->(gpo:GPO) WHERE r.roles.enforced IS NULL OR r.roles.isacl IS NULL RETURN d, r, gpo
# ```
# These consistency rules and Cypher queries can help ensure the accuracy and coherence of the graph data related to the `Domain` node.

# %% [markdown]
# ### GPO

# %%
rules_gpo = _perform_function(8100, "GPO", "llama3-70b-8192")

# %%
for rule in rules_gpo: 
    print(rule)
# Out:
# Based on the provided data, I've identified some patterns and consistency rules related to node GPO. Here are the rules and the corresponding Cypher queries to check for violations:
#
# **Rule 1: Unique `objectid` property**
#
# * Description: Each GPO node should have a unique `objectid` property.
# * Cypher query: `MATCH (gpo:GPO) WITH gpo.objectid as oid MATCH (gpo2:GPO) WHERE gpo2.objectid = oid AND ID(gpo) <> ID(gpo2) RETURN COUNT(*)`
#
# **Rule 2: Consistent `domain` property**
#
# * Description: All GPO nodes should have the same `domain` property value, which is `TestCompany.Local` in this case.
# * Cypher query: `MATCH (gpo:GPO) WHERE gpo.domain <> "TestCompany.Local" RETURN COUNT(*)`
#
# **Rule 3: Correct `name` property format**
#
# * Description: The `name` property of each GPO node should be in the format `GPO_<number>@TestCompany.Local`.
# * Cypher query: `MATCH (gpo:GPO) WHERE NOT gpo.name =~ "GPO_[0-9]+@TestCompany.Local" RETURN COUNT(*)`
#
# **Rule 4: GP_LINK edge consistency**
#
# * Description: GPO nodes should only be connected to OU nodes with a GP_LINK edge, and the edge should have an empty roles dictionary `{}`.
# * Cypher query: `MATCH ()-[r:GP_LINK]->() WHERE NOT (r.roles = {}) OR NOT (type(r.endNode) = "OU") RETURN COUNT(*)`
#
# **Rule 5: No duplicate connections**
#
# * Description: A GPO node should not be connected to the same OU node more than once with a GP_LINK edge.
# * Cypher query: `MATCH (gpo:GPO)-[r:GP_LINK]->(ou:OU) WITH gpo, ou, COUNT(r) as count WHERE count > 1 RETURN COUNT(*)`
#
# **Rule 6: Generic_WRITE edge consistency**
#
# * Description: GPO nodes should only be connected to Group nodes with a GENERIC_WRITE edge, and the edge should have an `isacl` role with value `True`.
# * Cypher query: `MATCH ()-[r:GENERIC_WRITE]->() WHERE NOT (type(r.endNode) = "Group") OR NOT (r.roles.isacl = True) RETURN COUNT(*)`
#
# These rules and queries can help ensure the data is accurate, coherent, and follows the expected schema.

# %% [markdown]
# ### OU

# %%
rules_ou = _perform_function(8100, "OU", "llama3-70b-8192")

# %%
for rule in rules_ou: 
    print(rule)
# Out:
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to node OU. Here are the rules I've found, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: An OU node must have a `domain` property.**
#
# Cypher query:
# ```
# MATCH (ou:OU) WHERE NOT exists(ou.domain) RETURN ou
# ```
# **Rule 2: An OU node must have a `name` property.**
#
# Cypher query:
# ```
# MATCH (ou:OU) WHERE NOT exists(ou.name) RETURN ou
# ```
# **Rule 3: An OU node must have an `objectId` property.**
#
# Cypher query:
# ```
# MATCH (ou:OU) WHERE NOT exists(ou.objectId) RETURN ou
# ```
# **Rule 4: An OU node must be connected to a Domain node with a CONTAINS edge.**
#
# Cypher query:
# ```
# MATCH (ou:OU) WHERE NOT exists(ou)-[:CONTAINS]-(d:Domain) RETURN ou
# ```
# **Rule 5: An OU node can be connected to multiple Computer nodes with CONTAINS edges.**
#
# This rule is already evident from the data, as multiple Computer nodes are connected to each OU node.
#
# **Rule 6: An OU node can be connected to a GPO node with a GP_LINK edge (optional).**
#
# Cypher query:
# ```
# MATCH (ou:OU) WHERE exists(ou)-[:GP_LINK]-(gpo:GPO) RETURN ou
# ```
# This rule is optional, as not all OU nodes have a GPO connection.
#
# **Rule 7: An OU node's `blocksInheritance` property must be a boolean value.**
#
# Cypher query:
# ```
# MATCH (ou:OU) WHERE NOT ou.blocksInheritance IN [true, false] RETURN ou
# ```
# These rules ensure that the graph data is accurate, coherent, and follows the expected schema. You can use these Cypher queries to check for violations and take corrective action to maintain data consistency.
# Based on the provided data, I have identified some patterns and inferred consistency rules related to node OU:
#
# **Consistency Rule 1: Each OU node has a unique `neo4jImportId`**
#
# Description: Each OU node has a unique `neo4jImportId` property.
#
# Cypher Query: `MATCH (ou:OU) RETURN ou.neo4jImportId AS id, COUNT(ou) AS count GROUP BY id HAVING count > 1`
#
# This query checks if there are any duplicate `neo4jImportId` values among OU nodes.
#
# **Consistency Rule 2: Each OU node is connected to exactly one Domain node**
#
# Description: Each OU node is connected to exactly one Domain node with a `CONTAINS` edge.
#
# Cypher Query: `MATCH (ou:OU)-[:CONTAINS]-(domain:Domain) RETURN ou.neo4jImportId AS id, COUNT(domain) AS count GROUP BY id HAVING count > 1 OR count = 0`
#
# This query checks if each OU node is connected to exactly one Domain node.
#
# **Consistency Rule 3: Each OU node has a unique `name` property**
#
# Description: Each OU node has a unique `name` property.
#
# Cypher Query: `MATCH (ou:OU) RETURN ou.name AS name, COUNT(ou) AS count GROUP BY name HAVING count > 1`
#
# This query checks if there are any duplicate `name` values among OU nodes.
#
# **Consistency Rule 4: Each OU node can be connected to multiple Computer nodes**
#
# Description: Each OU node can be connected to multiple Computer nodes with a `CONTAINS` edge.
#
# Cypher Query: `MATCH (ou:OU)-[:CONTAINS]-(computer:Computer) RETURN ou.neo4jImportId AS id, COUNT(computer) AS count`
#
# This query checks the number of Computer nodes connected to each OU node.
#
# **Consistency Rule 5: Each OU node can be connected to multiple GPO nodes**
#
# Description: Each OU node can be connected to multiple GPO nodes with a `GP_LINK` edge.
#
# Cypher Query: `MATCH (ou:OU)-[:GP_LINK]-(gpo:GPO) RETURN ou.neo4jImportId AS id, COUNT(gpo) AS count`
#
# This query checks the number of GPO nodes connected to each OU node.
#
# By running these Cypher queries, you can identify any inconsistencies in the graph data that violate these consistency rules.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the node OU. Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: An OU node should have a unique `neo4jImportId` property.**
#
# Cypher query: `MATCH (ou:OU) WITH ou.neo4jImportId AS id, COUNT(ou) AS count WHERE count > 1 RETURN id, count`
#
# **Rule 2: An OU node should have a `domain` property with a value that matches the pattern `<domain_name>` (e.g., `TestCompany.Local`).**
#
# Cypher query: `MATCH (ou:OU) WHERE NOT ou.domain =~ '[A-Za-z0-9\.]+' RETURN ou`
#
# **Rule 3: An OU node should have a `name` property with a value that matches the pattern `<prefix>_<computer_type>@<domain>` (e.g., `CA_COMPUTERS@TestCompany.Local`).**
#
# Cypher query: `MATCH (ou:OU) WHERE NOT ou.name =~ '[A-Z_]+_[A-Z_]+@[A-Za-z0-9\.]+' RETURN ou`
#
# **Rule 4: An OU node should have only one edge of type `CONTAINS` connected to a `Domain` node.**
#
# Cypher query: `MATCH (ou:OU)-[r:CONTAINS]->(d:Domain) WITH ou, COUNT(r) AS count WHERE count > 1 RETURN ou, count`
#
# **Rule 5: An OU node should have edges of type `CONTAINS` connected to `Computer` nodes, but not to other OU nodes.**
#
# Cypher query: `MATCH (ou:OU)-[r:CONTAINS]->(c:OU) RETURN ou, c`
#
# **Rule 6: An OU node should have edges of type `GP_LINK` connected to `GPO` nodes, but not to other OU nodes.**
#
# Cypher query: `MATCH (ou:OU)-[r:GP_LINK]->(c:OU) RETURN ou, c`
#
# **Rule 7: A `Computer` node connected to an OU node should have a unique `objectid` property.**
#
# Cypher query: `MATCH (ou:OU)-[:CONTAINS]->(c:Computer) WITH c.objectid AS id, COUNT(c) AS count WHERE count > 1 RETURN id, count`
#
# **Rule 8: A `GPO` node connected to an OU node should have a unique `objectid` property.**
#
# Cypher query: `MATCH (ou:OU)-[:GP_LINK]->(gpo:GPO) WITH gpo.objectid AS id, COUNT(gpo) AS count WHERE count > 1 RETURN id, count`
#
# These rules and queries can help ensure the accuracy and coherence of the graph data.
# After analyzing the provided data, I've identified some patterns and consistency rules related to node OU. Here are the rules I've detected, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: An OU node is connected to multiple Computer nodes with a CONTAINS edge**
#
# * Description: An OU node can have multiple Computer nodes connected to it with a CONTAINS edge.
# * Cypher query to check for violations: `MATCH (ou:OU) WHERE NOT EXISTS((ou)-[:CONTAINS]->(:Computer)) RETURN ou`
#
# **Rule 2: An OU node is connected to at most one GPO node with a GP_LINK edge**
#
# * Description: An OU node can have at most one GPO node connected to it with a GP_LINK edge.
# * Cypher query to check for violations: `MATCH (ou:OU) WHERE size((ou)-[:GP_LINK]->(:GPO)) > 1 RETURN ou`
#
# **Rule 3: An OU node is connected to a Domain node with a CONTAINS edge**
#
# * Description: An OU node must be connected to a Domain node with a CONTAINS edge.
# * Cypher query to check for violations: `MATCH (ou:OU) WHERE NOT EXISTS((ou)-[:CONTAINS]->(:Domain)) RETURN ou`
#
# **Rule 4: An OU node can have multiple User nodes connected to it with a CONTAINS edge (only for OU nodes with name ending in "_USERS")**
#
# * Description: For OU nodes with names ending in "_USERS", they can have multiple User nodes connected to them with a CONTAINS edge.
# * Cypher query to check for violations: `MATCH (ou:OU {name: ~/.*_USERS$/}) WHERE NOT EXISTS((ou)-[:CONTAINS]->(:User)) RETURN ou`
#
# **Rule 5: An OU node has a name property**
#
# * Description: An OU node must have a name property.
# * Cypher query to check for violations: `MATCH (ou:OU) WHERE NOT EXISTS(ou.name) RETURN ou`
#
# **Rule 6: An OU node has a domain property**
#
# * Description: An OU node must have a domain property.
# * Cypher query to check for violations: `MATCH (ou:OU) WHERE NOT EXISTS(ou.domain) RETURN ou`
#
# **Rule 7: An OU node has a blocksInheritance property**
#
# * Description: An OU node must have a blocksInheritance property.
# * Cypher query to check for violations: `MATCH (ou:OU) WHERE NOT EXISTS(ou.blocksInheritance) RETURN ou`
#
# These rules and Cypher queries can help identify inconsistencies in the graph data related to node OU.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the node OU:
#
# **Rule 1: An OU node has a unique `neo4jImportId` property**
#
# Consistency Rule: Each OU node should have a unique `neo4jImportId` property.
#
# Cypher Query to check for violations:
# ```
# MATCH (ou:OU) WITH ou.neo4jImportId as id, COUNT(*) as count
# WHERE count > 1
# RETURN id, count
# ```
# This query groups the OU nodes by their `neo4jImportId` property and returns any IDs that appear more than once, indicating duplicates.
#
# **Rule 2: An OU node is connected to exactly one Domain node with a CONTAINS edge**
#
# Consistency Rule: Each OU node should be connected to exactly one Domain node with a CONTAINS edge.
#
# Cypher Query to check for violations:
# ```
# MATCH (ou:OU) -[:CONTAINS] -> (d:Domain)
# WITH ou, COUNT(*) as count
# WHERE count > 1
# RETURN ou, count
# ```
# This query counts the number of Domain nodes connected to each OU node with a CONTAINS edge and returns any OU nodes with more than one connection.
#
# **Rule 3: An OU node is connected to multiple User nodes with CONTAINS edges**
#
# Consistency Rule: Each OU node can be connected to multiple User nodes with CONTAINS edges.
#
# Cypher Query to check for violations:
# ```
# MATCH (ou:OU) -[:CONTAINS] -> (u:User)
# WITH ou, COUNT(*) as count
# WHERE count < 1
# RETURN ou, count
# ```
# This query counts the number of User nodes connected to each OU node with a CONTAINS edge and returns any OU nodes with no connections.
#
# **Rule 4: An OU node can be connected to multiple GPO nodes with GP_LINK edges**
#
# Consistency Rule: Each OU node can be connected to multiple GPO nodes with GP_LINK edges.
#
# Cypher Query to check for violations:
# ```
# MATCH (ou:OU) -[:GP_LINK] -> (gpo:GPO)
# WITH ou, COUNT(*) as count
# WHERE count < 1
# RETURN ou, count
# ```
# This query counts the number of GPO nodes connected to each OU node with a GP_LINK edge and returns any OU nodes with no connections.
#
# **Rule 5: An OU node has a `blocksInheritance` property with a boolean value**
#
# Consistency Rule: Each OU node should have a `blocksInheritance` property with a boolean value.
#
# Cypher Query to check for violations:
# ```
# MATCH (ou:OU) WHERE NOT EXISTS(ou.blocksInheritance) OR NOT (ou.blocksInheritance IN [true, false])
# RETURN ou
# ```
# This query returns any OU nodes that do not have a `blocksInheritance` property or have a non-boolean value.
#
# By running these Cypher queries, you can identify any inconsistencies in the data related to the OU nodes and take steps to correct them.
# Based on the provided data, I've identified several patterns and consistency rules related to node OU:
#
# **Rule 1: OU nodes are connected to Domain nodes with CONTAINS edge**
#
# * Description: Each OU node is connected to exactly one Domain node with a CONTAINS edge.
# * Cypher query: `MATCH (ou:OU)-[:CONTAINS]->(d:Domain) RETURN ou, d`
#
# **Rule 2: OU nodes are connected to User nodes with CONTAINS edge**
#
# * Description: Each OU node is connected to multiple User nodes with a CONTAINS edge.
# * Cypher query: `MATCH (ou:OU)-[:CONTAINS]->(u:User) RETURN ou, u`
#
# **Rule 3: OU nodes are connected to GPO nodes with GP_LINK edge**
#
# * Description: Each OU node is connected to multiple GPO nodes with a GP_LINK edge.
# * Cypher query: `MATCH (ou:OU)-[:GP_LINK]->(gpo:GPO) RETURN ou, gpo`
#
# **Rule 4: OU nodes have specific properties**
#
# * Description: Each OU node has properties such as `blocksInheritance`, `neo4jImportId`, `domain`, `name`, and `objectid`.
# * Cypher query: `MATCH (ou:OU) RETURN ou.blocksInheritance, ou.neo4jImportId, ou.domain, ou.name, ou.objectid`
#
# **Rule 5: OU nodes are not connected to other OU nodes**
#
# * Description: There are no edges between OU nodes.
# * Cypher query: `MATCH (ou1:OU)-[:*]->(ou2:OU) RETURN ou1, ou2` (this query should return no results)
#
# These rules can be used to ensure data consistency and accuracy in the graph database. By running these Cypher queries, you can detect any inconsistencies or violations of these rules in the data.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to node OU. Here are the rules I've identified, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: An OU node can have multiple USER nodes connected to it with a CONTAINS edge.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (ou:OU {id: 930})-[:CONTAINS]-(u:User) RETURN COUNT(DISTINCT u) as count
# ```
# Expected result: `count` should be greater than 1.
#
# **Rule 2: An OU node can have multiple GPO nodes connected to it with a GP_LINK edge.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (ou:OU {id: 931})-[:GP_LINK]-(gpo:GPO) RETURN COUNT(DISTINCT gpo) as count
# ```
# Expected result: `count` should be greater than 1.
#
# **Rule 3: An OU node can have only one Domain node connected to it with a CONTAINS edge.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (ou:OU {id: 931})-[:CONTAINS]-(d:Domain) RETURN COUNT(DISTINCT d) as count
# ```
# Expected result: `count` should be equal to 1.
#
# **Rule 4: A User node can be connected to only one OU node with a CONTAINS edge.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User {id: 566})-[:CONTAINS]-(ou:OU) RETURN COUNT(DISTINCT ou) as count
# ```
# Expected result: `count` should be equal to 1.
#
# **Rule 5: An OU node must have at least one User node connected to it with a CONTAINS edge.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (ou:OU {id: 932}) WHERE NOT EXISTS ((ou)-[:CONTAINS]-(u:User)) RETURN COUNT(*) as count
# ```
# Expected result: `count` should be equal to 0.
#
# **Rule 6: An OU node can have at most one GP_LINK edge to a GPO node.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (ou:OU {id: 932})-[:GP_LINK]-(gpo:GPO) RETURN COUNT(DISTINCT gpo) as count
# ```
# Expected result: `count` should be less than or equal to 1.
#
# These rules and queries can help ensure the accuracy, coherence, and consistency of the graph data.
# After analyzing the provided data, I've identified some patterns and consistency rules related to node OU:
#
# **Consistency Rule 1:** An OU node can have multiple CONTAINS relationships with User nodes.
#
# * Description: An OU node can be connected to multiple User nodes, indicating that the OU contains those users.
# * Cypher query to check for violations: `MATCH (ou:OU)-[:CONTAINS]-(u:User) WHERE NOT (ou)-[:CONTAINS]->(:User) RETURN ou, u`
#
# **Consistency Rule 2:** An OU node can have multiple GP_LINK relationships with GPO nodes.
#
# * Description: An OU node can be connected to multiple GPO nodes, indicating that the OU is linked to those GPOs.
# * Cypher query to check for violations: `MATCH (ou:OU)-[:GP_LINK]-(gpo:GPO) WHERE NOT (ou)-[:GP_LINK]->(:GPO) RETURN ou, gpo`
#
# **Consistency Rule 3:** An OU node can only have one type of edge with a User node (CONTAINS).
#
# * Description: An OU node should only have a CONTAINS relationship with a User node, and not any other type of edge.
# * Cypher query to check for violations: `MATCH (ou:OU)-[r]-(u:User) WHERE type(r) <> 'CONTAINS' RETURN ou, u, r`
#
# **Consistency Rule 4:** An OU node can only have one type of edge with a GPO node (GP_LINK).
#
# * Description: An OU node should only have a GP_LINK relationship with a GPO node, and not any other type of edge.
# * Cypher query to check for violations: `MATCH (ou:OU)-[r]-(gpo:GPO) WHERE type(r) <> 'GP_LINK' RETURN ou, gpo, r`
#
# **Consistency Rule 5:** Roles are not specified in the CONTAINS or GP_LINK relationships.
#
# * Description: The roles property is empty in all CONTAINS and GP_LINK relationships.
# * Cypher query to check for violations: `MATCH ()-[r]-(u) WHERE r.roles IS NOT NULL RETURN r`
#
# Note: These consistency rules are based on the provided data and may not be comprehensive. Additional data may reveal more patterns and rules.

# %% [markdown]
# ### Group

# %%
rules_group = _perform_function(8100, "Group", "llama3-70b-8192")

# %%
for rule in rules_group: 
    print(rule)
# Out:
# Based on the provided data, I've identified some patterns and consistency rules related to the `Group` node:
#
# **Rule 1: Existence of `highvalue` property**
#
# * Description: Every `Group` node should have a `highvalue` property.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE NOT EXISTS(g.highvalue) RETURN g
# ```
#
# **Rule 2: Uniqueness of `neo4jImportId`**
#
# * Description: Every `Group` node should have a unique `neo4jImportId` property.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g1:Group), (g2:Group) WHERE g1.neo4jImportId = g2.neo4jImportId AND g1 <> g2 RETURN g1, g2
# ```
#
# **Rule 3: Consistency of `domain` property**
#
# * Description: Every `Group` node should have a `domain` property with a specific format (e.g., `TestCompany.Local`).
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE NOT g.domain =~ '.*\\..*' RETURN g
# ```
#
# **Rule 4: Consistency of `name` property**
#
# * Description: Every `Group` node should have a `name` property with a specific format (e.g., `DOMAIN ADMINS@TestCompany.Local`).
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE NOT g.name =~ 'DOMAIN ADMINS@.*' RETURN g
# ```
#
# **Rule 5: Existence of `objectid` property**
#
# * Description: Every `Group` node should have an `objectid` property.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE NOT EXISTS(g.objectid) RETURN g
# ```
#
# **Rule 6: Consistency of edge connections**
#
# * Description: Every `Group` node should have edges with other nodes (e.g., `Computer`, `Group`) with a specific edge type (e.g., `GENERIC_ALL`) and role (e.g., `isacl: True`).
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[r:GENERIC_ALL]-(n) WHERE NOT r.roles = {isacl: true} RETURN g, r, n
# ```
#
# These rules can help ensure the accuracy and coherence of the graph data. You can modify or add rules as needed based on your specific use case and schema requirements.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the Node Group. Here are the rules I've found, along with corresponding Cypher queries to check for violations:
#
# **Rule 1: All edges between Node Group 0 and other Node Groups have the same properties**
#
# * Description: All edges between Node Group 0 and other Node Groups have the same properties, i.e., `edge_type` is `GENERIC_ALL` and `roles` contains `{'isacl': True}`.
# * Cypher query:
# ```cypher
# MATCH (n0:Group {id: 0})-[:GENERIC_ALL]-(n1:Group)
# WHERE NOT (n0)-[:GENERIC_ALL {roles: {'isacl': true}}]->(n1)
# RETURN COUNT(*) AS violation_count;
# ```
# This query checks if there are any edges between Node Group 0 and other Node Groups that don't have the expected properties. If the result is non-zero, it indicates a violation of this rule.
#
# **Rule 2: Node Group 0 is connected to all other Node Groups**
#
# * Description: Node Group 0 is connected to all other Node Groups with an edge of type `GENERIC_ALL`.
# * Cypher query:
# ```cypher
# MATCH (n0:Group {id: 0})
# WHERE NOT (n0)-[:GENERIC_ALL]->(:Group)
# RETURN COUNT(*) AS violation_count;
# ```
# This query checks if there are any Node Groups that are not connected to Node Group 0 with an edge of type `GENERIC_ALL`. If the result is non-zero, it indicates a violation of this rule.
#
# **Rule 3: Node Group 0 is the only node with multiple edges**
#
# * Description: Node Group 0 is the only node with multiple edges, and all other nodes have at most one edge.
# * Cypher query:
# ```cypher
# MATCH (n:Group)
# WHERE n.id <> 0 AND size((n)-[:GENERIC_ALL]->()) > 1
# RETURN COUNT(*) AS violation_count;
# ```
# This query checks if there are any nodes (other than Node Group 0) with multiple edges. If the result is non-zero, it indicates a violation of this rule.
#
# These rules and queries help ensure the accuracy, coherence, and consistency of the graph data.
# After analyzing the provided data, I've identified several patterns and consistency rules related to the `Group` node. Here are the rules I've discovered, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: All edges connecting `Group` nodes have the same type and roles**
#
# Description: All edges connecting `Group` nodes have the type `GENERIC_ALL` and the same roles `{'isacl': True}`.
#
# Cypher query:
# ```
# MATCH (g1:Group)-[e:GENERIC_ALL]->(g2:Group)
# WHERE e.roles <> {'isacl': true} OR e.type <> 'GENERIC_ALL'
# RETURN e;
# ```
# **Rule 2: Node `Group` 0 is connected to all other `Group` nodes**
#
# Description: Node `Group` 0 is connected to all other `Group` nodes in the dataset.
#
# Cypher query:
# ```
# MATCH (g:Group) WHERE NOT ((g)-[:GENERIC_ALL]-(g0:Group {id: 0}))
# RETURN g;
# ```
# **Rule 3: Each `Group` node is connected to Node `Group` 0**
#
# Description: Each `Group` node is connected to Node `Group` 0 with an edge of type `GENERIC_ALL` and roles `{'isacl': true}`.
#
# Cypher query:
# ```
# MATCH (g:Group) WHERE NOT ((g)<-[:GENERIC_ALL]-(g0:Group {id: 0}))
# RETURN g;
# ```
# **Rule 4: No duplicate edges between `Group` nodes**
#
# Description: There are no duplicate edges between `Group` nodes, i.e., no two edges with the same type, roles, and direction between the same pair of nodes.
#
# Cypher query:
# ```
# MATCH (g1:Group)-[e1:GENERIC_ALL]->(g2:Group)
# MATCH (g1)-[e2:GENERIC_ALL]->(g2)
# WHERE e1 <> e2 AND e1.roles = e2.roles AND e1.type = e2.type
# RETURN e1, e2;
# ```
# These rules aim to ensure that the graph data is accurate and follows the expected schema. By running these Cypher queries, you can identify potential inconsistencies and violations in the data.
# Based on the provided data, I've identified some patterns and inferred consistency rules related to the `Group` node:
#
# **Consistency Rules:**
#
# 1. **All edges connected to a `Group` node have the type `GENERIC_ALL` and a role `isacl` with value `True`**.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(n) WHERE e isacl IS NULL OR e isacl <> true OR e.type <> 'GENERIC_ALL' RETURN g, e, n;
# ```
# This query will return all edges connected to a `Group` node that do not have the expected properties.
#
# 2. **A `Group` node can be connected to multiple `Group` nodes**.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g1:Group)-[:GENERIC_ALL]-(g2:Group) WHERE g1 = g2 RETURN g1, g2;
# ```
# This query will return all cases where a `Group` node is connected to itself, which is not expected.
#
# 3. **A `Group` node can be connected to multiple `User` nodes**.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:GENERIC_ALL]-(u:User) WHERE g IN [] RETURN g, u;
# ```
# This query will return an empty result set, as there are no restrictions on the number of `User` nodes connected to a `Group` node.
#
# 4. **There is no limit on the number of edges connected to a `Group` node**.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) RETURN g, COUNT(g)-[:GENERIC_ALL]-(n) AS edgeCount;
# ```
# This query will return the number of edges connected to each `Group` node, but there is no expected limit.
#
# 5. **All connected nodes (both `Group` and `User`) have a unique ID**.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (n) WHERE ID(n) IN [] RETURN n;
# ```
# This query will return an empty result set, as there are no duplicate IDs in the data.
#
# Note that these rules and queries are based on the provided data and might not cover all possible scenarios. Additional data and domain knowledge might be required to identify more comprehensive consistency rules.
# Based on the provided data, I've identified the following consistency rules related to the Node Group:
#
# **Rule 1: All edges connected to a Group node have the same edge type**
#
# * Description: All edges connected to a Group node should have the same edge type, which is GENERIC_ALL in this case.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(u:User)
# WHERE e.type <> 'GENERIC_ALL'
# RETURN g, e, u
# ```
# This query will return any edges that don't have the GENERIC_ALL type, indicating a violation of this rule.
#
# **Rule 2: All edges connected to a Group node have the same roles property**
#
# * Description: All edges connected to a Group node should have the same roles property, which is {'isacl': True} in this case.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(u:User)
# WHERE e.roles <> {'isacl': True}
# RETURN g, e, u
# ```
# This query will return any edges that don't have the {'isacl': True} roles property, indicating a violation of this rule.
#
# **Rule 3: A Group node can be connected to multiple User nodes**
#
# * Description: A Group node can be connected to multiple User nodes, as seen in the provided data.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(u:User)
# WITH g, COUNT(u) AS num_users
# WHERE num_users < 2
# RETURN g
# ```
# This query will return any Group nodes that are connected to fewer than two User nodes, indicating a potential violation of this rule.
#
# **Rule 4: All User nodes connected to a Group node have a unique identifier**
#
# * Description: All User nodes connected to a Group node should have a unique identifier, as seen in the provided data.
# * Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(u:User)
# WITH g, u
# MATCH (g)-[e2]-(u2:User)
# WHERE u.id = u2.id AND u <> u2
# RETURN g, u, u2
# ```
# This query will return any duplicate User nodes connected to the same Group node, indicating a violation of this rule.
#
# These consistency rules ensure that the graph data is accurate, coherent, and follows the expected schema.
# Based on the provided data, I've identified the following patterns and consistency rules related to the Node Group:
#
# **Rule 1: Edge Type Consistency**
#
# * Description: All edges connecting a Node Group to a Node User have the same type, namely GENERIC_ALL.
# * Cypher Query: `MATCH (g:Group)-[e]-(u:User) RETURN COUNT(DISTINCT e.type) AS edge_type_count`
# * Expected Result: edge_type_count = 1, indicating that all edges have the same type GENERIC_ALL.
#
# **Rule 2: Role Consistency**
#
# * Description: All edges connecting a Node Group to a Node User have the same role, namely {'isacl': True}.
# * Cypher Query: `MATCH (g:Group)-[e]-(u:User) RETURN COUNT(DISTINCT e.roles) AS role_count`
# * Expected Result: role_count = 1, indicating that all edges have the same role {'isacl': True}.
#
# **Rule 3: Node Group Connectivity**
#
# * Description: A Node Group can be connected to multiple Node Users, but each Node User is connected to only one Node Group.
# * Cypher Query: `MATCH (g:Group)-[e]-(u:User) RETURN COUNT(DISTINCT g) AS group_count, COUNT(DISTINCT u) AS user_count`
# * Expected Result: group_count = 1, user_count > 1, indicating that there is only one Node Group connected to multiple Node Users.
#
# **Rule 4: Node User Uniqueness**
#
# * Description: Each Node User is unique and has a distinct identifier.
# * Cypher Query: `MATCH (u:User) RETURN COUNT(DISTINCT u.id) AS user_id_count`
# * Expected Result: user_id_count = user_count, indicating that each Node User has a unique identifier.
#
# To check for violations of these rules, you can modify the Cypher queries to return the specific nodes or edges that violate the rule. For example, to find edges with different types, you can use:
# ```cypher
# MATCH (g:Group)-[e]-(u:User) WHERE e.type <> 'GENERIC_ALL' RETURN e
# ```
# This would return all edges that have a type other than GENERIC_ALL.
# After analyzing the provided data, I've identified the following patterns and consistency rules related to the Node Group:
#
# **Rule 1: All nodes connected to a Group node have a GENERIC_ALL edge with roles {'isacl': True}**
#
# This rule states that every node connected to a Group node must have an edge with the type GENERIC_ALL and the property roles set to {'isacl': True}.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e:GENERIC_ALL]-(u:User)
# WHERE NOT e.roles = {'isacl': True}
# RETURN g, e, u
# ```
# **Rule 2: A Group node can be connected to multiple User nodes**
#
# This rule states that a Group node can have multiple relationships with different User nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e:GENERIC_ALL]-(u:User)
# WITH g, COUNT(u) as count
# WHERE count < 2
# RETURN g
# ```
# **Rule 3: Each User node is connected to only one Group node**
#
# This rule states that a User node is only connected to one Group node.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)-[e:GENERIC_ALL]-(g:Group)
# WITH u, COUNT(g) as count
# WHERE count > 1
# RETURN u
# ```
# **Rule 4: All edges between Group and User nodes have the label GENERIC_ALL**
#
# This rule states that every edge between a Group node and a User node must have the label GENERIC_ALL.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(u:User)
# WHERE NOT e:GENERIC_ALL
# RETURN g, e, u
# ```
# These rules can be used to ensure data consistency and accuracy in the graph.
# Based on the provided data, I have identified the following patterns and consistency rules related to the `Group` node:
#
# **Rule 1: Single Group Node**
# Description: There should only be one `Group` node with ID 0.
# Cypher Query: `MATCH (g:Group) RETURN COUNT(DISTINCT g) AS group_count` (should return 1)
#
# **Rule 2: Edge Type Consistency**
# Description: All edges connected to the `Group` node should be of type `GENERIC_ALL`.
# Cypher Query: `MATCH (g:Group)-[e]-(n) RETURN e.type AS edge_type` (should only return `GENERIC_ALL`)
#
# **Rule 3: Role Consistency**
# Description: All edges connected to the `Group` node should have a role property with `isacl` set to `True`.
# Cypher Query: `MATCH (g:Group)-[e]-(n) RETURN e.roles isacl AS isacl_role` (should only return `True`)
#
# **Rule 4: Node Type Consistency**
# Description: The `Group` node should be connected to either `User` nodes or `Computer` nodes.
# Cypher Query: `MATCH (g:Group)-[e]-(n) RETURN labels(n) AS node_labels` (should only return `User` or `Computer`)
#
# **Rule 5: Connection Consistency**
# Description: The `Group` node should be connected to at least one `User` node or one `Computer` node.
# Cypher Query: `MATCH (g:Group) RETURN EXISTS((g)-[:GENERIC_ALL]-(:User)) OR EXISTS((g)-[:GENERIC_ALL]-(:Computer)) AS connection_consistency` (should return `True`)
#
# **Rule 6: Duplicate Connections**
# Description: There should be no duplicate connections between the `Group` node and other nodes.
# Cypher Query: `MATCH (g:Group)-[e1]-(n) MATCH (g:Group)-[e2]-(n) WHERE e1 <> e2 RETURN COUNT(*) AS duplicate_connections` (should return 0)
#
# These rules can be used to validate the consistency of the graph data and ensure that it follows the expected schema.
# After analyzing the data, I've identified some patterns and consistency rules related to the `Group` node:
#
# **Rule 1: Edge type consistency**
#
# * Description: All edges connected to `Group` nodes have the same type, `GENERIC_ALL`.
# * Cypher query: `MATCH (g:Group)-[e]-(c:Computer) WHERE e.type <> 'GENERIC_ALL' RETURN g, e, c`
#
# **Rule 2: Role consistency**
#
# * Description: All edges connected to `Group` nodes have the same role, `isacl` with value `True`.
# * Cypher query: `MATCH (g:Group)-[e]-(c:Computer) WHERE e.roles.isacl <> true RETURN g, e, c`
#
# **Rule 3: Node type consistency**
#
# * Description: All nodes connected to `Group` nodes are of type `Computer`.
# * Cypher query: `MATCH (g:Group)-[e]-(c) WHERE NOT c:Computer RETURN g, e, c`
#
# **Rule 4: Edge multiplicity**
#
# * Description: Each `Group` node has multiple edges to different `Computer` nodes.
# * Cypher query: `MATCH (g:Group) WHERE size((g)-[:GENERIC_ALL]-(c:Computer)) < 2 RETURN g`
#
# **Rule 5: Node uniqueness**
#
# * Description: Each `Computer` node is connected to at most one `Group` node.
# * Cypher query: `MATCH (c:Computer) WHERE size((c)-[:GENERIC_ALL]-(g:Group)) > 1 RETURN c`
#
# These rules can be used to identify inconsistencies in the graph data. By running these Cypher queries, you can detect and correct any deviations from the expected schema.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the node Group. Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: All edges from a Group node have the same label (GENERIC_ALL) and role (isacl=True)**
#
# Cypher query: `MATCH (g:Group)-[e:GENERIC_ALL]-(c:Computer) WHERE e.roles.isacl <> true RETURN g, e, c`
#
# This query checks if all edges from a Group node have the GENERIC_ALL label and the isacl role set to true. If any edge does not meet this condition, it will be returned in the result set.
#
# **Rule 2: A Group node can only be connected to Computer nodes**
#
# Cypher query: `MATCH (g:Group)-[e:GENERIC_ALL]-(n) WHERE NOT n:Computer RETURN g, e, n`
#
# This query checks if a Group node is connected to any node that is not a Computer node. If any such connection is found, it will be returned in the result set.
#
# **Rule 3: All Computer nodes connected to a Group node have a unique identifier**
#
# Cypher query: `MATCH (g:Group)-[e:GENERIC_ALL]-(c1:Computer), (g)-[e2:GENERIC_ALL]-(c2:Computer) WHERE c1.id = c2.id RETURN g, e1, c1, e2, c2`
#
# This query checks if there are any duplicate Computer nodes connected to a Group node. If any duplicates are found, they will be returned in the result set.
#
# **Rule 4: A Group node can be connected to multiple Computer nodes, but each Computer node can only be connected to one Group node**
#
# Cypher query: `MATCH (c:Computer)-[e1:GENERIC_ALL]-(g1:Group), (c)-[e2:GENERIC_ALL]-(g2:Group) WHERE g1 <> g2 RETURN c, e1, g1, e2, g2`
#
# This query checks if a Computer node is connected to multiple Group nodes. If any Computer node is connected to more than one Group node, it will be returned in the result set.
#
# These rules and queries can help ensure the accuracy, coherence, and schema compliance of the graph data.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the Node Group. Here are the rules along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: All edges connected to a Group node have the same label (GENERIC_ALL) and role (isacl=True).**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(c:Computer)
# WHERE NOT (e.label = 'GENERIC_ALL' AND e.roles = {isacl: true})
# RETURN g, e, c;
# ```
# This query will return any Group nodes, edges, and connected Computer nodes that do not conform to the expected label and role.
#
# **Rule 2: A Group node is connected to multiple Computer nodes, but each Computer node is connected to only one Group node.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:GENERIC_ALL]-(c:Computer)
# WITH g, COUNT(c) AS count
# WHERE count > 1
# RETURN g, count;
# ```
# This query will return any Group nodes that are connected to more than one Computer node, which is not allowed according to this rule.
#
# **Rule 3: There are no duplicate edges between a Group node and a Computer node.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e1:GENERIC_ALL]-(c:Computer)
# MATCH (g)-[e2:GENERIC_ALL]-(c)
# WHERE e1 <> e2
# RETURN g, e1, e2, c;
# ```
# This query will return any duplicate edges between a Group node and a Computer node, which is not allowed according to this rule.
#
# These consistency rules and Cypher queries can help ensure the accuracy and coherence of the graph data.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the Node Group. Here are the rules I've discovered, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: A Group node can be connected to multiple Computer nodes with the GENERIC_ALL edge type and 'isacl' role.**
#
# Description: This rule states that a Group node can have multiple relationships with Computer nodes, all with the GENERIC_ALL edge type and 'isacl' role.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e:GENERIC_ALL {roles: {'isacl': true}}]->(c:Computer)
# RETURN g, COUNT(DISTINCT c) AS num_computers
# HAVING num_computers = 1
# ```
# This query will return any Group node that has only one relationship with a Computer node with the GENERIC_ALL edge type and 'isacl' role, indicating a potential violation of this rule.
#
# **Rule 2: A Group node can be connected to multiple Computer nodes with the ADMIN_TO edge type and no roles.**
#
# Description: This rule states that a Group node can have multiple relationships with Computer nodes, all with the ADMIN_TO edge type and no roles specified.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e:ADMIN_TO {roles: {}}]->(c:Computer)
# RETURN g, COUNT(DISTINCT c) AS num_computers
# HAVING num_computers = 1
# ```
# This query will return any Group node that has only one relationship with a Computer node with the ADMIN_TO edge type and no roles, indicating a potential violation of this rule.
#
# **Rule 3: A Group node can be connected to a Domain node with various edge types (WRITE_OWNER, WRITE_DACL, DC_SYNC, GET_CHANGES, GET_CHANGES_ALL) and 'isacl' role.**
#
# Description: This rule states that a Group node can have relationships with a Domain node, each with a different edge type (WRITE_OWNER, WRITE_DACL, DC_SYNC, GET_CHANGES, GET_CHANGES_ALL) and the 'isacl' role.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e:WRITE_OWNER|WRITE_DACL|DC_SYNC|GET_CHANGES|GET_CHANGES_ALL {roles: {'isacl': true}}]->(d:Domain)
# RETURN g, COUNT(DISTINCT e) AS num_edges
# HAVING num_edges < 5
# ```
# This query will return any Group node that has fewer than 5 relationships with a Domain node, each with a different edge type and the 'isacl' role, indicating a potential violation of this rule.
#
# These rules and queries can help ensure the accuracy and coherence of the graph data by identifying potential inconsistencies and violations of the expected schema.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the `Group` node:
#
# **Consistency Rule 1: A `Group` node is connected to multiple `Computer` nodes with an `ADMIN_TO` edge.**
#
# Description: Each `Group` node is connected to multiple `Computer` nodes, indicating that the group has administrative access to these computers.
#
# Cypher Query:
# ```cypher
# MATCH (g:Group) -[:ADMIN_TO] -> (c:Computer)
# RETURN g, COUNT(c) AS num_computers
# ```
# This query returns each `Group` node and the number of `Computer` nodes it is connected to.
#
# **Consistency Rule 2: All edges between a `Group` node and a `Computer` node have the same edge type (`ADMIN_TO`) and empty `roles` property.**
#
# Description: The edges between `Group` and `Computer` nodes always have the same type (`ADMIN_TO`) and an empty `roles` property, indicating that the group has a standard administrative role on these computers.
#
# Cypher Query:
# ```cypher
# MATCH (g:Group) -[r:ADMIN_TO] -> (c:Computer)
# WHERE NOT r.roles = {}
# RETURN COUNT(r) AS num_edges
# ```
# This query returns the number of edges between `Group` and `Computer` nodes that do not have an empty `roles` property, which should be 0 in a consistent dataset.
#
# **Consistency Rule 3: There is only one `Group` node with ID 0.**
#
# Description: There is only one `Group` node with the ID 0, which is the central node in the graph.
#
# Cypher Query:
# ```cypher
# MATCH (g:Group {id: 0})
# RETURN COUNT(g) AS num_groups
# ```
# This query returns the number of `Group` nodes with ID 0, which should be 1 in a consistent dataset.
#
# These consistency rules can be used to validate the graph data and ensure that it follows the expected schema.
# Based on the provided data, I've identified some patterns and consistency rules related to the Node Group. Here are the rules and corresponding Cypher queries to check for violations:
#
# **Rule 1: A Group node can only be connected to Computer nodes**
#
# * Description: A Group node should only have edges to Computer nodes, and not to any other type of node.
# * Cypher query: `MATCH (g:Group)-[r]->(n) WHERE NOT labels(n) CONTAINS 'Computer' RETURN g, r, n`
#
# **Rule 2: All edges from a Group node to a Computer node must have the ADMIN_TO type**
#
# * Description: All edges from a Group node to a Computer node should have the ADMIN_TO type, and not any other type.
# * Cypher query: `MATCH (g:Group)-[r:ADMIN_TO]->(c:Computer) RETURN COUNT(r) AS admin_to_edges MATCH (g:Group)-[r]->(c:Computer) WHERE NOT type(r) = 'ADMIN_TO' RETURN COUNT(r) AS non_admin_to_edges`
#
# **Rule 3: A Group node can have multiple edges to the same Computer node**
#
# * Description: A Group node can have multiple edges to the same Computer node, indicating multiple administrative roles.
# * Cypher query: `MATCH (g:Group)-[r:ADMIN_TO]->(c:Computer) RETURN g, c, COUNT(r) AS num_edges WHERE num_edges > 1`
#
# **Rule 4: A Computer node can have multiple edges from different Group nodes**
#
# * Description: A Computer node can have multiple edges from different Group nodes, indicating multiple administrative roles from different groups.
# * Cypher query: `MATCH (g1:Group)-[r1:ADMIN_TO]->(c:Computer) MATCH (g2:Group)-[r2:ADMIN_TO]->(c) WHERE g1 <> g2 RETURN c, COUNT(DISTINCT g1) AS num_groups`
#
# These rules and queries can help ensure the consistency and accuracy of the graph data related to Node Group.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `Group` node. Here are the rules I've inferred, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: A Group node can have multiple ADMIN_TO edges to Computer nodes.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:ADMIN_TO]-(c:Computer)
# WITH g, COUNT(DISTINCT c) AS num_computers
# WHERE num_computers = 1
# RETURN g, num_computers
# ```
# This query checks if a Group node has only one ADMIN_TO edge to a Computer node. If so, it returns the Group node and the number of unique Computer nodes it's connected to. A non-empty result set indicates a violation of this rule.
#
# **Rule 2: A Group node can have multiple MEMBER_OF edges to User nodes.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:MEMBER_OF]-(u:User)
# WITH g, COUNT(DISTINCT u) AS num_users
# WHERE num_users = 1
# RETURN g, num_users
# ```
# This query checks if a Group node has only one MEMBER_OF edge to a User node. If so, it returns the Group node and the number of unique User nodes it's connected to. A non-empty result set indicates a violation of this rule.
#
# **Rule 3: A Group node can have either ADMIN_TO edges to Computer nodes or MEMBER_OF edges to User nodes, but not both.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:ADMIN_TO]-(c:Computer)
# MATCH (g)-[:MEMBER_OF]-(u:User)
# RETURN g
# ```
# This query checks if a Group node has both ADMIN_TO edges to Computer nodes and MEMBER_OF edges to User nodes. A non-empty result set indicates a violation of this rule.
#
# **Rule 4: A Group node can have multiple MEMBER_OF edges to Computer nodes, but only with the MEMBER_OF relationship type.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[r:ADMIN_TO]-(c:Computer)
# WHERE r.type = 'MEMBER_OF'
# RETURN g, r
# ```
# This query checks if a Group node has an ADMIN_TO edge to a Computer node with a MEMBER_OF relationship type. A non-empty result set indicates a violation of this rule.
#
# These rules and queries can help identify inconsistencies in the graph data related to the Group node.
# After analyzing the provided data, I've identified some patterns and consistency rules related to Node Group. Here are the rules and corresponding Cypher queries to check for violations:
#
# **Rule 1: A Group node is connected to multiple Computer nodes with an edge type of MEMBER_OF.**
#
# Cypher query:
# ```cypher
# MATCH (g:Group)-[:MEMBER_OF]-(c:Computer)
# RETURN g, COUNT(DISTINCT c) AS num_computers
# ```
# This query checks if a Group node is connected to multiple Computer nodes with an edge type of MEMBER_OF. The `COUNT(DISTINCT c)` function returns the number of unique Computer nodes connected to each Group node.
#
# **Rule 2: A Group node has only one edge type of MEMBER_OF connecting it to a Computer node.**
#
# Cypher query:
# ```cypher
# MATCH (g:Group)-[r:MEMBER_OF]-(c:Computer)
# RETURN g, COUNT(DISTINCT r) AS num_edges
# ```
# This query checks if a Group node has only one edge type of MEMBER_OF connecting it to a Computer node. The `COUNT(DISTINCT r)` function returns the number of unique edges between each Group node and Computer node.
#
# **Rule 3: The roles property in the MEMBER_OF edge is always an empty map.**
#
# Cypher query:
# ```cypher
# MATCH (g:Group)-[r:MEMBER_OF {roles: {}}]-(c:Computer)
# RETURN g, r
# ```
# This query checks if the roles property in the MEMBER_OF edge is always an empty map. The `{roles: {}}` pattern in the MATCH clause filters out edges with non-empty roles maps.
#
# **Rule 4: A Computer node is connected to only one Group node with an edge type of MEMBER_OF.**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer)-[:MEMBER_OF]-(g:Group)
# RETURN c, COUNT(DISTINCT g) AS num_groups
# ```
# This query checks if a Computer node is connected to only one Group node with an edge type of MEMBER_OF. The `COUNT(DISTINCT g)` function returns the number of unique Group nodes connected to each Computer node.
#
# These rules and queries can help ensure the consistency of the graph data by identifying any deviations from the expected schema.
# Based on the provided data, I've identified the following patterns and consistency rules related to the `Group` node:
#
# **Rule 1: A Group node is connected to multiple Computer nodes with an edge of type MEMBER_OF**
#
# Description: A Group node can be connected to multiple Computer nodes, and each connection is represented by an edge of type MEMBER_OF.
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT EXISTS((g)-[:MEMBER_OF]-(c:Computer)) RETURN g
# ```
# This query will return any Group nodes that do not have at least one edge of type MEMBER_OF connecting them to a Computer node.
#
# **Rule 2: The MEMBER_OF edge does not carry any roles**
#
# Description: The MEMBER_OF edge between a Group node and a Computer node does not have any roles associated with it.
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group)-[e:MEMBER_OF]->(c:Computer) WHERE e.roles IS NOT NULL RETURN e
# ```
# This query will return any MEMBER_OF edges that have roles associated with them, indicating a violation of this rule.
#
# **Rule 3: The MEMBER_OF edge is directional (from Group to Computer)**
#
# Description: The MEMBER_OF edge always points from a Group node to a Computer node, never the other way around.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer)-[e:MEMBER_OF]->(g:Group) RETURN e
# ```
# This query will return any MEMBER_OF edges that point from a Computer node to a Group node, indicating a violation of this rule.
#
# These rules ensure that the graph data adheres to a consistent structure, where Group nodes are connected to multiple Computer nodes via MEMBER_OF edges, and these edges do not carry any roles and are directional.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the Node Group:
#
# **Consistency Rule 1: A Group node can have multiple MEMBER_OF edges to Computer or User nodes**
#
# Description: A Group node can be connected to multiple Computer or User nodes via MEMBER_OF edges.
#
# Cypher Query to check for violations:
# ```
# MATCH (g:Group)-[:MEMBER_OF]-(c)
# WHERE g MEMBER_OF.size() < 2
# RETURN g, c
# ```
# This query checks if a Group node has less than 2 MEMBER_OF edges. If any results are returned, it means there's a violation of this rule.
#
# **Consistency Rule 2: A Group node has a unique name and domain combination**
#
# Description: Each Group node should have a unique combination of name and domain properties.
#
# Cypher Query to check for violations:
# ```
# MATCH (g1:Group {name: g2.name, domain: g2.domain})
# WHERE g1.neo4jImportId <> g2.neo4jImportId
# RETURN g1, g2
# ```
# This query checks for duplicate name and domain combinations across different Group nodes. If any results are returned, it means there's a violation of this rule.
#
# **Consistency Rule 3: A Computer or User node can be part of only one Group**
#
# Description: Each Computer or User node should be connected to only one Group node via a MEMBER_OF edge.
#
# Cypher Query to check for violations:
# ```
# MATCH (c)-[:MEMBER_OF]-(g1), (c)-[:MEMBER_OF]-(g2)
# WHERE g1.neo4jImportId <> g2.neo4jImportId
# RETURN c, g1, g2
# ```
# This query checks for Computer or User nodes connected to multiple Group nodes via MEMBER_OF edges. If any results are returned, it means there's a violation of this rule.
#
# These consistency rules and Cypher queries can help ensure the accuracy and coherence of the graph data.
# After analyzing the data, I've identified the following patterns and consistency rules related to the Node Group:
#
# **Rule 1: A Group node is connected to multiple User nodes with an edge type of MEMBER_OF.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[r:MEMBER_OF]->(u:User)
# RETURN g, r, u
# ```
# This query should return all Group nodes connected to User nodes with an edge type of MEMBER_OF.
#
# **Rule 2: The roles property of the MEMBER_OF edge is empty (i.e., {})**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[r:MEMBER_OF]->(u:User)
# WHERE r.roles <> {}
# RETURN g, r, u
# ```
# This query should return any MEMBER_OF edges with non-empty roles properties.
#
# **Rule 3: A Group node can have multiple MEMBER_OF edges to different User nodes, but each User node is only connected to one Group node with an edge type of MEMBER_OF.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)-[:MEMBER_OF]->(g1:Group)
# MATCH (u:User)-[:MEMBER_OF]->(g2:Group)
# WHERE g1 <> g2
# RETURN u, g1, g2
# ```
# This query should return any User nodes connected to more than one Group node with an edge type of MEMBER_OF.
#
# These consistency rules ensure that the graph data adheres to the expected schema, where a Group node can have multiple members, each member is a User node, and each User node belongs to only one Group node.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `Group` node:
#
# **Consistency Rule 1:**
# A `Group` node can have multiple `User` nodes connected to it via the `MEMBER_OF` edge.
#
# **Cypher Query:**
# ```cypher
# MATCH (g:Group)-[:MEMBER_OF]-(u:User)
# RETURN g, COUNT(u) AS user_count
# ```
# This query returns all `Group` nodes with the count of connected `User` nodes. Violations of this rule would be `Group` nodes with no connected `User` nodes or multiple edges to the same `User` node.
#
# **Consistency Rule 2:**
# The `roles` property of the `MEMBER_OF` edge is always an empty object `{}`.
#
# **Cypher Query:**
# ```cypher
# MATCH ()-[e:MEMBER_OF]->()
# WHERE e.roles <> {}
# RETURN e
# ```
# This query returns all `MEMBER_OF` edges with non-empty `roles` properties. Violations of this rule would be edges with non-empty `roles` objects.
#
# **Consistency Rule 3:**
# All `MEMBER_OF` edges connect a `Group` node to a `User` node.
#
# **Cypher Query:**
# ```cypher
# MATCH ()-[e:MEMBER_OF]->()
# WHERE NOT (e.startNode():Group AND e.endNode():User)
# RETURN e
# ```
# This query returns all `MEMBER_OF` edges that do not connect a `Group` node to a `User` node. Violations of this rule would be edges connecting nodes of different types.
#
# **Consistency Rule 4:**
# There are no duplicate edges between a `Group` node and a `User` node.
#
# **Cypher Query:**
# ```cypher
# MATCH (g:Group)-[e1:MEMBER_OF]->(u:User)
# MATCH (g:Group)-[e2:MEMBER_OF]->(u:User)
# WHERE e1 <> e2
# RETURN e1, e2
# ```
# This query returns all duplicate `MEMBER_OF` edges between a `Group` node and a `User` node. Violations of this rule would be duplicate edges between the same nodes.
#
# These consistency rules can help ensure the accuracy and coherence of the graph data. By running these Cypher queries, you can identify and fix any inconsistencies in the data.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the `Group` node. Here are the rules I've identified, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1:** A `Group` node should have at least one `MEMBER_OF` edge to a `User` node.
#
# **Cypher query:**
# ```cypher
# MATCH (g:Group) WHERE NOT EXISTS((g)-[:MEMBER_OF]->(u:User)) RETURN g
# ```
# This query checks for `Group` nodes that do not have any `MEMBER_OF` edges to `User` nodes.
#
# **Rule 2:** A `Group` node should not have multiple `MEMBER_OF` edges to the same `User` node.
#
# **Cypher query:**
# ```cypher
# MATCH (g:Group)-[r1:MEMBER_OF]->(u:User) WHERE EXISTS((g)-[r2:MEMBER_OF]->(u)) AND r1 <> r2 RETURN g, u
# ```
# This query checks for `Group` nodes that have multiple `MEMBER_OF` edges to the same `User` node.
#
# **Rule 3:** A `Group` node should have a unique `name` property.
#
# **Cypher query:**
# ```cypher
# MATCH (g1:Group {name: g2.name}) WHERE g1 <> g2 RETURN g1, g2
# ```
# This query checks for duplicate `name` properties among `Group` nodes.
#
# **Rule 4:** A `Group` node should have an `objectid` property that follows a specific format (e.g., S-1-5-21-...).
#
# **Cypher query:**
# ```cypher
# MATCH (g:Group) WHERE NOT g.objectid STARTS WITH 'S-1-5-21-' RETURN g
# ```
# This query checks for `Group` nodes with an `objectid` property that does not follow the expected format.
#
# **Rule 5:** A `Group` node should have a `domain` property that matches a specific domain pattern (e.g., TestCompany.Local).
#
# **Cypher query:**
# ```cypher
# MATCH (g:Group) WHERE NOT g.domain ENDS WITH '.Local' RETURN g
# ```
# This query checks for `Group` nodes with a `domain` property that does not match the expected pattern.
#
# By running these Cypher queries, you can identify potential inconsistencies in the graph data related to the `Group` node.
# After analyzing the provided data, I've identified several patterns and consistency rules related to the `Group` node:
#
# **Rule 1: Each Group node has a unique `neo4jImportId`**
#
# * Description: Each Group node has a unique `neo4jImportId` property.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE g.neo4jImportId IS NOT UNIQUE RETURN g
# ```
#
# **Rule 2: Each Group node has a `domain` property with a specific format**
#
# * Description: Each Group node has a `domain` property with a format of `<company_name>.Local`, where `<company_name>` is a variable string.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.domain =~ '^.+\\.Local$' RETURN g
# ```
#
# **Rule 3: Each Group node has a `name` property with a specific format**
#
# * Description: Each Group node has a `name` property with a format of `<group_name>@<company_name>.Local`, where `<group_name>` is a variable string and `<company_name>` matches the `domain` property.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.name =~ '^.+@' + g.domain RETURN g
# ```
#
# **Rule 4: Each Group node has an `objectid` property**
#
# * Description: Each Group node has an `objectid` property with a format of `S-1-5-21-<uuid>-<number>`.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.objectid =~ '^S-1-5-21-[^-]+-\\d+$' RETURN g
# ```
#
# **Rule 5: Groups with `highvalue` property have specific edge relationships**
#
# * Description: Groups with the `highvalue` property have edges with the `GET_CHANGES`, `GET_CHANGES_ALL`, `DC_SYNC`, `WRITE_DACL`, `WRITE_OWNER`, and `OWNS` roles.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group {highvalue: true})-[:GET_CHANGES|GET_CHANGES_ALL|DC_SYNC|WRITE_DACL|WRITE_OWNER|OWNS]-(d) RETURN g
# ```
#
# **Rule 6: Groups without `highvalue` property have `GENERIC_ALL` edge relationships**
#
# * Description: Groups without the `highvalue` property have edges with the `GENERIC_ALL` role.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group {highvalue: null})-[:GENERIC_ALL]-(d) RETURN g
# ```
#
# **Rule 7: Groups can have `MEMBER_OF` edge relationships with User nodes**
#
# * Description: Groups can have `MEMBER_OF` edge relationships with User nodes.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group)-[:MEMBER_OF]-(u:User) RETURN g, u
# ```
#
# These rules can help ensure the consistency and accuracy of the graph data related to the `Group` node.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the Node Group:
#
# **Consistency Rule 1: Each Group node has a unique neo4jImportId**
#
# * Description: Each Group node should have a unique neo4jImportId property.
# * Cypher Query: `MATCH (g:Group) WITH g.neo4jImportId as id, COUNT(g) as count WHERE count > 1 RETURN id, count`
#
# **Consistency Rule 2: Each Group node has a domain property**
#
# * Description: Each Group node should have a domain property.
# * Cypher Query: `MATCH (g:Group) WHERE NOT EXISTS(g.domain) RETURN g`
#
# **Consistency Rule 3: Each Group node has a name property**
#
# * Description: Each Group node should have a name property.
# * Cypher Query: `MATCH (g:Group) WHERE NOT EXISTS(g.name) RETURN g`
#
# **Consistency Rule 4: Each Group node has an objectid property**
#
# * Description: Each Group node should have an objectid property.
# * Cypher Query: `MATCH (g:Group) WHERE NOT EXISTS(g.objectid) RETURN g`
#
# **Consistency Rule 5: Each Group node is connected to a node with GENERIC_ALL edge**
#
# * Description: Each Group node should be connected to a node with a GENERIC_ALL edge.
# * Cypher Query: `MATCH (g:Group) WHERE NOT EXISTS((g)-[:GENERIC_ALL]-(otherNode)) RETURN g`
#
# **Consistency Rule 6: Each Group node can have multiple MEMBER_OF edges to User nodes**
#
# * Description: Each Group node can have multiple MEMBER_OF edges to User nodes.
# * Cypher Query: `MATCH (g:Group)-[:MEMBER_OF]-(u:User) RETURN g, COUNT(u) as count GROUP BY g ORDER BY count DESC`
#
# **Consistency Rule 7: Each Group node can have multiple edges to Computer nodes**
#
# * Description: Each Group node can have multiple edges to Computer nodes with EXECUTE_DCOM, CAN_RDP, or ADMIN_TO relationships.
# * Cypher Query: `MATCH (g:Group)-[r:EXECUTE_DCOM|CAN_RDP|ADMIN_TO]-(c:Computer) RETURN g, COUNT(c) as count GROUP BY g ORDER BY count DESC`
#
# These consistency rules can help ensure the data accuracy and coherence in the graph database. By running the provided Cypher queries, you can identify any inconsistencies or anomalies in the data.
# Based on the provided data, I've identified some patterns and consistency rules related to the `Group` node. Here are the rules I've found, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every Group node is connected to node [Group] 0 with edge GENERIC_ALL**
#
# Description: Each Group node should have a GENERIC_ALL edge to node [Group] 0.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE NOT (g)-[:GENERIC_ALL]->(zero:Group {neo4jImportId: 0}) RETURN g;
# ```
# **Rule 2: Every Group node has a unique name and objectid**
#
# Description: Each Group node should have a unique `name` and `objectid` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g1:Group), (g2:Group) WHERE g1.name = g2.name AND g1.objectid = g2.objectid AND g1.neo4jImportId <> g2.neo4jImportId RETURN g1, g2;
# ```
# **Rule 3: Every Group node has a domain property set to "TestCompany.Local"**
#
# Description: Each Group node should have its `domain` property set to "TestCompany.Local".
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE g.domain <> "TestCompany.Local" RETURN g;
# ```
# **Rule 4: MEMBER_OF edges only connect Group nodes to User nodes**
#
# Description: MEMBER_OF edges should only connect Group nodes to User nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH ()-[r:MEMBER_OF]->() WHERE NOT (r)-[:MEMBER_OF]->(:User) RETURN r;
# ```
# **Rule 5: GENERIC_ALL edges only connect Group nodes to other Group nodes**
#
# Description: GENERIC_ALL edges should only connect Group nodes to other Group nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH ()-[r:GENERIC_ALL]->() WHERE NOT (r)-[:GENERIC_ALL]->(:Group) RETURN r;
# ```
# These consistency rules can help ensure the accuracy and coherence of the graph data. By running these Cypher queries, you can identify any violations of these rules and take corrective action to maintain the integrity of the graph.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the `Group` node. Here are the rules I've identified, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every Group node has a GENERIC_ALL edge to node [Group] 0**
#
# Consistency Rule: Every Group node should have a GENERIC_ALL edge to node [Group] 0.
#
# Cypher Query: `MATCH (g:Group) WHERE NOT exists((g)-[:GENERIC_ALL]->(:Group {neo4jImportId: 0})) RETURN g`
#
# **Rule 2: A Group node can have multiple MEMBER_OF edges to User nodes**
#
# Consistency Rule: A Group node can have multiple MEMBER_OF edges to User nodes.
#
# Cypher Query: `MATCH (g:Group)-[:MEMBER_OF]->(u:User) RETURN g, u`
#
# **Rule 3: A Group node can have multiple MEMBER_OF edges to other Group nodes**
#
# Consistency Rule: A Group node can have multiple MEMBER_OF edges to other Group nodes.
#
# Cypher Query: `MATCH (g:Group)-[:MEMBER_OF]->(h:Group) RETURN g, h`
#
# **Rule 4: Every Group node has a domain property with a specific format**
#
# Consistency Rule: Every Group node should have a domain property with the format "[domain name].Local".
#
# Cypher Query: `MATCH (g:Group) WHERE NOT g.domain =~ regex('.*.Local') RETURN g`
#
# **Rule 5: Every Group node has a name property with a specific format**
#
# Consistency Rule: Every Group node should have a name property with the format "[name]@[domain name].Local".
#
# Cypher Query: `MATCH (g:Group) WHERE NOT g.name =~ regex('.*@.*.Local') RETURN g`
#
# **Rule 6: Every Group node has an objectid property with a specific format**
#
# Consistency Rule: Every Group node should have an objectid property with the format "S-1-5-21-[numbers]-[numbers]-[numbers]-[numbers]".
#
# Cypher Query: `MATCH (g:Group) WHERE NOT g.objectid =~ regex('S-1-5-21-[0-9]+-[0-9]+-[0-9]+-[0-9]+') RETURN g`
#
# These rules and queries can help ensure the consistency and accuracy of the graph data related to the `Group` node.
# Based on the provided data, I've identified some patterns and consistency rules related to Node Group:
#
# **Rule 1: Every Group node has a unique neo4jImportId**
#
# * Description: Each Group node should have a unique neo4jImportId property.
# * Cypher query to check for violations: `MATCH (g:Group) WHERE g.neo4jImportId IS NOT UNIQUE RETURN g`
#
# **Rule 2: Every Group node has a domain property**
#
# * Description: Each Group node should have a domain property.
# * Cypher query to check for violations: `MATCH (g:Group) WHERE g.domain IS NULL RETURN g`
#
# **Rule 3: Every Group node has a name property**
#
# * Description: Each Group node should have a name property.
# * Cypher query to check for violations: `MATCH (g:Group) WHERE g.name IS NULL RETURN g`
#
# **Rule 4: Every Group node has an objectid property**
#
# * Description: Each Group node should have an objectid property.
# * Cypher query to check for violations: `MATCH (g:Group) WHERE g.objectid IS NULL RETURN g`
#
# **Rule 5: Every Group node is connected to a Group node with id 0 via a GENERIC_ALL edge**
#
# * Description: Each Group node should be connected to a Group node with id 0 via a GENERIC_ALL edge.
# * Cypher query to check for violations: `MATCH (g:Group) WHERE NOT (g)-[:GENERIC_ALL]->(zero:Group {neo4jImportId: 0}) RETURN g`
#
# **Rule 6: A Group node can be connected to multiple User nodes via MEMBER_OF edges**
#
# * Description: A Group node can be connected to multiple User nodes via MEMBER_OF edges.
# * Cypher query to check for violations: None, as this rule is a pattern and not a constraint.
#
# **Rule 7: A Group node can be connected to multiple Computer nodes via ADMIN_TO edges**
#
# * Description: A Group node can be connected to multiple Computer nodes via ADMIN_TO edges.
# * Cypher query to check for violations: None, as this rule is a pattern and not a constraint.
#
# Note that these rules are based on the provided data and may not be exhaustive. Additional rules may be identified with more data or domain-specific knowledge.
# Based on the provided data, I've identified some patterns and inferred consistency rules related to the node Group. Here are the rules and their corresponding Cypher queries to check for violations:
#
# ...
#
# **Rule 1: All Groups have a connection to Node 0 with edge GENERIC_ALL**
#
# * Description: Every Group node is connected to Node 0 with an edge of type GENERIC_ALL.
# * Cypher query: `MATCH (g:Group) WHERE NOT (g)-[:GENERIC_ALL]->(:Group {neo4jImportId: 0}) RETURN g`
#
# **Rule 2: Groups have a unique name and objectid**
#
# * Description: Each Group node has a unique name and objectid.
# * Cypher query: `MATCH (g1:Group), (g2:Group) WHERE g1.name = g2.name AND g1.objectid = g2.objectid AND g1 <> g2 RETURN g1, g2`
#
# **Rule 3: Groups are connected to Users with edge MEMBER_OF**
#
# * Description: Groups are connected to Users with an edge of type MEMBER_OF.
# * Cypher query: `MATCH (g:Group) WHERE NOT (g)-[:MEMBER_OF]->(:User) RETURN g`
#
# **Rule 4: Groups are connected to Computers with edges EXECUTE_DCOM, CAN_RDP, or ADMIN_TO**
#
# * Description: Some Groups are connected to Computers with edges of types EXECUTE_DCOM, CAN_RDP, or ADMIN_TO.
# * Cypher query: `MATCH (g:Group) WHERE NOT (g)-[:EXECUTE_DCOM|:CAN_RDP|:ADMIN_TO]->(:Computer) RETURN g`
#
# **Rule 5: Groups can be members of other Groups**
#
# * Description: Some Groups are members of other Groups.
# * Cypher query: `MATCH (g1:Group)-[:MEMBER_OF]->(g2:Group) RETURN g1, g2`
#
# These rules can be used to validate the consistency of the graph data and identify potential errors or inconsistencies.
# After analyzing the provided data, I've identified several patterns and consistency rules related to the `Group` node. Here are the rules I've found, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: Every Group node is connected to Group node 0 with an GENERIC_ALL edge**
# ```
# Cypher query: MATCH (g:Group) WHERE NOT (g)-[:GENERIC_ALL]->(g0:Group {id: 0}) RETURN g
# ```
# This rule checks that every `Group` node is connected to the `Group` node with id 0 (which seems to be a root or parent node) with an `GENERIC_ALL` edge.
#
# **Rule 2: Every Group node has a domain property with value 'TestCompany.Local'**
# ```
# Cypher query: MATCH (g:Group) WHERE g.domain <> 'TestCompany.Local' RETURN g
# ```
# This rule checks that every `Group` node has a `domain` property with value `'TestCompany.Local'`.
#
# **Rule 3: Every Group node has a name property with a specific format**
# ```
# Cypher query: MATCH (g:Group) WHERE NOT g.name =~ /.*@TestCompany.Local/ RETURN g
# ```
# This rule checks that every `Group` node has a `name` property with a specific format, which seems to be `<something>@TestCompany.Local`.
#
# **Rule 4: Every Group node has an objectid property with a specific format**
# ```
# Cypher query: MATCH (g:Group) WHERE NOT g.objectid =~ /S-1-5-21-.*/ RETURN g
# ```
# This rule checks that every `Group` node has an `objectid` property with a specific format, which seems to be `S-1-5-21-<something>`.
#
# **Rule 5: A Group node can have multiple MEMBER_OF edges to User nodes**
# ```
# Cypher query: MATCH (g:Group)-[:MEMBER_OF]->(u:User) WHERE NOT (g)-[:MEMBER_OF]->() RETURN g
# ```
# This rule checks that a `Group` node can have multiple `MEMBER_OF` edges to `User` nodes.
#
# **Rule 6: A Group node can have a MEMBER_OF edge to another Group node**
# ```
# Cypher query: MATCH (g:Group)-[:MEMBER_OF]->(g2:Group) RETURN g
# ```
# This rule checks that a `Group` node can have a `MEMBER_OF` edge to another `Group` node.
#
# Note that these rules are based on the provided data and may not be exhaustive. Additional rules may be identified by analyzing more data or understanding the specific requirements of the graph schema.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the Node Group. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: A Group node is connected to a single node with a GENERIC_ALL edge**
#
# * Description: Each Group node is connected to a single node ( likely a root node or a special group) with a GENERIC_ALL edge.
# * Cypher query: `MATCH (g:Group) WITH g, COUNT(DISTINCT g)-[:GENERIC_ALL]-(n) AS count WHERE count > 1 RETURN g`
#
# **Rule 2: A Group node has a unique name within its domain**
#
# * Description: Each Group node has a unique name within its domain.
# * Cypher query: `MATCH (g1:Group {domain: 'TestCompany.Local'}), (g2:Group {domain: 'TestCompany.Local'}) WHERE g1.name = g2.name AND g1.neo4jImportId <> g2.neo4jImportId RETURN g1, g2`
#
# **Rule 3: A Group node has a unique objectid within its domain**
#
# * Description: Each Group node has a unique objectid within its domain.
# * Cypher query: `MATCH (g1:Group {domain: 'TestCompany.Local'}), (g2:Group {domain: 'TestCompany.Local'}) WHERE g1.objectid = g2.objectid AND g1.neo4jImportId <> g2.neo4jImportId RETURN g1, g2`
#
# **Rule 4: A Group node is connected to at least one User node with a MEMBER_OF edge**
#
# * Description: Each Group node is connected to at least one User node with a MEMBER_OF edge.
# * Cypher query: `MATCH (g:Group) WHERE NOT (g)-[:MEMBER_OF]-(u:User) RETURN g`
#
# **Rule 5: A Group node can be connected to multiple User nodes with MEMBER_OF edges**
#
# * Description: A Group node can be connected to multiple User nodes with MEMBER_OF edges.
# * Cypher query: `MATCH (g:Group) WITH g, COUNT(DISTINCT (g)-[:MEMBER_OF]-(u:User)) AS count WHERE count = 1 RETURN g` (This query will return Groups with only one MEMBER_OF edge, which might be an anomaly)
#
# **Rule 6: Some Group nodes are connected to Computer nodes with EXECUTE_DCOM, CAN_RDP, or ADMIN_TO edges**
#
# * Description: Some Group nodes are connected to Computer nodes with EXECUTE_DCOM, CAN_RDP, or ADMIN_TO edges.
# * Cypher query: `MATCH (g:Group)-[:EXECUTE_DCOM|CAN_RDP|ADMIN_TO]-(c:Computer) RETURN g, c` (This query will return all Group-Computer relationships with the specified edge types)
#
# These rules and Cypher queries can help you identify inconsistencies in your graph data and ensure that the schema is followed correctly.
# After analyzing the data, I've identified the following patterns and inferred consistency rules related to the `Group` node:
#
# **Rule 1: A Group node can be connected to multiple User nodes with the MEMBER_OF edge.**
#
# Description: A Group node can have multiple MEMBER_OF edges connecting it to different User nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:MEMBER_OF]-(u:User)
# RETURN g, COUNT(DISTINCT u) AS num_users
# WHERE num_users = 1  // Should be > 1
# ```
# **Rule 2: A Group node can be connected to multiple Computer nodes with the ADMIN_TO edge.**
#
# Description: A Group node can have multiple ADMIN_TO edges connecting it to different Computer nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[:ADMIN_TO]-(c:Computer)
# RETURN g, COUNT(DISTINCT c) AS num_computers
# WHERE num_computers = 1  // Should be > 1
# ```
# **Rule 3: A Group node can have multiple edges of the same type (MEMBER_OF or ADMIN_TO) to different nodes.**
#
# Description: A Group node can have multiple edges of the same type connecting it to different nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(n)
# WITH g, e, COUNT(DISTINCT n) AS num_edges
# WHERE num_edges = 1  // Should be > 1
# RETURN g, e, num_edges
# ```
# **Rule 4: A Group node can only have edges of type MEMBER_OF or ADMIN_TO.**
#
# Description: A Group node should only have edges of type MEMBER_OF or ADMIN_TO, and no other types of edges.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group)-[e]-(n)
# WHERE NOT (e.type IN ['MEMBER_OF', 'ADMIN_TO'])
# RETURN g, e, n
# ```
# These consistency rules ensure that the graph data is accurate and coherent, and can help identify potential errors or inconsistencies in the data.
# Based on the provided data, the following patterns and consistency rules related to the Node Group can be identified:
#
# **Pattern 1:** A Group node is connected to multiple Computer nodes with an ADMIN_TO edge.
#
# **Consistency Rule 1:** A Group node should have at least one ADMIN_TO edge to a Computer node.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE NOT (g)-[:ADMIN_TO]->() RETURN g
# ```
# **Pattern 2:** All edges between Group and Computer nodes have an empty roles property.
#
# **Consistency Rule 2:** All ADMIN_TO edges between Group and Computer nodes should have an empty roles property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH ()-[r:ADMIN_TO {roles: {}}]->() RETURN r
# ```
# **Pattern 3:** Multiple Computer nodes are connected to the same Group node with an ADMIN_TO edge.
#
# **Consistency Rule 3:** A Group node can have multiple ADMIN_TO edges to different Computer nodes.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (g:Group) WHERE (g)-[:ADMIN_TO]->(c1:Computer) AND (g)-[:ADMIN_TO]->(c2:Computer) AND c1 <> c2 RETURN g, c1, c2
# ```
# **Pattern 4:** The data does not contain any other types of nodes or edges besides Group, Computer, and ADMIN_TO.
#
# **Consistency Rule 4:** The graph should only contain Group and Computer nodes, and only ADMIN_TO edges between them.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (n) WHERE NOT (n:Group OR n:Computer) RETURN n
# ```
# ```cypher
# MATCH ()-[r]->() WHERE NOT r:ADMIN_TO RETURN r
# ```
# These consistency rules and Cypher queries can help ensure the accuracy and coherence of the graph data by detecting any deviations from the expected schema.
# Based on the provided data, I have identified several patterns and consistency rules related to the `Group` node:
#
# **Consistency Rule 1: A Group node should have a unique `neo4jImportId`**
#
# * Description: Each Group node should have a unique `neo4jImportId` property.
# * Cypher query: `MATCH (g:Group) RETURN g.neo4jImportId AS id, COUNT(*) AS count GROUP BY id HAVING count > 1`
#
# **Consistency Rule 2: A Group node should have a `domain` property**
#
# * Description: Each Group node should have a `domain` property.
# * Cypher query: `MATCH (g:Group) WHERE NOT EXISTS(g.domain) RETURN g`
#
# **Consistency Rule 3: A Group node should have a `name` property**
#
# * Description: Each Group node should have a `name` property.
# * Cypher query: `MATCH (g:Group) WHERE NOT EXISTS(g.name) RETURN g`
#
# **Consistency Rule 4: A Group node should have an `objectid` property**
#
# * Description: Each Group node should have an `objectid` property.
# * Cypher query: `MATCH (g:Group) WHERE NOT EXISTS(g.objectid) RETURN g`
#
# **Consistency Rule 5: A Group node should have at most one edge of type `GENERIC_ALL` to another Group node**
#
# * Description: Each Group node should have at most one edge of type `GENERIC_ALL` to another Group node.
# * Cypher query: `MATCH (g:Group)-[:GENERIC_ALL]->(gg:Group) RETURN g, COUNT(*) AS count GROUP BY g HAVING count > 1`
#
# **Consistency Rule 6: A Group node should have at least one edge of type `MEMBER_OF` to a User node**
#
# * Description: Each Group node should have at least one edge of type `MEMBER_OF` to a User node.
# * Cypher query: `MATCH (g:Group) WHERE NOT EXISTS((g)-[:MEMBER_OF]->(:User)) RETURN g`
#
# **Consistency Rule 7: A Group node should have at most one edge of type `ADMIN_TO` to a Computer node**
#
# * Description: Each Group node should have at most one edge of type `ADMIN_TO` to a Computer node.
# * Cypher query: `MATCH (g:Group)-[:ADMIN_TO]->(c:Computer) RETURN g, COUNT(*) AS count GROUP BY g HAVING count > 1`
#
# These consistency rules can be used to check for violations in the dataset and ensure that the graph data is accurate and coherent.
# After analyzing the provided data, I've identified several patterns and consistency rules related to the `Group` node. Here are the rules I've inferred, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Group node has a unique `neo4jImportId`**
#
# Description: Each Group node should have a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```
# MATCH (g1:Group), (g2:Group) WHERE g1.neo4jImportId = g2.neo4jImportId AND g1 <> g2 RETURN g1, g2
# ```
# **Rule 2: Each Group node has a `domain` property set to "TestCompany.Local"`
#
# Description: All Group nodes should have a `domain` property set to "TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE g.domain <> "TestCompany.Local" RETURN g
# ```
# **Rule 3: Each Group node has a `name` property in the format "<short_name>@TestCompany.Local"`
#
# Description: All Group nodes should have a `name` property in the format "<short_name>@TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.name =~ /^([A-Za-z0-9]+)@TestCompany\.Local$/ RETURN g
# ```
# **Rule 4: Each Group node has an `objectid` property in the format "S-1-5-21-...-<number>"**
#
# Description: All Group nodes should have an `objectid` property in the format "S-1-5-21-...-<number>".
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.objectid =~ /^S-1-5-21-([0-9-]+)$/
# ```
# **Rule 5: Each Group node is connected to node 0 with an edge of type GENERIC_ALL**
#
# Description: Each Group node should be connected to node 0 with an edge of type GENERIC_ALL.
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT (g)-[:GENERIC_ALL]->(zero:Group {neo4jImportId: 0}) RETURN g
# ```
# **Rule 6: Each Group node has at least one edge of type MEMBER_OF to a User node**
#
# Description: Each Group node should have at least one edge of type MEMBER_OF to a User node.
#
# Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT ()-[:MEMBER_OF]->(u:User) RETURN g
# ```
# These rules and corresponding Cypher queries can be used to ensure the accuracy, coherence, and consistency of the graph data.
# Based on the provided data, I've identified the following patterns and consistency rules related to the `Group` node:
#
# **Rule 1:** Each `Group` node has a unique `neo4jImportId`.
#
# * Description: Each `Group` node should have a unique `neo4jImportId` property.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WITH g.neo4jImportId AS importId
# GROUP BY importId
# HAVING COUNT(importId) > 1
# RETURN importId AS duplicate_importId
# ```
# **Rule 2:** Each `Group` node has a `domain` property with a consistent value.
#
# * Description: All `Group` nodes should have a `domain` property with the same value, which is `TestCompany.Local` in this case.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE g.domain <> 'TestCompany.Local'
# RETURN g.neo4jImportId AS invalid_domain
# ```
# **Rule 3:** Each `Group` node has a `name` property that follows a consistent naming convention.
#
# * Description: The `name` property of each `Group` node follows a consistent naming convention, e.g., `<GroupName>@TestCompany.Local`.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.name ENDS WITH '@TestCompany.Local'
# RETURN g.neo4jImportId AS invalid_name
# ```
# **Rule 4:** Each `Group` node has an `objectid` property with a consistent format.
#
# * Description: The `objectid` property of each `Group` node has a consistent format, e.g., `S-1-5-21-883232822-274137685-4173207997-<number>`.
# * Cypher query to check for violations:
# ```
# MATCH (g:Group) WHERE NOT g.objectid STARTS WITH 'S-1-5-21-883232822-274137685-4173207997-'
# RETURN g.neo4jImportId AS invalid_objectid
# ```
# **Rule 5:** Each `Group` node is connected to a single `Group` node with an edge `GENERIC_ALL` and a `roles` property with a single key-value pair (`'isacl': True`).
#
# * Description: Each `Group` node should be connected to a single `Group` node with an edge `GENERIC_ALL` and a `roles` property with a single key-value pair (`'isacl': True`).
# * Cypher query to check for violations:
# ```
# MATCH (g:Group)-[r:GENERIC_ALL]->(parent:Group)
# WHERE SIZE(r.roles) <> 1 OR NOT r.roles = {isacl: true}
# RETURN g.neo4jImportId AS invalid_generic_all
# ```
# **Rule 6:** Each `Group` node can have multiple edges `MEMBER_OF` connecting it to multiple `User` nodes.
#
# * Description: Each `Group` node can have multiple edges `MEMBER_OF` connecting it to multiple `User` nodes.
# * Cypher query to check for violations: Not applicable, as this is a valid pattern.
#
# By running these Cypher queries, you can identify any inconsistencies in the data related to the `Group` node.

# %% [markdown]
# ### Computer

# %%
rules_computer = _perform_function(8100, "Computer", "llama3-70b-8192")

# %%
for rule in rules_computer: 
    print(rule)
# Out:
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the node `Computer`. For each rule, I'll provide a clear description and a corresponding Cypher query to check for violations.
#
# **Rule 1: All Computers have a `domain` property**
# Description: Every `Computer` node should have a `domain` property.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS(c.domain) RETURN c
# ```
# **Rule 2: All Computers have a `operatingsystem` property**
# Description: Every `Computer` node should have an `operatingsystem` property.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS(c.operatingsystem) RETURN c
# ```
# **Rule 3: All Computers have a `name` property**
# Description: Every `Computer` node should have a `name` property.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS(c.name) RETURN c
# ```
# **Rule 4: All Computers have an `objectid` property**
# Description: Every `Computer` node should have an `objectid` property.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS(c.objectid) RETURN c
# ```
# **Rule 5: All Computers have an `enabled` property**
# Description: Every `Computer` node should have an `enabled` property.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS(c.enabled) RETURN c
# ```
# **Rule 6: Every Computer is connected to at least one Group with a GENERIC_ALL edge**
# Description: Every `Computer` node should have at least one edge with the type `GENERIC_ALL` to a `Group` node.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:GENERIC_ALL]->(:Group)) RETURN c
# ```
# **Rule 7: Every Computer is connected to at least one Group with an ADMIN_TO edge**
# Description: Every `Computer` node should have at least one edge with the type `ADMIN_TO` to a `Group` node.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:ADMIN_TO]->(:Group)) RETURN c
# ```
# **Rule 8: Every Computer is connected to at least one OU with a CONTAINS edge**
# Description: Every `Computer` node should have at least one edge with the type `CONTAINS` to an `OU` node.
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:CONTAINS]->(:OU)) RETURN c
# ```
# These rules ensure that each `Computer` node has the required properties and is connected to other nodes in a consistent way. You can use these Cypher queries to check for violations of these rules in your graph data.
# After analyzing the data, I've identified the following patterns and consistency rules related to the `Computer` node:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId`**
#
# Description: Each `Computer` node has a unique `neo4jImportId` property.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WITH c.neo4jImportId AS id
# WHERE NOT id IS NULL
# GROUP BY id
# HAVING COUNT(id) > 1
# RETURN "Duplicate neo4jImportId found";
# ```
# **Rule 2: Each Computer node has a `domain` property**
#
# Description: Each `Computer` node has a `domain` property with a value.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WHERE c.domain IS NULL
# RETURN "Computer node without domain";
# ```
# **Rule 3: Each Computer node has an `operatingsystem` property**
#
# Description: Each `Computer` node has an `operatingsystem` property with a value.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WHERE c.operatingsystem IS NULL
# RETURN "Computer node without operatingsystem";
# ```
# **Rule 4: Each Computer node has a `name` property in the format `<name>.<domain>`**
#
# Description: Each `Computer` node has a `name` property in the format `<name>.<domain>`.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.name =~ /.*\..*/
# RETURN "Computer node with invalid name format";
# ```
# **Rule 5: Each Computer node has an `objectid` property**
#
# Description: Each `Computer` node has an `objectid` property with a value.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WHERE c.objectid IS NULL
# RETURN "Computer node without objectid";
# ```
# **Rule 6: Each Computer node has an `enabled` property with a boolean value**
#
# Description: Each `Computer` node has an `enabled` property with a boolean value.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WHERE c.enabled IS NOT TRUE AND c.enabled IS NOT FALSE
# RETURN "Computer node with invalid enabled value";
# ```
# **Rule 7: Each Computer node has at least one edge to a Group node with an ADMIN_TO or MEMBER_OF relationship**
#
# Description: Each `Computer` node has at least one edge to a `Group` node with an `ADMIN_TO` or `MEMBER_OF` relationship.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:ADMIN_TO|:MEMBER_OF]->(:Group))
# RETURN "Computer node without ADMIN_TO or MEMBER_OF relationship to a Group";
# ```
# **Rule 8: Each Computer node has at most one edge to an OU node with a CONTAINS relationship**
#
# Description: Each `Computer` node has at most one edge to an `OU` node with a `CONTAINS` relationship.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer) WITH c
# MATCH (c)-[:CONTAINS]->(ou:OU)
# WITH c, COUNT(ou) AS count
# WHERE count > 1
# RETURN "Computer node with multiple CONTAINS relationships to OU nodes";
# ```
# These rules ensure that the `Computer` nodes in the graph have consistent properties and relationships.
# Based on the provided data, I have identified the following patterns and consistency rules related to the `Computer` node:
#
# 1. **Every Computer node has a unique `neo4jImportId`**:
# Consistency rule: Each `Computer` node should have a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WITH c ORDER BY c.neo4jImportId ASC RETURN c.neo4jImportId AS importId, COUNT(*) AS count WHERE count > 1
# ```
# This query groups the `Computer` nodes by their `neo4jImportId` and returns the duplicate `neo4jImportId` values.
#
# 2. **Every Computer node has a `domain` property**:
# Consistency rule: Each `Computer` node should have a `domain` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.domain) RETURN c
# ```
# This query returns all `Computer` nodes that do not have a `domain` property.
#
# 3. **Every Computer node has an `operatingsystem` property**:
# Consistency rule: Each `Computer` node should have an `operatingsystem` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.operatingsystem) RETURN c
# ```
# This query returns all `Computer` nodes that do not have an `operatingsystem` property.
#
# 4. **Every Computer node has a `name` property**:
# Consistency rule: Each `Computer` node should have a `name` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.name) RETURN c
# ```
# This query returns all `Computer` nodes that do not have a `name` property.
#
# 5. **Every Computer node has an `objectid` property**:
# Consistency rule: Each `Computer` node should have an `objectid` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.objectid) RETURN c
# ```
# This query returns all `Computer` nodes that do not have an `objectid` property.
#
# 6. **Every Computer node has an `enabled` property**:
# Consistency rule: Each `Computer` node should have an `enabled` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.enabled) RETURN c
# ```
# This query returns all `Computer` nodes that do not have an `enabled` property.
#
# 7. **Every Computer node is connected to a Group node with an ADMIN_TO edge**:
# Consistency rule: Each `Computer` node should be connected to at least one `Group` node with an `ADMIN_TO` edge.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:ADMIN_TO]->()) RETURN c
# ```
# This query returns all `Computer` nodes that are not connected to a `Group` node with an `ADMIN_TO` edge.
#
# 8. **Every Computer node is connected to an OU node with a CONTAINS edge**:
# Consistency rule: Each `Computer` node should be connected to an `OU` node with a `CONTAINS` edge.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:CONTAINS]->()) RETURN c
# ```
# This query returns all `Computer` nodes that are not connected to an `OU` node with a `CONTAINS` edge.
#
# These consistency rules and Cypher queries can be used to ensure the accuracy and coherence of the graph data.
# After analyzing the provided data, I've identified several patterns and inferred consistency rules related to the node `Computer`. Here are the rules, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: A Computer node must have a `domain` property**
#
# Description: Every `Computer` node should have a `domain` property.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.domain) RETURN c
# ```
# This query will return all `Computer` nodes that don't have a `domain` property.
#
# **Rule 2: A Computer node must have an `operatingsystem` property**
#
# Description: Every `Computer` node should have an `operatingsystem` property.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.operatingsystem) RETURN c
# ```
# This query will return all `Computer` nodes that don't have an `operatingsystem` property.
#
# **Rule 3: A Computer node must have a `name` property**
#
# Description: Every `Computer` node should have a `name` property.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.name) RETURN c
# ```
# This query will return all `Computer` nodes that don't have a `name` property.
#
# **Rule 4: A Computer node must have an `objectid` property**
#
# Description: Every `Computer` node should have an `objectid` property.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.objectid) RETURN c
# ```
# This query will return all `Computer` nodes that don't have an `objectid` property.
#
# **Rule 5: A Computer node must be connected to at least one Group node with an ADMIN_TO edge**
#
# Description: Every `Computer` node should have at least one `ADMIN_TO` edge to a `Group` node.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:ADMIN_TO]->(:Group)) RETURN c
# ```
# This query will return all `Computer` nodes that don't have an `ADMIN_TO` edge to a `Group` node.
#
# **Rule 6: A Computer node must be connected to at most one OU node with a CONTAINS edge**
#
# Description: Every `Computer` node should have at most one `CONTAINS` edge to an `OU` node.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer)-[:CONTAINS]->(ou:OU) WHERE size((c)-[:CONTAINS]->(ou)) > 1 RETURN c
# ```
# This query will return all `Computer` nodes that have more than one `CONTAINS` edge to an `OU` node.
#
# **Rule 7: A Computer node must have an `enabled` property with a boolean value**
#
# Description: Every `Computer` node should have an `enabled` property with a boolean value.
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT EXISTS(c.enabled) OR NOT (c.enabled IN [true, false]) RETURN c
# ```
# This query will return all `Computer` nodes that don't have an `enabled` property or have an `enabled` property with a non-boolean value.
#
# These consistency rules and Cypher queries can help ensure the accuracy and coherence of the graph data.
# After analyzing the provided data, I have identified several consistency rules related to the `Computer` node. Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property**
#
# Cypher query: `MATCH (c:Computer) RETURN c.neo4jImportId AS id, COUNT(*) AS count WHERE count > 1`
#
# This query looks for duplicate `neo4jImportId` values across all `Computer` nodes. If the count is greater than 1, it indicates a violation of this rule.
#
# **Rule 2: Each Computer node has a `domain` property with a specific format**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.domain =~ '^[a-zA-Z0-9.]+\\.Local$' RETURN c`
#
# This query checks if the `domain` property of each `Computer` node matches the expected format (e.g., `TestCompany.Local`). If a node doesn't match this format, it will be returned as a violation.
#
# **Rule 3: Each Computer node has an `operatingsystem` property with a specific set of values**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.operatingsystem IN ['Windows 10', 'Windows 7', 'Windows Server 2008'] RETURN c`
#
# This query checks if the `operatingsystem` property of each `Computer` node has one of the expected values (Windows 10, Windows 7, or Windows Server 2008). If a node has an unexpected value, it will be returned as a violation.
#
# **Rule 4: Each Computer node has a `name` property with a specific format**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.name =~ '^COMP\\d{4,5}\\.TestCompany\\.Local$' RETURN c`
#
# This query checks if the `name` property of each `Computer` node matches the expected format (e.g., `COMP00033.TestCompany.Local`). If a node doesn't match this format, it will be returned as a violation.
#
# **Rule 5: Each Computer node has an `objectid` property with a specific format**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.objectid =~ '^S-1-5-21-\\d+-\\d+-\\d+-\\d+$' RETURN c`
#
# This query checks if the `objectid` property of each `Computer` node matches the expected format (e.g., `S-1-5-21-883232822-274137685-4173207997-1032`). If a node doesn't match this format, it will be returned as a violation.
#
# **Rule 6: Each Computer node has an `enabled` property with a boolean value**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.enabled IN [true, false] RETURN c`
#
# This query checks if the `enabled` property of each `Computer` node has a boolean value (true or false). If a node has an unexpected value, it will be returned as a violation.
#
# **Rule 7: Each Computer node has at least one connection to a Group node with an `ADMIN_TO` edge**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->() RETURN c`
#
# This query checks if each `Computer` node has at least one connection to a `Group` node with an `ADMIN_TO` edge. If a node doesn't have such a connection, it will be returned as a violation.
#
# **Rule 8: Each Computer node has at most one connection to a Group node with a `GENERIC_ALL` edge**
#
# Cypher query: `MATCH (c:Computer) WHERE (c)-[:GENERIC_ALL]->() WITH c, COUNT(*) AS count WHERE count > 1 RETURN c`
#
# This query checks if each `Computer` node has at most one connection to a `Group` node with a `GENERIC_ALL` edge. If a node has more than one such connection, it will be returned as a violation.
#
# These rules and queries can help ensure the consistency and accuracy of the graph data related to the `Computer` node.
# Based on the provided data, I've identified some patterns and inferred consistency rules related to nodes of type `Computer`. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every Computer node has a neo4jImportId property**
# Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS(c.neo4jImportId) RETURN c`
#
# **Rule 2: Every Computer node has an owned property with a value of False**
# Cypher query: `MATCH (c:Computer) WHERE c.owned = TRUE RETURN c`
#
# **Rule 3: Every Computer node has a domain property with a value of "TestCompany.Local"**
# Cypher query: `MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN c`
#
# **Rule 4: Every Computer node has an operatingsystem property with a valid operating system value**
# Cypher query: `MATCH (c:Computer) WHERE c.operatingsystem NOT IN ["Windows 7", "Windows 10", "Windows Server 2008"] RETURN c`
#
# **Rule 5: Every Computer node has a name property with a valid computer name format**
# Cypher query: `MATCH (c:Computer) WHERE NOT c.name STARTS WITH "COMP" OR NOT c.name CONTAINS "." RETURN c`
#
# **Rule 6: Every Computer node has an objectid property with a valid SID format**
# Cypher query: `MATCH (c:Computer) WHERE NOT c.objectid STARTS WITH "S-1-5-" RETURN c`
#
# **Rule 7: Every Computer node has an enabled property with a value of True**
# Cypher query: `MATCH (c:Computer) WHERE c.enabled = FALSE RETURN c`
#
# **Rule 8: Every Computer node is connected to a Group node with edge GENERIC_ALL**
# Cypher query: `MATCH (c:Computer) WHERE NOT ()-[r:GENERIC_ALL]->() RETURN c`
#
# **Rule 9: Every Computer node is connected to a Group node with edge ADMIN_TO**
# Cypher query: `MATCH (c:Computer) WHERE NOT ()-[r:ADMIN_TO]->() RETURN c`
#
# **Rule 10: Every Computer node is connected to an OU node with edge CONTAINS**
# Cypher query: `MATCH (c:Computer) WHERE NOT ()-[r:CONTAINS]->() RETURN c`
#
# **Rule 11: A Computer node can be connected to multiple Group nodes with edge MEMBER_OF, but not with edge GENERIC_ALL or ADMIN_TO**
# Cypher query: `MATCH (c:Computer)-[r:MEMBER_OF]->(g:Group) WHERE (c)-[r2:GENERIC_ALL|ADMIN_TO]->(g) RETURN c`
#
# **Rule 12: A Computer node can be connected to multiple User nodes with edge HAS_SESSION or EXECUTE_DCOM, but not with edge GENERIC_ALL or ADMIN_TO**
# Cypher query: `MATCH (c:Computer)-[r:HAS_SESSION|EXECUTE_DCOM]->(u:User) WHERE (c)-[r2:GENERIC_ALL|ADMIN_TO]->(u) RETURN c`
#
# These rules and queries can help ensure the consistency and accuracy of the graph data related to nodes of type `Computer`.
# Based on the provided data, I've identified several patterns and inferred consistency rules related to the `Computer` node. Here are the rules I've discovered, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId`**
#
# * Description: Each Computer node should have a unique `neo4jImportId` property.
# * Cypher query: `MATCH (c:Computer) WITH c.neo4jImportId AS id, COUNT(*) AS count WHERE count > 1 RETURN id`
#
# **Rule 2: Each Computer node has a `domain` property**
#
# * Description: Each Computer node should have a `domain` property.
# * Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS(c.domain) RETURN c`
#
# **Rule 3: Each Computer node has an `operatingsystem` property**
#
# * Description: Each Computer node should have an `operatingsystem` property.
# * Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS(c.operatingsystem) RETURN c`
#
# **Rule 4: Each Computer node has a `name` property**
#
# * Description: Each Computer node should have a `name` property.
# * Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS(c.name) RETURN c`
#
# **Rule 5: Each Computer node has an `objectid` property**
#
# * Description: Each Computer node should have an `objectid` property.
# * Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS(c.objectid) RETURN c`
#
# **Rule 6: Each Computer node has an `enabled` property**
#
# * Description: Each Computer node should have an `enabled` property.
# * Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS(c.enabled) RETURN c`
#
# **Rule 7: Each Computer node is connected to at least one Group node with an `ADMIN_TO` edge**
#
# * Description: Each Computer node should be connected to at least one Group node with an `ADMIN_TO` edge.
# * Cypher query: `MATCH (c:Computer) WHERE NOT EXISTS((c)-[:ADMIN_TO]->(:Group)) RETURN c`
#
# **Rule 8: Each Computer node is connected to exactly one OU node with a `CONTAINS` edge**
#
# * Description: Each Computer node should be connected to exactly one OU node with a `CONTAINS` edge.
# * Cypher query: `MATCH (c:Computer) WITH COUNT((c)-[:CONTAINS]->(:OU)) AS count WHERE count <> 1 RETURN c`
#
# These rules aim to ensure that the graph data is accurate, coherent, and follows the expected schema. The Cypher queries can be executed to identify any violations of these rules in the dataset.
# Upon analyzing the provided data, I've identified some patterns and inferred consistency rules related to the node `Computer`. Here are the rules I've discovered, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property.**
#
# Cypher query: `MATCH (c:Computer) RETURN c.neo4jImportId AS id, COUNT(*) AS count GROUP BY id HAVING count > 1`
#
# This rule ensures that each Computer node has a unique `neo4jImportId` property. The query checks for any duplicates in the `neo4jImportId` column.
#
# **Rule 2: Each Computer node has a `domain` property with a value of "TestCompany.Local".**
#
# Cypher query: `MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN c`
#
# This rule ensures that all Computer nodes have a `domain` property with a value of "TestCompany.Local". The query returns any Computer nodes that violate this rule.
#
# **Rule 3: Each Computer node has an `operatingsystem` property with a value from a specific set (Windows 10, Windows Server 2008, Windows Server 2012, Windows 7).**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.operatingsystem IN ["Windows 10", "Windows Server 2008", "Windows Server 2012", "Windows 7"] RETURN c`
#
# This rule ensures that all Computer nodes have an `operatingsystem` property with a value from a specific set of operating systems. The query returns any Computer nodes that violate this rule.
#
# **Rule 4: Each Computer node has a `name` property in the format "COMPXXXXX.TestCompany.Local".**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.name =~ "COMP\\d{5}\\.TestCompany\\.Local" RETURN c`
#
# This rule ensures that all Computer nodes have a `name` property in the format "COMPXXXXX.TestCompany.Local". The query returns any Computer nodes that violate this rule.
#
# **Rule 5: Each Computer node has an `objectid` property in the format "S-1-5-21-XXXXXXXX-XXXXXXXX-XXXXXXXX-XXXX".**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.objectid =~ "S-1-5-21-\\d{10}-\\d{10}-\\d{10}-\\d{4}" RETURN c`
#
# This rule ensures that all Computer nodes have an `objectid` property in the format "S-1-5-21-XXXXXXXX-XXXXXXXX-XXXXXXXX-XXXX". The query returns any Computer nodes that violate this rule.
#
# **Rule 6: Each Computer node has an `enabled` property with a value of true.**
#
# Cypher query: `MATCH (c:Computer) WHERE c.enabled = false RETURN c`
#
# This rule ensures that all Computer nodes have an `enabled` property with a value of true. The query returns any Computer nodes that violate this rule.
#
# **Rule 7: Each Computer node is connected to a Group node with a GENERIC_ALL edge.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:GENERIC_ALL]->() RETURN c`
#
# This rule ensures that each Computer node is connected to a Group node with a GENERIC_ALL edge. The query returns any Computer nodes that violate this rule.
#
# **Rule 8: Each Computer node is connected to a Group node with an ADMIN_TO edge.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->() RETURN c`
#
# This rule ensures that each Computer node is connected to a Group node with an ADMIN_TO edge. The query returns any Computer nodes that violate this rule.
#
# **Rule 9: Each Computer node is connected to an OU node with a CONTAINS edge.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->() RETURN c`
#
# This rule ensures that each Computer node is connected to an OU node with a CONTAINS edge. The query returns any Computer nodes that violate this rule.
#
# These rules aim to capture the patterns and relationships observed in the provided data. By running these Cypher queries, you can identify any inconsistencies or violations in the dataset.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `Computer` node. Here are the rules I've discovered:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property**
#
# Description: Each `Computer` node should have a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WITH c.neo4jImportId AS id
# WITH collect(id) AS ids
# WHERE size(ids) != size(distinct ids)
# RETURN "Duplicate neo4jImportId found" AS error_message
# ```
# **Rule 2: Each Computer node has a `domain` property with a specific value**
#
# Description: Each `Computer` node should have a `domain` property with the value "TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.domain != "TestCompany.Local"
# RETURN "Invalid domain value" AS error_message
# ```
# **Rule 3: Each Computer node has an `operatingsystem` property with a specific value**
#
# Description: Each `Computer` node should have an `operatingsystem` property with a value from a specific set (e.g., Windows Server 2012, Windows Server 2008, Windows 7).
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.operatingsystem NOT IN ["Windows Server 2012", "Windows Server 2008", "Windows 7"]
# RETURN "Invalid operatingsystem value" AS error_message
# ```
# **Rule 4: Each Computer node has a `name` property with a specific format**
#
# Description: Each `Computer` node should have a `name` property with a specific format (e.g., COMP000xx.TestCompany.Local).
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT c.name STARTS WITH "COMP" AND NOT c.name ENDS WITH ".TestCompany.Local"
# RETURN "Invalid name format" AS error_message
# ```
# **Rule 5: Each Computer node has an `objectid` property with a specific format**
#
# Description: Each `Computer` node should have an `objectid` property with a specific format (e.g., S-1-5-21-883232822-274137685-4173207997-xxxx).
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT c.objectid STARTS WITH "S-1-5-21-883232822-274137685-4173207997-"
# RETURN "Invalid objectid format" AS error_message
# ```
# **Rule 6: Each Computer node has an `enabled` property with a specific value**
#
# Description: Each `Computer` node should have an `enabled` property with a boolean value (True or False).
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.enabled NOT IN [true, false]
# RETURN "Invalid enabled value" AS error_message
# ```
# **Rule 7: Each Computer node is connected to at least one Group node with an ADMIN_TO edge**
#
# Description: Each `Computer` node should be connected to at least one `Group` node with an ADMIN_TO edge.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->(:Group)
# RETURN "Computer node is not connected to a Group node with an ADMIN_TO edge" AS error_message
# ```
# **Rule 8: Each Computer node is connected to at least one OU node with a CONTAINS edge**
#
# Description: Each `Computer` node should be connected to at least one `OU` node with a CONTAINS edge.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->(:OU)
# RETURN "Computer node is not connected to an OU node with a CONTAINS edge" AS error_message
# ```
# These rules can help ensure the accuracy, coherence, and schema consistency of the graph data related to `Computer` nodes.
# Based on the provided data, I've identified several patterns and inferred consistency rules related to nodes of type `Computer`. Here are the rules along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: A Computer node must have exactly one `CONTAINS` relationship with an `OU` node.**
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->(:OU)
# RETURN c
# ```
# This query will return any `Computer` nodes that do not have a `CONTAINS` relationship with an `OU` node.
#
# **Rule 2: A Computer node must have at least one `ADMIN_TO` relationship with a `Group` node.**
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->(:Group)
# RETURN c
# ```
# This query will return any `Computer` nodes that do not have an `ADMIN_TO` relationship with a `Group` node.
#
# **Rule 3: A Computer node must have a `GENERIC_ALL` relationship with a `Group` node with `isacl: true`.**
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:GENERIC_ALL {roles: {isacl: true}}]->(:Group)
# RETURN c
# ```
# This query will return any `Computer` nodes that do not have a `GENERIC_ALL` relationship with a `Group` node with `isacl: true`.
#
# **Rule 4: A Computer node must have a `MEMBER_OF` relationship with a `Group` node.**
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:MEMBER_OF]->(:Group)
# RETURN c
# ```
# This query will return any `Computer` nodes that do not have a `MEMBER_OF` relationship with a `Group` node.
#
# **Rule 5: A Computer node must have a unique `objectid` property.**
#
# Cypher query:
# ```
# MATCH (c1:Computer), (c2:Computer) WHERE c1.objectid = c2.objectid AND c1 <> c2
# RETURN c1, c2
# ```
# This query will return any pair of `Computer` nodes that have the same `objectid` property.
#
# **Rule 6: A Computer node must have a valid `operatingsystem` property (e.g., Windows 7, Windows 10, etc.).**
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT c.operatingsystem IN ['Windows 7', 'Windows 10', ...] // add more valid operating systems as needed
# RETURN c
# ```
# This query will return any `Computer` nodes that do not have a valid `operatingsystem` property.
#
# These rules and queries can help ensure the accuracy and consistency of the graph data related to `Computer` nodes.
# After analyzing the data, I've identified several patterns and consistency rules related to the Computer node. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every Computer node has a unique neo4jImportId property**
#
# * Cypher query: `MATCH (c:Computer) WHERE c.neo4jImportId IS NULL OR c.neo4jImportId = '' RETURN c`
#
# **Rule 2: Every Computer node has a domain property**
#
# * Cypher query: `MATCH (c:Computer) WHERE c.domain IS NULL OR c.domain = '' RETURN c`
#
# **Rule 3: Every Computer node has an operatingsystem property**
#
# * Cypher query: `MATCH (c:Computer) WHERE c.operatingsystem IS NULL OR c.operatingsystem = '' RETURN c`
#
# **Rule 4: Every Computer node has a name property that follows a specific format (e.g., "COMPxxxxx.TestCompany.Local")**
#
# * Cypher query: `MATCH (c:Computer) WHERE NOT c.name =~ 'COMP\\d{5}\\.TestCompany\\.Local' RETURN c`
#
# **Rule 5: Every Computer node has an objectid property that follows a specific format (e.g., "S-1-5-21-...")**
#
# * Cypher query: `MATCH (c:Computer) WHERE NOT c.objectid =~ 'S-1-5-21-\\d+-\\d+-\\d+-\\d+' RETURN c`
#
# **Rule 6: Every Computer node has an enabled property with a boolean value**
#
# * Cypher query: `MATCH (c:Computer) WHERE c.enabled IS NULL OR NOT (c.enabled = true OR c.enabled = false) RETURN c`
#
# **Rule 7: Every Computer node is connected to at least one Group node with an ADMIN_TO edge**
#
# * Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->(:Group) RETURN c`
#
# **Rule 8: Every Computer node is connected to at most one OU node with a CONTAINS edge**
#
# * Cypher query: `MATCH (c:Computer) WHERE (c)-[:CONTAINS]->(:OU) WITH c, count(*) as cnt WHERE cnt > 1 RETURN c`
#
# **Rule 9: Every Computer node has at least one edge (GENERIC_ALL, ADMIN_TO, MEMBER_OF, HAS_SESSION, ALLOWED_TO_DELEGATE, or EXECUTE_DCOM) to a Group or User node**
#
# * Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:GENERIC_ALL|ADMIN_TO|MEMBER_OF|HAS_SESSION|ALLOWED_TO_DELEGATE|EXECUTE_DCOM]->() RETURN c`
#
# These rules and queries can help ensure the accuracy and consistency of the graph data related to the Computer node.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `Computer` node. Here are the rules with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every Computer node has a unique `neo4jImportId` property.**
#
# Cypher query: `MATCH (c:Computer) RETURN c.neo4jImportId AS id, COUNT(*) AS count GROUP BY id HAVING count > 1`
#
# **Rule 2: Every Computer node has a `domain` property set to "TestCompany.Local".**
#
# Cypher query: `MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN c`
#
# **Rule 3: Every Computer node has an `operatingsystem` property with a valid operating system value (e.g., Windows 7, Windows 10, Windows Server 2008).**
#
# Cypher query: `MATCH (c:Computer) WHERE c.operatingsystem NOT IN ["Windows 7", "Windows 10", "Windows Server 2008"] RETURN c`
#
# **Rule 4: Every Computer node has a `name` property in the format "COMPXXXXX.TestCompany.Local".**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.name =~ "COMP\\d{5}\\.TestCompany\\.Local" RETURN c`
#
# **Rule 5: Every Computer node has an `objectid` property in the format "S-1-5-21-xxxxx-xxxxx-xxxxx-xxxx".**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.objectid =~ "S-1-5-21-\\d+-\\d+-\\d+-\\d+" RETURN c`
#
# **Rule 6: Every Computer node has an `enabled` property set to true.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT c.enabled RETURN c`
#
# **Rule 7: Every Computer node has at least one edge to a Group node with an `ADMIN_TO` relationship.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->(:Group) RETURN c`
#
# **Rule 8: Every Computer node has at most one edge to an OU node with a `CONTAINS` relationship.**
#
# Cypher query: `MATCH (c:Computer) WHERE (c)-[:CONTAINS]->(:OU) WITH c, COUNT(*) AS count WHERE count > 1 RETURN c`
#
# **Rule 9: Every Computer node has edges to Group nodes with `GENERIC_ALL` and `ADMIN_TO` relationships to node 0.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT ((c)-[:GENERIC_ALL]->(:Group {id: 0}) AND (c)-[:ADMIN_TO]->(:Group {id: 0})) RETURN c`
#
# **Rule 10: Every Computer node has edges to Group nodes with `MEMBER_OF` relationships to node 1.**
#
# Cypher query: `MATCH (c:Computer) WHERE NOT (c)-[:MEMBER_OF]->(:Group {id: 1}) RETURN c`
#
# These rules and queries can help ensure the consistency and accuracy of the graph data. By running these queries, you can identify potential issues and take corrective action to maintain data quality.
# After analyzing the provided data, I've identified some consistency rules related to node Computer:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property**
#
# Description: Ensure that each Computer node has a unique `neo4jImportId` property.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WITH c.neo4jImportId AS id
# WHERE size((MATCH (c2:Computer) WHERE c2.neo4jImportId = id RETURN c2)) > 1
# RETURN "Duplicate neo4jImportId found" AS error
# ```
#
# **Rule 2: Each Computer node has a `domain` property with a valid domain name**
#
# Description: Ensure that each Computer node has a `domain` property with a valid domain name.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE NOT exists(c.domain) OR NOT c.domain =~ '^[a-zA-Z0-9.-]+$'
# RETURN "Invalid or missing domain name" AS error
# ```
#
# **Rule 3: Each Computer node has an `operatingsystem` property with a valid operating system name**
#
# Description: Ensure that each Computer node has an `operatingsystem` property with a valid operating system name.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE NOT exists(c.operatingsystem) OR NOT c.operatingsystem =~ '^(Windows|Linux|Mac|Unix)$'
# RETURN "Invalid or missing operating system name" AS error
# ```
#
# **Rule 4: Each Computer node has a `name` property with a valid hostname**
#
# Description: Ensure that each Computer node has a `name` property with a valid hostname.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE NOT exists(c.name) OR NOT c.name =~ '^[a-zA-Z0-9.-]+$'
# RETURN "Invalid or missing hostname" AS error
# ```
#
# **Rule 5: Each Computer node has an `objectid` property with a valid object ID**
#
# Description: Ensure that each Computer node has an `objectid` property with a valid object ID.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE NOT exists(c.objectid) OR NOT c.objectid =~ '^S-[0-9]+-[0-9]+-[0-9]+$'
# RETURN "Invalid or missing object ID" AS error
# ```
#
# **Rule 6: Each Computer node has an `enabled` property with a valid boolean value**
#
# Description: Ensure that each Computer node has an `enabled` property with a valid boolean value.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE NOT exists(c.enabled) OR NOT (c.enabled = true OR c.enabled = false)
# RETURN "Invalid or missing enabled property" AS error
# ```
#
# **Rule 7: Each Computer node is connected to at least one Group node with a MEMBER_OF edge**
#
# Description: Ensure that each Computer node is connected to at least one Group node with a MEMBER_OF edge.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE NOT exists((c)-[:MEMBER_OF]->(:Group))
# RETURN "Computer node not connected to a Group node with MEMBER_OF edge" AS error
# ```
#
# **Rule 8: Each Computer node is connected to at most one OU node with a CONTAINS edge**
#
# Description: Ensure that each Computer node is connected to at most one OU node with a CONTAINS edge.
#
# Cypher query:
# ```
# MATCH (c:Computer)
# WHERE size((c)-[:CONTAINS]->(:OU)) > 1
# RETURN "Computer node connected to multiple OU nodes with CONTAINS edge" AS error
# ```
#
# These rules can help ensure the data accuracy and consistency of the Computer nodes in the graph.
# After analyzing the provided data, I have identified several consistency rules related to the `Computer` node. For each rule, I provide a clear description and a corresponding Cypher query to check for violations in the dataset.
#
# **Rule 1: Each Computer node has a unique `neo4jImportId`**
#
# Description: Each `Computer` node should have a unique `neo4jImportId` property.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WITH c.neo4jImportId AS id
# WHERE size(collect(id)) != size(distinct id)
# RETURN "Duplicate neo4jImportId found" AS error
# ```
# **Rule 2: Each Computer node has a valid `domain` property**
#
# Description: Each `Computer` node should have a valid `domain` property that matches a specific pattern (e.g., `TestCompany.Local`).
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WHERE NOT c.domain =~ "TestCompany\\.Local"
# RETURN "Invalid domain found" AS error
# ```
# **Rule 3: Each Computer node has a valid `operatingsystem` property**
#
# Description: Each `Computer` node should have a valid `operatingsystem` property that matches a specific set of values (e.g., `Windows Server 2012`, `Windows 7`, `Windows 10`, etc.).
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WHERE NOT c.operatingsystem IN ["Windows Server 2012", "Windows 7", "Windows 10", ...]
# RETURN "Invalid operatingsystem found" AS error
# ```
# **Rule 4: Each Computer node has a valid `name` property**
#
# Description: Each `Computer` node should have a valid `name` property that matches a specific pattern (e.g., `COMP001xx.TestCompany.Local`).
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WHERE NOT c.name =~ "COMP001\\d{2}\\.TestCompany\\.Local"
# RETURN "Invalid name found" AS error
# ```
# **Rule 5: Each Computer node has a valid `objectid` property**
#
# Description: Each `Computer` node should have a valid `objectid` property that matches a specific pattern (e.g., `S-1-5-21-883232822-274137685-4173207997-xxxx`).
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WHERE NOT c.objectid =~ "S-1-5-21-883232822-274137685-4173207997-\\d{4}"
# RETURN "Invalid objectid found" AS error
# ```
# **Rule 6: Each Computer node has a valid `enabled` property**
#
# Description: Each `Computer` node should have a valid `enabled` property that is set to `True` or `False`.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WHERE NOT c.enabled IN [True, False]
# RETURN "Invalid enabled property found" AS error
# ```
# **Rule 7: Each Computer node has at least one `ADMIN_TO` edge to a Group node**
#
# Description: Each `Computer` node should have at least one `ADMIN_TO` edge to a `Group` node.
#
# Cypher Query:
# ```cypher
# MATCH (c:Computer)
# WHERE NOT (c)-[:ADMIN_TO]->(:Group)
# RETURN "Computer node without ADMIN_TO edge found" AS error
# ```
# These rules and queries can help ensure the consistency and accuracy of the graph data related to `Computer` nodes.
# After analyzing the data, I've identified some patterns and inferred consistency rules related to the node Computer. Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: A Computer node must have a unique `neo4jImportId` property.**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) RETURN COUNT(DISTINCT c.neo4jImportId) AS count
# ```
# This query returns the count of distinct `neo4jImportId` values among all Computer nodes. If the count is not equal to the total number of Computer nodes, it indicates duplicate `neo4jImportId` values.
#
# **Rule 2: A Computer node must have a `domain` property with a value of "TestCompany.Local".**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN c
# ```
# This query returns all Computer nodes with a `domain` property value other than "TestCompany.Local".
#
# **Rule 3: A Computer node must have an `operatingsystem` property with a value of either "Windows 7" or "Windows 10".**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.operatingsystem NOT IN ["Windows 7", "Windows 10"] RETURN c
# ```
# This query returns all Computer nodes with an `operatingsystem` property value not equal to "Windows 7" or "Windows 10".
#
# **Rule 4: A Computer node must have a `name` property in the format "COMPxxxxxxxx.TestCompany.Local".**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.name STARTS WITH "COMP" AND NOT c.name ENDS WITH ".TestCompany.Local" RETURN c
# ```
# This query returns all Computer nodes with a `name` property value not matching the specified format.
#
# **Rule 5: A Computer node must have an `objectid` property with a value in the format "S-1-5-21-xxxxxxxx-xxxxxxxx-xxxxxxxx-xxxx".**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.objectid STARTS WITH "S-1-5-21-" RETURN c
# ```
# This query returns all Computer nodes with an `objectid` property value not matching the specified format.
#
# **Rule 6: A Computer node must have an `enabled` property with a value of True.**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.enabled <> True RETURN c
# ```
# This query returns all Computer nodes with an `enabled` property value not equal to True.
#
# **Rule 7: A Computer node must have at least one edge of type GENERIC_ALL with a Group node.**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:GENERIC_ALL]->(:Group) RETURN c
# ```
# This query returns all Computer nodes without an edge of type GENERIC_ALL with a Group node.
#
# **Rule 8: A Computer node must have at least one edge of type MEMBER_OF with a Group node.**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:MEMBER_OF]->(:Group) RETURN c
# ```
# This query returns all Computer nodes without an edge of type MEMBER_OF with a Group node.
#
# **Rule 9: A Computer node must have at least one edge of type CONTAINS with an OU node.**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->(:OU) RETURN c
# ```
# This query returns all Computer nodes without an edge of type CONTAINS with an OU node.
#
# By running these queries, you can identify any inconsistencies in the data and take corrective action to ensure the data conforms to the expected schema.
# Based on the provided data, I've identified the following patterns and consistency rules related to node `Computer`:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property.**
#
# Description: Every `Computer` node has a unique `neo4jImportId` property, which is an integer value.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.neo4jImportId IS NOT NULL AND c.neo4jImportId = 0
# RETURN c
# ```
# **Rule 2: Each Computer node has a `domain` property with a consistent value.**
#
# Description: All `Computer` nodes have a `domain` property with the value "TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.domain IS NOT NULL AND c.domain <> "TestCompany.Local"
# RETURN c
# ```
# **Rule 3: Each Computer node has an `operatingsystem` property with a valid value.**
#
# Description: The `operatingsystem` property of each `Computer` node has one of the following valid values: "Windows 10", "Windows Server 2008", or "Windows Server 2012".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.operatingsystem IS NOT NULL AND NOT (c.operatingsystem IN ["Windows 10", "Windows Server 2008", "Windows Server 2012"])
# RETURN c
# ```
# **Rule 4: Each Computer node has a `name` property with a consistent format.**
#
# Description: The `name` property of each `Computer` node follows the format "COMPxxxxxx.TestCompany.Local", where "xxxxxx" is a unique identifier.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.name IS NOT NULL AND NOT (c.name =~ "COMP\\d+\\.TestCompany\\.Local")
# RETURN c
# ```
# **Rule 5: Each Computer node has an `objectid` property with a unique value.**
#
# Description: Every `Computer` node has a unique `objectid` property, which is a string value.
#
# Cypher query to check for violations:
# ```
# MATCH (c1:Computer), (c2:Computer) WHERE c1.objectid = c2.objectid AND c1 <> c2
# RETURN c1, c2
# ```
# **Rule 6: Each Computer node has an `enabled` property with a boolean value.**
#
# Description: The `enabled` property of each `Computer` node is a boolean value (true or false).
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.enabled IS NOT NULL AND NOT (c.enabled IN [true, false])
# RETURN c
# ```
# **Rule 7: Each Computer node is connected to at least one Group node with a MEMBER_OF edge.**
#
# Description: Every `Computer` node is connected to at least one `Group` node with a `MEMBER_OF` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:MEMBER_OF]->(:Group))
# RETURN c
# ```
# **Rule 8: Each Computer node is connected to at most one OU node with a CONTAINS edge.**
#
# Description: Every `Computer` node is connected to at most one `OU` node with a `CONTAINS` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE size((c)-[:CONTAINS]->(:OU)) > 1
# RETURN c
# ```
# These rules can be used to ensure the accuracy, coherence, and consistency of the graph data related to `Computer` nodes.
# Based on the provided data, I've identified several consistency rules related to the Computer node:
#
# **Rule 1: Computer node must have a unique neo4jImportId**
#
# Each Computer node should have a unique `neo4jImportId` property. This ensures that each Computer node can be uniquely identified.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.neo4jImportId IS NOT NULL AND c.neo4jImportId IN (
#   SELECT neo4jImportId FROM (
#     SELECT neo4jImportId, COUNT(*) AS count
#     FROM (MATCH (c:Computer) RETURN c.neo4jImportId) AS subquery
#     GROUP BY neo4jImportId
#     HAVING count > 1
#   ) AS duplicates
# )
# RETURN c
# ```
# **Rule 2: Computer node must have a domain property**
#
# Each Computer node should have a `domain` property specifying the domain it belongs to.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.domain IS NULL
# RETURN c
# ```
# **Rule 3: Computer node must have an operatingsystem property**
#
# Each Computer node should have an `operatingsystem` property specifying the operating system it runs.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.operatingsystem IS NULL
# RETURN c
# ```
# **Rule 4: Computer node must have a name property**
#
# Each Computer node should have a `name` property specifying the computer's name.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.name IS NULL
# RETURN c
# ```
# **Rule 5: Computer node must be connected to at least one Group node with a MEMBER_OF edge**
#
# Each Computer node should be connected to at least one Group node with a MEMBER_OF edge, indicating the group it belongs to.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:MEMBER_OF]->()
# RETURN c
# ```
# **Rule 6: Computer node must be connected to an OU node with a CONTAINS edge**
#
# Each Computer node should be connected to an OU node with a CONTAINS edge, indicating the organizational unit it belongs to.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->()
# RETURN c
# ```
# **Rule 7: Computer node can have multiple ADMIN_TO edges, but they should all point to different Group nodes**
#
# Each Computer node can have multiple ADMIN_TO edges, but they should all point to different Group nodes.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer)-[:ADMIN_TO]->(g:Group)
# WITH c, COLLECT(g) AS groups
# WHERE SIZE(groups) < SIZE((c)-[:ADMIN_TO]->())
# RETURN c
# ```
# These consistency rules aim to ensure that the graph data is accurate and follows the expected schema. By running these Cypher queries, you can identify any inconsistencies or errors in the data.
# After analyzing the provided data, I have identified some patterns and consistency rules related to the node `Computer`. Here are the rules along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Computer node should have a unique `neo4jImportId` property.**
#
# * Cypher query: `MATCH (c:Computer) RETURN count(DISTINCT c.neo4jImportId) AS unique_import_ids, count(c) AS total_computers WHERE unique_import_ids <> total_computers`
#
# **Rule 2: Each Computer node should have a `domain` property with a value that is not null or empty.**
#
# ...
#
# **Rule 1: Every Computer node has a `domain` property with a value of "TestCompany.Local"**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN c
# ```
# **Rule 2: Every Computer node has an `operatingsystem` property with a value of either "Windows Server 2012", "Windows 10", "Windows Server 2008", or "Windows 7"**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.operatingsystem NOT IN ["Windows Server 2012", "Windows 10", "Windows Server 2008", "Windows 7"] RETURN c
# ```
# **Rule 3: Every Computer node has a `name` property in the format "COMPXXXXX.TestCompany.Local"**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.name =~ /COMP\d{5}\.TestCompany\.Local/ RETURN c
# ```
# **Rule 4: Every Computer node has an `enabled` property with a value of `true`**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.enabled <> true RETURN c
# ```
# **Rule 5: Every Computer node is connected to a Group node with an ADMIN_TO edge**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->(:Group) RETURN c
# ```
# **Rule 6: Every Computer node is connected to a Group node with a MEMBER_OF edge**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:MEMBER_OF]->(:Group) RETURN c
# ```
# **Rule 7: Every Computer node is connected to an OU node with a CONTAINS edge**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->(:OU) RETURN c
# ```
# **Rule 8: Every Computer node has a unique `objectid` property**
#
# Cypher query:
# ```cypher
# MATCH (c1:Computer), (c2:Computer) WHERE c1.objectid = c2.objectid AND c1.neo4jImportId <> c2.neo4jImportId RETURN c1, c2
# ```
# These rules and queries can help identify inconsistencies in the data, ensuring that the Computer nodes conform to the expected schema.
# After analyzing the data, I've identified some patterns and consistency rules related to the `Computer` node. Here are the rules I've found, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property**
#
# Description: Each Computer node should have a unique `neo4jImportId` property to prevent duplicates.
#
# Cypher Query:
# ```
# MATCH (c:Computer) WITH c.neo4jImportId AS id
# WHERE size((MATCH (c2:Computer) WHERE c2.neo4jImportId = id RETURN c2)) > 1
# RETURN count(*)
# ```
# This query checks if there are any duplicate `neo4jImportId` values among the Computer nodes. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 2: Each Computer node is connected to at least one Group node with an `ADMIN_TO` edge**
#
# Description: Each Computer node should be connected to at least one Group node with an `ADMIN_TO` edge, indicating administrative access.
#
# Cypher Query:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->(:Group)
# RETURN count(*)
# ```
# This query checks if there are any Computer nodes that are not connected to at least one Group node with an `ADMIN_TO` edge. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 3: Each Computer node is connected to exactly one OU node with a `CONTAINS` edge**
#
# Description: Each Computer node should be connected to exactly one OU node with a `CONTAINS` edge, indicating the organizational unit it belongs to.
#
# Cypher Query:
# ```
# MATCH (c:Computer) WHERE NOT (c)-[:CONTAINS]->(:OU) OR (c)-[:CONTAINS]->(:OU) AND size((c)-[:CONTAINS]->(:OU)) > 1
# RETURN count(*)
# ```
# This query checks if there are any Computer nodes that are not connected to exactly one OU node with a `CONTAINS` edge. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 4: Each Computer node has a valid `domain` property**
#
# Description: Each Computer node should have a valid `domain` property, which should not be null or empty.
#
# Cypher Query:
# ```
# MATCH (c:Computer) WHERE c.domain IS NULL OR c.domain = ""
# RETURN count(*)
# ```
# This query checks if there are any Computer nodes with a null or empty `domain` property. If the count is greater than 0, it indicates a violation of this rule.
#
# These rules and queries help ensure the accuracy and consistency of the graph data related to the `Computer` node.
# Based on the provided data, I've identified the following consistency rules related to the `Computer` node:
#
# **Rule 1: A Computer node should have a `domain` property**
#
# Description: Every Computer node should have a `domain` property with a valid value.
#
# Cypher Query: `MATCH (c:Computer) WHERE NOT EXISTS(c.domain) RETURN c`
#
# **Rule 2: A Computer node should have an `operatingsystem` property**
#
# Description: Every Computer node should have an `operatingsystem` property with a valid value.
#
# Cypher Query: `MATCH (c:Computer) WHERE NOT EXISTS(c.operatingsystem) RETURN c`
#
# **Rule 3: A Computer node should have a `name` property**
#
# Description: Every Computer node should have a `name` property with a valid value.
#
# Cypher Query: `MATCH (c:Computer) WHERE NOT EXISTS(c.name) RETURN c`
#
# **Rule 4: A Computer node should have an `objectid` property**
#
# Description: Every Computer node should have an `objectid` property with a valid value.
#
# Cypher Query: `MATCH (c:Computer) WHERE NOT EXISTS(c.objectid) RETURN c`
#
# **Rule 5: A Computer node should have an `enabled` property**
#
# Description: Every Computer node should have an `enabled` property with a valid boolean value.
#
# Cypher Query: `MATCH (c:Computer) WHERE NOT EXISTS(c.enabled) OR NOT (c.enabled IN [true, false]) RETURN c`
#
# **Rule 6: A Computer node should have at least one connection to a Group node**
#
# Description: Every Computer node should have at least one connection to a Group node using the MEMBER_OF edge type.
#
# Cypher Query: `MATCH (c:Computer) WHERE NOT ()-[:MEMBER_OF]-(g:Group) RETURN c`
#
# **Rule 7: A Computer node should have at most one connection to a User node using the HAS_SESSION edge type**
#
# Description: A Computer node should have at most one connection to a User node using the HAS_SESSION edge type.
#
# Cypher Query: `MATCH (c:Computer)-[:HAS_SESSION]->(u:User) WITH c, COUNT(u) as count WHERE count > 1 RETURN c`
#
# **Rule 8: A Computer node should have at most one connection to a Group node using the ADMIN_TO edge type for each Group**
#
# Description: A Computer node should have at most one connection to a Group node using the ADMIN_TO edge type for each Group.
#
# Cypher Query: `MATCH (c:Computer)-[:ADMIN_TO]->(g:Group) WITH c, g, COUNT(*) as count WHERE count > 1 RETURN c, g`
#
# **Rule 9: A Computer node should have at most one connection to an OU node using the CONTAINS edge type**
#
# Description: A Computer node should have at most one connection to an OU node using the CONTAINS edge type.
#
# Cypher Query: `MATCH (c:Computer)-[:CONTAINS]->(ou:OU) WITH c, COUNT(ou) as count WHERE count > 1 RETURN c`
#
# By running these Cypher queries, you can identify any inconsistencies in the graph data related to the Computer node and its connections to other nodes.
# After analyzing the data, I've identified some patterns and consistency rules related to node `Computer`. Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: Each Computer node has a unique `neo4jImportId` property**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) RETURN COUNT(DISTINCT c.neo4jImportId) AS unique_import_ids
# ```
# If the result is not equal to the number of Computer nodes, it indicates that there are duplicate `neo4jImportId` values.
#
# **Rule 2: Each Computer node has a `domain` property with a specific value (e.g., "TestCompany.Local")**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes with incorrect or missing `domain` values.
#
# **Rule 3: Each Computer node has an `operatingsystem` property with a valid value (e.g., "Windows Server 2008", "Windows 7", "Windows 10")**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.operatingsystem IN ["Windows Server 2008", "Windows 7", "Windows 10"] RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes with invalid or missing `operatingsystem` values.
#
# **Rule 4: Each Computer node has a `name` property with a specific format (e.g., "COMP00284.TestCompany.Local")**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.name =~ "COMP\\d+\\.TestCompany\\.Local" RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes with invalid or missing `name` values.
#
# **Rule 5: Each Computer node has an `objectid` property with a specific format (e.g., "S-1-5-21-883232822-274137685-4173207997-1283")**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.objectid =~ "S-1-5-21-\\d+-\\d+-\\d+-\\d+" RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes with invalid or missing `objectid` values.
#
# **Rule 6: Each Computer node has an `enabled` property with a boolean value**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT c.enabled IN [true, false] RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes with invalid or missing `enabled` values.
#
# **Rule 7: Each Computer node is connected to at least one Group node with an ADMIN_TO edge**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE NOT (c)-[:ADMIN_TO]->() RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes without an ADMIN_TO edge to a Group node.
#
# **Rule 8: Each Computer node is connected to at most one OU node with a CONTAINS edge**
#
# Cypher query:
# ```cypher
# MATCH (c:Computer) WHERE (c)-[:CONTAINS]->() WITH c, COUNT(*) AS count WHERE count > 1 RETURN c
# ```
# If any Computer nodes are returned, it indicates that there are nodes connected to more than one OU node with a CONTAINS edge.
#
# By running these Cypher queries, you can identify any inconsistencies in the data and take steps to correct them.
# Based on the provided data, I've identified the following patterns and consistency rules related to the `Computer` node:
#
# **Rule 1: Computer nodes have a unique `neo4jImportId` property**
#
# Description: Each `Computer` node has a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.neo4jImportId IS NOT NULL AND EXISTS((c)-[:SAME_PROPERTY {property: "neo4jImportId"}]->()) RETURN count(*)
# ```
# **Rule 2: Computer nodes have a `domain` property with a specific value**
#
# Description: All `Computer` nodes have a `domain` property with the value "TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.domain <> "TestCompany.Local" RETURN count(*)
# ```
# **Rule 3: Computer nodes have a `name` property with a specific format**
#
# Description: All `Computer` nodes have a `name` property in the format "COMPXXXXX.TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT c.name STARTS WITH "COMP" AND NOT c.name ENDS WITH ".TestCompany.Local" RETURN count(*)
# ```
# **Rule 4: Computer nodes have an `operatingsystem` property with a specific set of values**
#
# Description: All `Computer` nodes have an `operatingsystem` property with one of the following values: "Windows Server 2008", "Windows Server 2012", "Windows 7", "Windows 10".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE c.operatingsystem NOT IN ["Windows Server 2008", "Windows Server 2012", "Windows 7", "Windows 10"] RETURN count(*)
# ```
# **Rule 5: Computer nodes have an `objectid` property with a specific format**
#
# Description: All `Computer` nodes have an `objectid` property in the format "S-1-5-21-...'".
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT c.objectid STARTS WITH "S-1-5-21-" RETURN count(*)
# ```
# **Rule 6: Computer nodes have an `enabled` property with a boolean value**
#
# Description: All `Computer` nodes have an `enabled` property with a boolean value (true or false).
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT (c.enabled = true OR c.enabled = false) RETURN count(*)
# ```
# **Rule 7: Computer nodes are connected to at least one `Group` node**
#
# Description: Each `Computer` node is connected to at least one `Group` node through an edge with type `ADMIN_TO`, `MEMBER_OF`, `GENERIC_ALL`, or `CAN_RDP`.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE NOT EXISTS((c)-[:ADMIN_TO|MEMBER_OF|GENERIC_ALL|CAN_RDP]->()) RETURN count(*)
# ```
# **Rule 8: Computer nodes are connected to at most one `OU` node**
#
# Description: Each `Computer` node is connected to at most one `OU` node through an edge with type `CONTAINS`.
#
# Cypher query to check for violations:
# ```
# MATCH (c:Computer) WHERE EXISTS((c)-[:CONTAINS]->(ou1:OU)) AND EXISTS((c)-[:CONTAINS]->(ou2:OU)) AND ou1 <> ou2 RETURN count(*)
# ```
# These consistency rules and corresponding Cypher queries can help ensure the accuracy and coherence of the graph data related to the `Computer` node.
# After analyzing the data, I've identified some patterns and inferred consistency rules related to the `Computer` node. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: A Computer node must have a unique `neo4jImportId` property.**
#
# Description: Each Computer node should have a unique `neo4jImportId` property to ensure data consistency and avoid duplicates.
#
# Cypher query:
# ```
# MATCH (c:Computer) WITH c.neo4jImportId as id, COUNT(c) as count
# WHERE count > 1
# RETURN id, count
# ```
# This query checks for duplicate `neo4jImportId` values across all Computer nodes. If the count is greater than 1, it means there's a violation of this rule.
#
# **Rule 2: A Computer node must have a `domain` property.**
#
# Description: Every Computer node should have a `domain` property to specify the domain it belongs to.
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT exists(c.domain)
# RETURN c
# ```
# This query finds Computer nodes without a `domain` property, indicating a violation of this rule.
#
# **Rule 3: A Computer node must have an `operatingsystem` property or be null.**
#
# Description: A Computer node should either have an `operatingsystem` property or have a null value for it.
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT exists(c.operatingsystem) AND c.operatingsystem IS NOT NULL
# RETURN c
# ```
# This query finds Computer nodes with an `operatingsystem` property that is neither null nor existing, which is a violation of this rule.
#
# **Rule 4: A Computer node can have multiple GROUP connections with different roles.**
#
# Description: A Computer node can be connected to multiple Group nodes with different roles (e.g., MEMBER_OF, ADMIN_TO, EXECUTE_DCOM).
#
# Cypher query:
# ```
# MATCH (c:Computer)-[:MEMBER_OF|:ADMIN_TO|:EXECUTE_DCOM]-(g:Group)
# WITH c, g, COLLECT(TYPE(r)) as roles
# WHERE SIZE(roles) > 1
# RETURN c, g, roles
# ```
# This query checks for Computer nodes connected to a Group node with multiple roles. If the size of the roles collection is greater than 1, it means the rule is satisfied.
#
# **Rule 5: A Computer node must be connected to an OU node with a CONTAINS edge.**
#
# Description: Every Computer node should be connected to an OU node with a CONTAINS edge to establish its organizational unit.
#
# Cypher query:
# ```
# MATCH (c:Computer) WHERE NOT exists((c)-[:CONTAINS]-(ou:OU))
# RETURN c
# ```
# This query finds Computer nodes without a CONTAINS edge to an OU node, indicating a violation of this rule.
#
# **Rule 6: A Computer node can have multiple OU connections with a CONTAINS edge.**
#
# Description: A Computer node can be connected to multiple OU nodes with a CONTAINS edge.
#
# Cypher query:
# ```
# MATCH (c:Computer)-[:CONTAINS]-(ou:OU)
# WITH c, COLLECT(ou) as ous
# WHERE SIZE(ous) > 1
# RETURN c, ous
# ```
# This query checks for Computer nodes connected to multiple OU nodes with a CONTAINS edge. If the size of the `ous` collection is greater than 1, it means the rule is satisfied.
#
# By applying these rules and Cypher queries, you can ensure the accuracy, coherence, and schema consistency of the graph data related to Computer nodes.

# %% [markdown]
# ### User

# %%
rules_user = _perform_function(8100, "User", "llama3-70b-8192")

# %%
for rule in rules_user: 
    print(rule)
# Out:
# Based on the provided data, I have identified the following patterns and consistency rules related to the `User` node:
#
# **Consistency Rule 1:** Each `User` node has a unique `neo4jImportId` property.
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE u.neo4jImportId IS NOT UNIQUE
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 2:** Each `User` node has a `displayname` property that is not empty.
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE u.displayname IS NULL OR u.displayname = ''
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 3:** Each `User` node has a `domain` property with a value of "TestCompany.Local".
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE u.domain <> 'TestCompany.Local'
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 4:** Each `User` node has a `name` property that follows the format "FirstnameLastnameXX@TestCompany.Local", where "XX" is a numeric suffix.
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE NOT u.name =~ '([A-Za-z]+)([A-Za-z]+)(\\d+)@(TestCompany\\.Local)$'
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 5:** Each `User` node has an `objectid` property that starts with "S-1-5-21-883232822-274137685-4173207997-".
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE NOT u.objectid STARTS WITH 'S-1-5-21-883232822-274137685-4173207997-'
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 6:** Each `User` node has an edge to a `Group` node with label "0" and edge type "GENERIC_ALL".
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u)-[:GENERIC_ALL]->(:Group {neo4jImportId: 0})
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 7:** Each `User` node has an edge to at least one `Computer` node with edge type "HAS_SESSION".
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u)-[:HAS_SESSION]->(:Computer)
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 8:** Each `User` node has an edge to at least one `Group` node with edge type "MEMBER_OF", and at least one of these groups has a `neo4jImportId` of 2.
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->(:Group) OR NOT (u)-[:MEMBER_OF]->(:Group {neo4jImportId: 2})
# RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 9:** Each `User` node has an edge to an `OU` node with edge type "CONTAINS".
#
# Cypher Query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u)-[:CONTAINS]->(:OU)
# RETURN COUNT(*) AS num_violations
# ```
# These consistency rules and Cypher queries can help ensure that the graph data is accurate, coherent, and follows the expected schema for the `User` node.
# After analyzing the provided data, I have identified several consistency rules related to the `User` node:
#
# **Rule 1: Each User node has a unique `neo4jImportId`**
#
# Description: Each `User` node should have a unique `neo4jImportId` property.
#
# Cypher Query to check for violations: `MATCH (u:User) RETURN count(distinct u.neo4jImportId) AS count, collect(u.neo4jImportId) AS ids`
#
# **Rule 2: Each User node has a `domain` property**
#
# Description: All `User` nodes should have a `domain` property.
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE u.domain IS NULL RETURN count(*) AS count`
#
# **Rule 3: Each User node has a `name` property**
#
# Description: All `User` nodes should have a `name` property.
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE u.name IS NULL RETURN count(*) AS count`
#
# **Rule 4: Each User node has an `objectid` property**
#
# Description: All `User` nodes should have an `objectid` property.
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE u.objectid IS NULL RETURN count(*) AS count`
#
# **Rule 5: Each User node is connected to at least one Group node**
#
# Description: Each `User` node should be connected to at least one `Group` node via a `MEMBER_OF` edge.
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->() RETURN count(*) AS count`
#
# **Rule 6: Each User node has a `pwdlastset` property with a valid timestamp**
#
# Description: All `User` nodes should have a `pwdlastset` property with a valid timestamp (either 0 or a positive integer).
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE u.pwdlastset < 0 AND u.pwdlastset != -1 RETURN count(*) AS count`
#
# **Rule 7: Each User node has an `enabled` property**
#
# Description: All `User` nodes should have an `enabled` property with a boolean value.
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE u.enabled IS NULL RETURN count(*) AS count`
#
# **Rule 8: Each User node is connected to at least one OU node**
#
# Description: Each `User` node should be connected to at least one `OU` node via a `CONTAINS` edge.
#
# Cypher Query to check for violations: `MATCH (u:User) WHERE NOT (u)-[:CONTAINS]->() RETURN count(*) AS count`
#
# These rules can help ensure the data consistency and accuracy of the `User` nodes in the graph.
# Based on the provided data, I've identified several consistency rules related to Node [User]:
#
# **Rule 1: Every User node has a unique `neo4jImportId` property.**
#
# Description: Each User node should have a unique `neo4jImportId` property.
#
# Cypher Query: `MATCH (u:User) WITH u.neo4jImportId AS id, COUNT(*) AS count WHERE count > 1 RETURN id`
#
# **Rule 2: Every User node has a `displayname` property.**
#
# Description: Each User node should have a `displayname` property.
#
# Cypher Query: `MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN u`
#
# **Rule 3: Every User node has a `domain` property with a specific value.**
#
# Description: Each User node should have a `domain` property with a value of "TestCompany.Local".
#
# Cypher Query: `MATCH (u:User) WHERE u.domain <> "TestCompany.Local" RETURN u`
#
# **Rule 4: Every User node has a `name` property in the format "_firstname_lastname@example.com".**
#
# Description: Each User node should have a `name` property in the format "firstname_lastname@example.com".
#
# Cypher Query: `MATCH (u:User) WHERE NOT u.name =~ "^[A-Za-z]+_[A-Za-z]+@[A-Za-z]+\\.Local$" RETURN u`
#
# **Rule 5: Every User node has an `objectid` property with a specific format.**
#
# Description: Each User node should have an `objectid` property with a format of "S-1-5-21-...-...", where "..." are digits.
#
# Cypher Query: `MATCH (u:User) WHERE NOT u.objectid =~ "^S-1-5-21-\\d+-\\d+-\\d+-\\d+$" RETURN u`
#
# **Rule 6: Every User node is connected to exactly one OU node with a CONTAINS edge.**
#
# Description: Each User node should be connected to exactly one OU node with a CONTAINS edge.
#
# Cypher Query: `MATCH (u:User) WITH u, COUNT(DISTINCT u-[:CONTAINS]->(ou:OU)) AS count WHERE count <> 1 RETURN u`
#
# **Rule 7: Every User node is connected to at least one Group node with a MEMBER_OF edge.**
#
# Description: Each User node should be connected to at least one Group node with a MEMBER_OF edge.
#
# Cypher Query: `MATCH (u:User) WHERE NOT EXISTS(u-[:MEMBER_OF]->(g:Group)) RETURN u`
#
# **Rule 8: Every User node has an `enabled` property with a boolean value.**
#
# Description: Each User node should have an `enabled` property with a boolean value.
#
# Cypher Query: `MATCH (u:User) WHERE NOT EXISTS(u.enabled) OR NOT (u.enabled IN [true, false]) RETURN u`
#
# **Rule 9: Every User node has a `pwdlastset` property with a numeric value.**
#
# Description: Each User node should have a `pwdlastset` property with a numeric value.
#
# Cypher Query: `MATCH (u:User) WHERE NOT EXISTS(u.pwdlastset) OR NOT u.pwdlastset IS NUMERIC RETURN u`
#
# Note that these rules are based on the provided data and might not be exhaustive. Additional rules may be necessary to ensure data accuracy and coherence.
# After analyzing the provided data, I've identified several patterns and consistency rules related to the `User` node:
#
# **Rule 1: Each User node must have a unique `neo4jImportId` property**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u1:User), (u2:User) WHERE u1.neo4jImportId = u2.neo4jImportId AND u1 <> u2
# RETURN COUNT(*) AS duplicate_ids
# ```
# **Rule 2: Each User node must have a `domain` property with a value of "TestCompany.Local"**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE u.domain <> "TestCompany.Local"
# RETURN COUNT(*) AS invalid_domains
# ```
# **Rule 3: Each User node must have a `name` property in the format "<displayName>@TestCompany.Local"**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT u.name =~ "<displayName>@TestCompany.Local"
# RETURN COUNT(*) AS invalid_names
# ```
# **Rule 4: Each User node must have an `objectid` property with a value in the format "S-1-5-21-...-..."**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT u.objectid =~ "S-1-5-21-...-..."
# RETURN COUNT(*) AS invalid_objectids
# ```
# **Rule 5: Each User node must have a `displayname` property**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.displayname)
# RETURN COUNT(*) AS missing_displaynames
# ```
# **Rule 6: Each User node must have a `pwdlastset` property**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.pwdlastset)
# RETURN COUNT(*) AS missing_pwdlastset
# ```
# **Rule 7: Each User node must have a `lastlogon` property**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.lastlogon)
# RETURN COUNT(*) AS missing_lastlogon
# ```
# **Rule 8: Each User node must have a `enabled` property with a value of true or false**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.enabled) OR u.enabled NOT IN [true, false]
# RETURN COUNT(*) AS invalid_enabled
# ```
# **Rule 9: Each User node must be connected to a Group node with an edge type GENERIC_ALL and roles {'isacl': True}**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS((u)-[:GENERIC_ALL {roles: {'isacl': True}}]->())
# RETURN COUNT(*) AS missing_generic_all
# ```
# **Rule 10: Each User node may be connected to multiple Group nodes with edge type MEMBER_OF**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]_->())
# RETURN COUNT(*) AS missing_member_of
# ```
# **Rule 11: Each User node must be connected to an OU node with an edge type CONTAINS**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS((u)-[:CONTAINS]->())
# RETURN COUNT(*) AS missing_ou
# ```
# These rules and queries can help ensure the accuracy, coherence, and consistency of the graph data related to the `User` node.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `User` node. Here are the rules I've found, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property**
#
# Description: Each `User` node should have a unique `neo4jImportId` value.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u1:User {neo4jImportId: x}), (u2:User {neo4jImportId: x})
# WHERE u1 <> u2
# RETURN COUNT(*) AS duplicate_count
# ```
# **Rule 2: Each User node has a `displayname` property**
#
# Description: Every `User` node should have a `displayname` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.displayname)
# RETURN COUNT(*) AS missing_displayname_count
# ```
# **Rule 3: Each User node has a `domain` property with a specific value**
#
# Description: All `User` nodes should have a `domain` property with a value of `TestCompany.Local`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE u.domain <> 'TestCompany.Local'
# RETURN COUNT(*) AS invalid_domain_count
# ```
# **Rule 4: Each User node is connected to a Group node with a GENERIC_ALL edge**
#
# Description: Every `User` node should have a connection to a `Group` node with an edge labeled `GENERIC_ALL` and a property `roles` with a value of `{'isacl': True}`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS((u)-[:GENERIC_ALL {roles: {'isacl': True}}]->(:Group))
# RETURN COUNT(*) AS missing_generic_all_count
# ```
# **Rule 5: Each User node is connected to an OU node with a CONTAINS edge**
#
# Description: Every `User` node should have a connection to an `OU` node with an edge labeled `CONTAINS` and no properties.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS((u)-[:CONTAINS]->(:OU))
# RETURN COUNT(*) AS missing_ou_count
# ```
# **Rule 6: Each User node has a `pwdlastset` property with a valid value**
#
# Description: All `User` nodes should have a `pwdlastset` property with a value that is either an integer or `-1`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.pwdlastset IS INTEGER OR u.pwdlastset = -1)
# RETURN COUNT(*) AS invalid_pwdlastset_count
# ```
# These rules and queries can help identify inconsistencies in the graph data related to the `User` node.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the node "User". Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every User node has a unique `neo4jImportId` property.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) RETURN COUNT(DISTINCT u.neo4jImportId) AS count
# ```
# If the count is not equal to the total number of User nodes, it indicates duplicate `neo4jImportId` values.
#
# **Rule 2: Every User node has a `displayname` property.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE u.displayname IS NULL RETURN COUNT(*) AS count
# ```
# If the count is greater than 0, it indicates User nodes without a `displayname` property.
#
# **Rule 3: Every User node has a `domain` property with a value of "TestCompany.Local".**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE u.domain <> "TestCompany.Local" RETURN COUNT(*) AS count
# ```
# If the count is greater than 0, it indicates User nodes with a different `domain` value.
#
# **Rule 4: Every User node has a `name` property in the format "<displayName>@TestCompany.Local".**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT u.name STARTS WITH u.displayname + "@" + u.domain RETURN COUNT(*) AS count
# ```
# If the count is greater than 0, it indicates User nodes with a `name` property not following the expected format.
#
# **Rule 5: Every User node has an `enabled` property with a value of true.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT u.enabled RETURN COUNT(*) AS count
# ```
# If the count is greater than 0, it indicates User nodes with an `enabled` property set to false.
#
# **Rule 6: Every User node is connected to at least one Group node with an edge of type MEMBER_OF.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->() RETURN COUNT(*) AS count
# ```
# If the count is greater than 0, it indicates User nodes not connected to any Group node with a MEMBER_OF edge.
#
# **Rule 7: Every User node is connected to at most one OU node with an edge of type CONTAINS.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE (u)-[:CONTAINS]->() WITH COUNT(*) AS count WHERE count > 1 RETURN COUNT(*) AS multi_connections
# ```
# If the count is greater than 0, it indicates User nodes connected to multiple OU nodes with a CONTAINS edge.
#
# These consistency rules and Cypher queries help ensure that the graph data is accurate, coherent, and follows the expected schema.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the `User` node. Here are the rules I've found, along with the corresponding Cypher queries to check for violations:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property.**
#
# Cypher query: `MATCH (u:User) WITH u.neo4jImportId AS id, COUNT(*) AS count WHERE count > 1 RETURN id`
#
# This query checks if there are any duplicate `neo4jImportId` values across multiple `User` nodes.
#
# **Rule 2: Each User node has a `displayname` property.**
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN u`
#
# This query returns any `User` nodes that are missing the `displayname` property.
#
# **Rule 3: Each User node has a `domain` property with a value of "TestCompany.Local".**
#
# Cypher query: `MATCH (u:User) WHERE u.domain <> "TestCompany.Local" RETURN u`
#
# This query returns any `User` nodes with a `domain` property value that is not "TestCompany.Local".
#
# **Rule 4: Each User node has a `name` property in the format "FirstnameLastnameXX@TestCompany.Local", where XX is a number.**
#
# Cypher query: `MATCH (u:User) WHERE NOT u.name =~ "^[A-Za-z]+[A-Za-z]+[0-9]+@TestCompany\\.Local$" RETURN u`
#
# This query returns any `User` nodes with a `name` property value that does not match the expected format.
#
# **Rule 5: Each User node has an `objectid` property in the format "S-1-5-21-...-XXXX", where XXXX is a number.**
#
# Cypher query: `MATCH (u:User) WHERE NOT u.objectid =~ "S-1-5-21-[0-9]+-[0-9]+$" RETURN u`
#
# This query returns any `User` nodes with an `objectid` property value that does not match the expected format.
#
# **Rule 6: Each User node is connected to at least one Group node with a MEMBER_OF edge.**
#
# Cypher query: `MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->() RETURN u`
#
# This query returns any `User` nodes that are not connected to at least one `Group` node with a `MEMBER_OF` edge.
#
# **Rule 7: Each User node is connected to at most one OU node with a CONTAINS edge.**
#
# Cypher query: `MATCH (u:User) WHERE (u)-[:CONTAINS]->() WITH u, COUNT(*) AS count WHERE count > 1 RETURN u`
#
# This query returns any `User` nodes that are connected to more than one `OU` node with a `CONTAINS` edge.
#
# These consistency rules and queries can help ensure that the graph data is accurate and follows the expected schema for `User` nodes.
# Based on the provided data, I've identified several patterns and consistency rules related to the `User` node. For each rule, I'll provide a clear description and the corresponding Cypher query to check for violations.
#
# **Rule 1: Each User has a unique `neo4jImportId`**
# Description: Each `User` node should have a unique `neo4jImportId` property.
# Cypher Query: `MATCH (u:User) RETURN count(DISTINCT u.neo4jImportId) <> count(u) AS unique_import_ids`
#
# **Rule 2: Each User has a `displayname` and `name` property**
# Description: Each `User` node should have both `displayname` and `name` properties.
# Cypher Query: `MATCH (u:User) WHERE NOT EXISTS(u.displayname) OR NOT EXISTS(u.name) RETURN u`
#
# **Rule 3: Each User is connected to at least one Group with a `MEMBER_OF` edge**
# Description: Each `User` node should be connected to at least one `Group` node with a `MEMBER_OF` edge.
# Cypher Query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]-()) RETURN u`
#
# **Rule 4: Each User is connected to at most one OU with a `CONTAINS` edge**
# Description: Each `User` node should be connected to at most one `OU` node with a `CONTAINS` edge.
# Cypher Query: `MATCH (u:User) WHERE size((u)-[:CONTAINS]-()) > 1 RETURN u`
#
# **Rule 5: Each User has a `domain` property with a specific format**
# Description: Each `User` node should have a `domain` property with a format like `TestCompany.Local`.
# Cypher Query: `MATCH (u:User) WHERE NOT u.domain =~ '^.+\\..+$' RETURN u`
#
# **Rule 6: Each User has a `pwdlastset` property with a valid timestamp**
# Description: Each `User` node should have a `pwdlastset` property with a valid timestamp (integer value).
# Cypher Query: `MATCH (u:User) WHERE NOT u.pwdlastset =~ '^-?\\d+$' RETURN u`
#
# **Rule 7: Each User has an `enabled` property with a boolean value**
# Description: Each `User` node should have an `enabled` property with a boolean value.
# Cypher Query: `MATCH (u:User) WHERE NOT u.enabled IN [true, false] RETURN u`
#
# **Rule 8: Each User has an `objectid` property with a valid format**
# Description: Each `User` node should have an `objectid` property with a format like `S-1-5-21-883232822-274137685-4173207997-1365`.
# Cypher Query: `MATCH (u:User) WHERE NOT u.objectid =~ '^S-1-5-21-.+$' RETURN u`
#
# These rules and Cypher queries can help identify inconsistencies and errors in the `User` node data. You can use these queries to detect violations and take corrective action to ensure the accuracy and coherence of your graph data.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the Node [User]. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every User node has a `neo4jImportId` property**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.neo4jImportId) RETURN u`
#
# **Rule 2: Every User node has a `displayname` property**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN u`
#
# **Rule 3: Every User node has a `domain` property with a value of "TestCompany.Local"**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.domain) OR u.domain <> "TestCompany.Local" RETURN u`
#
# **Rule 4: Every User node has a `name` property in the format "Username@Domain"**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.name) OR NOT u.name =~ "^[^@]+@TestCompany\\.Local$" RETURN u`
#
# **Rule 5: Every User node has an `objectid` property with a value in the format "S-1-5-21-...-..."**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.objectid) OR NOT u.objectid =~ "^S-1-5-21-.+$" RETURN u`
#
# **Rule 6: Every User node is connected to exactly one node [Group] with an edge GENERIC_ALL and a role 'isacl'**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:GENERIC_ALL {roles: {isacl: true}}]->(:Group)) RETURN u`
#
# **Rule 7: Every User node is connected to at least one node [Group] with an edge MEMBER_OF**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->(:Group)) RETURN u`
#
# **Rule 8: Every User node is connected to exactly one node [OU] with an edge CONTAINS**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:CONTAINS]->(:OU)) RETURN u`
#
# **Rule 9: Every User node has a `enabled` property with a value of true or false**
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.enabled) OR u.enabled NOT IN [true, false] RETURN u`
#
# These rules aim to ensure the consistency of the User node properties and their relationships with other nodes in the graph.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `User` node:
#
# **Rule 1:** Every `User` node has a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT(u.neo4jImportId IS UNIQUE) RETURN u
# ```
# **Rule 2:** Every `User` node has a `domain` property with value "TestCompany.Local".
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE u.domain != "TestCompany.Local" RETURN u
# ```
# **Rule 3:** Every `User` node has a `enabled` property with value `true`.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT(u.enabled = true) RETURN u
# ```
# **Rule 4:** Every `User` node has an `objectid` property with a value in the format "S-1-5-21-...-138x", where x is a unique identifier.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT(u.objectid STARTS WITH "S-1-5-21-") OR LENGTH(u.objectid) <> 36 RETURN u
# ```
# **Rule 5:** Every `User` node has at least one connection to a `Group` node with an edge type `GENERIC_ALL` and roles `{'isacl': True}`.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT((u)-[:GENERIC_ALL {roles: {'isacl': true}}]->()) RETURN u
# ```
# **Rule 6:** Every `User` node has at most one connection to an `OU` node with an edge type `CONTAINS`.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE size((u)-[:CONTAINS]->()) > 1 RETURN u
# ```
# These rules can be used to ensure the consistency and accuracy of the graph data.
# Based on the provided data, I've identified some patterns and inferred consistency rules related to the node `User`. Here are the rules I've identified, along with corresponding Cypher queries to check for violations:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u1:User {neo4jImportId: x}), (u2:User {neo4jImportId: x})
# WHERE u1 <> u2
# RETURN u1, u2
# ```
# This query will return any duplicate `neo4jImportId` values, indicating a violation of this rule.
#
# **Rule 2: Each User node has a `domain` property with a value of "TestCompany.Local".**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)
# WHERE u.domain <> "TestCompany.Local"
# RETURN u
# ```
# This query will return any User nodes with a `domain` property that doesn't match the expected value.
#
# **Rule 3: Each User node has an `enabled` property with a value of true.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)
# WHERE NOT u.enabled
# RETURN u
# ```
# This query will return any User nodes with an `enabled` property that is false.
#
# **Rule 4: Each User node has an `objectid` property that matches the pattern "S-1-5-21-..."**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)
# WHERE NOT u.objectid STARTS WITH "S-1-5-21-"
# RETURN u
# ```
# This query will return any User nodes with an `objectid` property that doesn't match the expected pattern.
#
# **Rule 5: Each User node is connected to at least one Group node with an edge labeled "MEMBER_OF".**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)
# WHERE NOT (u)-[:MEMBER_OF]->()
# RETURN u
# ```
# This query will return any User nodes that are not connected to a Group node with an edge labeled "MEMBER_OF".
#
# **Rule 6: Each User node is connected to exactly one OU node with an edge labeled "CONTAINS".**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)
# WHERE (u)-[:CONTAINS]->()<-[:CONTAINS]-(u)
# RETURN u
# ```
# This query will return any User nodes that are connected to more than one OU node with an edge labeled "CONTAINS".
#
# **Rule 7: Each User node has a `displayname` property with a value that is not empty.**
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User)
# WHERE u.displayname = ""
# RETURN u
# ```
# This query will return any User nodes with an empty `displayname` property.
#
# These consistency rules and corresponding Cypher queries can help ensure the accuracy, coherence, and schema adherence of the graph data related to User nodes.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the Node [User]. Here are the rules I've found, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Each User node has at least one edge to a Group node with the MEMBER_OF relationship**
#
# Description: Every User node is expected to be a member of at least one Group node.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT ()-[:MEMBER_OF]->() RETURN u
# ```
# This query finds User nodes that do not have any MEMBER_OF relationships to Group nodes.
#
# **Rule 2: Each User node has at most one edge to a Group node with the GENERIC_ALL relationship**
#
# Description: A User node can have at most one GENERIC_ALL relationship to a Group node.
#
# Cypher Query:
# ```cypher
# MATCH (u:User)-[:GENERIC_ALL]->(g:Group) WITH u, COUNT(g) as count WHERE count > 1 RETURN u
# ```
# This query finds User nodes that have more than one GENERIC_ALL relationship to Group nodes.
#
# **Rule 3: Each User node has exactly one edge to an OU node with the CONTAINS relationship**
#
# Description: Every User node is expected to be contained in exactly one OU node.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT ((u)-[:CONTAINS]->(:OU)) OR ((u)-[:CONTAINS]->() |> 1) RETURN u
# ```
# This query finds User nodes that either do not have any CONTAINS relationships to OU nodes or have more than one CONTAINS relationship.
#
# **Rule 4: Each User node has a unique objectid property**
#
# Description: The objectid property of a User node should be unique across all User nodes.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WITH u.objectid as oid, COUNT(u) as count WHERE count > 1 RETURN oid
# ```
# This query finds objectid values that are not unique across all User nodes.
#
# **Rule 5: Each User node has a valid domain property**
#
# Description: The domain property of a User node should be a valid domain (e.g., TestCompany.Local).
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT u.domain =~ '^[a-zA-Z0-9.-]+\.[a-zA-Z0-9.-]+$' RETURN u
# ```
# This query finds User nodes with domain properties that do not match the expected format.
#
# **Rule 6: Each User node has a valid name property**
#
# Description: The name property of a User node should be a valid username (e.g., WinterLawall104@TestCompany.Local).
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT u.name =~ '^[a-zA-Z0-9.-]+@[a-zA-Z0-9.-]+$' RETURN u
# ```
# This query finds User nodes with name properties that do not match the expected format.
#
# These rules and queries can help ensure the accuracy, coherence, and consistency of the graph data related to User nodes.
# After analyzing the provided data, I've identified the following patterns and consistency rules related to node `User`:
#
# **Consistency Rule 1:** Every `User` node has a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u.neo4jImportId IS UNIQUE) RETURN COUNT(DISTINCT u.neo4jImportId) AS num_unique_import_ids
# ```
# **Consistency Rule 2:** Every `User` node has properties `owned`, `displayname`, `pwdlastset`, `domain`, `lastlogon`, `name`, `enabled`, and `objectid`.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT exists(u.owned) OR NOT exists(u.displayname) OR NOT exists(u.pwdlastset) OR NOT exists(u.domain) OR NOT exists(u.lastlogon) OR NOT exists(u.name) OR NOT exists(u.enabled) OR NOT exists(u.objectid) RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 3:** Every `User` node is connected to at least one `Group` node with an `MEMBER_OF` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->() RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 4:** Every `User` node is connected to exactly one `OU` node with a `CONTAINS` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WITH u, size((u)-[:CONTAINS]->()) AS num_ous WHERE num_ous != 1 RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 5:** Every `User` node is connected to at most one `Computer` node with a `HAS_SESSION` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WITH u, size((u)-[:HAS_SESSION]->()) AS num_computers WHERE num_computers > 1 RETURN COUNT(*) AS num_violations
# ```
# **Consistency Rule 6:** Every `User` node is connected to the `Group` node with `neo4jImportId` equal to 0 with a `GENERIC_ALL` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User) WHERE NOT (u)-[:GENERIC_ALL {roles: {'isacl': true}}]->(:Group {neo4jImportId: 0}) RETURN COUNT(*) AS num_violations
# ```
# These consistency rules and Cypher queries can be used to detect and prevent data inconsistencies in the graph database.
# Based on the provided data, I've identified some patterns and consistency rules related to the node `User`. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1:** A `User` node should have a unique `neo4jImportId`.
#
# Cypher query to check for violations:
# ```
# MATCH (u1:User {neo4jImportId: x})
# MATCH (u2:User {neo4jImportId: x})
# WHERE u1 <> u2
# RETURN COUNT(*)
# ```
# This query checks if there are multiple `User` nodes with the same `neo4jImportId`. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 2:** A `User` node should have a `displayname`, `pwdlastset`, `domain`, `lastlogon`, `name`, `enabled`, and `objectid` property.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User)
# WHERE NOT EXISTS(u.displayname) OR
#       NOT EXISTS(u.pwdlastset) OR
#       NOT EXISTS(u.domain) OR
#       NOT EXISTS(u.lastlogon) OR
#       NOT EXISTS(u.name) OR
#       NOT EXISTS(u.enabled) OR
#       NOT EXISTS(u.objectid)
# RETURN COUNT(*)
# ```
# This query checks if any `User` node is missing any of the required properties. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 3:** A `User` node should be connected to at least one `Group` node with an `MEMBER_OF` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User)
# WHERE NOT EXISTS((u)-[:MEMBER_OF]->(g:Group))
# RETURN COUNT(*)
# ```
# This query checks if any `User` node is not connected to a `Group` node with an `MEMBER_OF` edge. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 4:** A `User` node should be connected to exactly one `OU` node with a `CONTAINS` edge.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User)
# WHERE NOT EXISTS((u)-[:CONTAINS]->(ou:OU)) OR
#       EXISTS((u)-[:CONTAINS]->(ou1:OU)) AND EXISTS((u)-[:CONTAINS]->(ou2:OU)) AND ou1 <> ou2
# RETURN COUNT(*)
# ```
# This query checks if any `User` node is not connected to an `OU` node with a `CONTAINS` edge or if it is connected to more than one `OU` node with a `CONTAINS` edge. If the count is greater than 0, it indicates a violation of this rule.
#
# **Rule 5:** A `User` node should have an edge with a `GENERIC_ALL` role to a `Group` node with id 0.
#
# Cypher query to check for violations:
# ```
# MATCH (u:User)
# WHERE NOT EXISTS((u)-[:GENERIC_ALL {roles: {isacl: true}}]->(g:Group {id: 0}))
# RETURN COUNT(*)
# ```
# This query checks if any `User` node is not connected to a `Group` node with id 0 and an edge with a `GENERIC_ALL` role and `isacl` property. If the count is greater than 0, it indicates a violation of this rule.
#
# By running these Cypher queries, you can identify any inconsistencies or violations of these rules in your graph data.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `User` node. Here are the rules, along with corresponding Cypher queries to check for violations:
#
# **Rule 1:** Each `User` node has a unique `neo4jImportId`.
#
# Cypher query: `MATCH (u1:User), (u2:User) WHERE u1.neo4jImportId = u2.neo4jImportId AND u1 <> u2 RETURN COUNT(u1)`
#
# This query checks if there are any duplicate `neo4jImportId` values among `User` nodes.
#
# **Rule 2:** Each `User` node has a `domain` property with the value "TestCompany.Local".
#
# Cypher query: `MATCH (u:User) WHERE u.domain <> "TestCompany.Local" RETURN COUNT(u)`
#
# This query checks if all `User` nodes have the correct domain value.
#
# **Rule 3:** Each `User` node has an `enabled` property with a boolean value (true or false).
#
# Cypher query: `MATCH (u:User) WHERE NOT (u.enabled IS BOOLEAN) RETURN COUNT(u)`
#
# This query checks if all `User` nodes have a boolean `enabled` property.
#
# **Rule 4:** Each `User` node has a `name` property with a string value in the format "<Firstname><Lastname><number>@TestCompany.Local".
#
# Cypher query: `MATCH (u:User) WHERE NOT (u.name =~ "^([A-Za-z]+) ([A-Za-z]+)\\d+@TestCompany.Local$") RETURN COUNT(u)`
#
# This query checks if all `User` nodes have a correctly formatted `name` property.
#
# **Rule 5:** Each `User` node has a unique `objectid` property.
#
# Cypher query: `MATCH (u1:User), (u2:User) WHERE u1.objectid = u2.objectid AND u1 <> u2 RETURN COUNT(u1)`
#
# This query checks if there are any duplicate `objectid` values among `User` nodes.
#
# **Rule 6:** Each `User` node is connected to exactly one `Group` node with an `edge GENERIC_ALL` and `roles` property `{'isacl': True}`.
#
# Cypher query: `MATCH (u:User)-[r:GENERIC_ALL]-(g:Group) WHERE NOT (r.roles = {'isacl': True}) RETURN COUNT(u)`
#
# This query checks if all `User` nodes have the correct `GENERIC_ALL` edge and `roles` property.
#
# **Rule 7:** Each `User` node is connected to at least one `Group` node with an `edge MEMBER_OF`.
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS ((u)-[:MEMBER_OF]-(:Group)) RETURN COUNT(u)`
#
# This query checks if all `User` nodes are connected to at least one `Group` node via a `MEMBER_OF` edge.
#
# **Rule 8:** Each `User` node is connected to exactly one `OU` node with an `edge CONTAINS`.
#
# Cypher query: `MATCH (u:User)-[r:CONTAINS]-(ou:OU) WITH u, COUNT(r) AS count RETURN u WHERE count > 1`
#
# This query checks if all `User` nodes are connected to exactly one `OU` node via a `CONTAINS` edge.
#
# These rules and queries can help ensure the consistency and accuracy of the graph data related to `User` nodes.
# Based on the provided data, I've identified several consistency rules related to the `User` node:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property**
#
# * Description: Each `User` node should have a unique `neo4jImportId` property to ensure that each user is identified correctly.
# * Cypher query to check for violations: `MATCH (u:User) WHERE u.neo4jImportId IS NOT UNIQUE RETURN COUNT(*)`
#
# **Rule 2: Each User node has a `displayname` property**
#
# * Description: Each `User` node should have a `displayname` property to provide a human-readable name for the user.
# * Cypher query to check for violations: `MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN COUNT(*)`
#
# **Rule 3: Each User node has a `domain` property with a specific value**
#
# * Description: Each `User` node should have a `domain` property with a value of "TestCompany.Local" to ensure consistency across the graph.
# * Cypher query to check for violations: `MATCH (u:User) WHERE u.domain <> "TestCompany.Local" RETURN COUNT(*)`
#
# **Rule 4: Each User node has a `lastlogon` property**
#
# * Description: Each `User` node should have a `lastlogon` property to track the user's last login time.
# * Cypher query to check for violations: `MATCH (u:User) WHERE NOT EXISTS(u.lastlogon) RETURN COUNT(*)`
#
# **Rule 5: Each User node has an `enabled` property with a boolean value**
#
# * Description: Each `User` node should have an `enabled` property with a boolean value (true or false) to indicate the user's account status.
# * Cypher query to check for violations: `MATCH (u:User) WHERE NOT EXISTS(u.enabled) OR NOT (u.enabled IN [true, false]) RETURN COUNT(*)`
#
# **Rule 6: Each User node has an `objectid` property**
#
# * Description: Each `User` node should have an `objectid` property with a unique identifier to link to external systems.
# * Cypher query to check for violations: `MATCH (u:User) WHERE NOT EXISTS(u.objectid) RETURN COUNT(*)`
#
# **Rule 7: Each User node has a connection to a Group node with a MEMBER_OF edge**
#
# * Description: Each `User` node should have at least one connection to a `Group` node with a MEMBER_OF edge to indicate group membership.
# * Cypher query to check for violations: `MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->(:Group)) RETURN COUNT(*)`
#
# **Rule 8: Each User node has a connection to an OU node with a CONTAINS edge**
#
# * Description: Each `User` node should have a connection to an `OU` node with a CONTAINS edge to indicate organizational unit membership.
# * Cypher query to check for violations: `MATCH (u:User) WHERE NOT EXISTS((u)-[:CONTAINS]->(:OU)) RETURN COUNT(*)`
#
# By running these Cypher queries, you can identify any inconsistencies in the graph data related to the `User` node and take corrective actions to ensure data accuracy and coherence.
# After analyzing the data, I've identified the following patterns and consistency rules related to the node `User`:
#
# **Consistency Rule 1: Unique `neo4jImportId`**
# Each `User` node has a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u1:User), (u2:User) WHERE u1.neo4jImportId = u2.neo4jImportId AND u1 <> u2 RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 2: Mandatory properties**
# Each `User` node has the following mandatory properties: `owned`, `displayname`, `domain`, `lastlogon`, `name`, `enabled`, and `objectid`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.owned IS NOT NULL AND u.displayname IS NOT NULL AND u.domain IS NOT NULL AND u.lastlogon IS NOT NULL AND u.name IS NOT NULL AND u.enabled IS NOT NULL AND u.objectid IS NOT NULL) RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 3: `enabled` property is Boolean**
# The `enabled` property of each `User` node is a Boolean value.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.enabled = true OR u.enabled = false) RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 4: `domain` property is a string**
# The `domain` property of each `User` node is a string value.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.domain IS STRING) RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 5: `lastlogon` property is a numeric value**
# The `lastlogon` property of each `User` node is a numeric value.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.lastlogon IS NUMBER) RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 6: `pwdlastset` property is a numeric value**
# The `pwdlastset` property of each `User` node is a numeric value.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.pwdlastset IS NUMBER) RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 7: Edges to `Group` nodes**
# Each `User` node has at least one edge to a `Group` node with an edge type of `MEMBER_OF`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->(:Group) RETURN COUNT(*) > 0 AS violation
# ```
# **Consistency Rule 8: Edges to `OU` nodes**
# Each `User` node has at least one edge to an `OU` node with an edge type of `CONTAINS`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u)-[:CONTAINS]->(:OU) RETURN COUNT(*) > 0 AS violation
# ```
# These consistency rules can help identify potential issues with the graph data and ensure that it conforms to the expected schema.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the node `User`. Here are the rules, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property**
#
# Description: Each User node should have a unique `neo4jImportId` property to ensure data integrity.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) RETURN COUNT(DISTINCT u.neo4jImportId) AS unique_import_ids
# ```
# Expected result: `unique_import_ids` should be equal to the number of User nodes.
#
# **Rule 2: Each User node has a `domain` property with a specific format**
#
# Description: Each User node should have a `domain` property with a specific format, such as `TestCompany.Local`.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT u.domain =~ '^[a-zA-Z0-9]+\\.[a-zA-Z0-9]+$' RETURN count(u)
# ```
# Expected result: The query should return 0, indicating no User nodes with malformed `domain` properties.
#
# **Rule 3: Each User node has a `name` property with a specific format**
#
# Description: Each User node should have a `name` property with a specific format, such as `Username@TestCompany.Local`.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT u.name =~ '^[a-zA-Z0-9]+@[a-zA-Z0-9]+\\.[a-zA-Z0-9]+$' RETURN count(u)
# ```
# Expected result: The query should return 0, indicating no User nodes with malformed `name` properties.
#
# **Rule 4: Each User node is connected to at least one Group node with a `MEMBER_OF` edge**
#
# Description: Each User node should be connected to at least one Group node with a `MEMBER_OF` edge.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->() RETURN count(u)
# ```
# Expected result: The query should return 0, indicating all User nodes have at least one `MEMBER_OF` edge to a Group node.
#
# **Rule 5: Each User node is connected to exactly one OU node with a `CONTAINS` edge**
#
# Description: Each User node should be connected to exactly one OU node with a `CONTAINS` edge.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WITH u, COUNT((u)-[:CONTAINS]->()) AS ou_count WHERE ou_count <> 1 RETURN count(u)
# ```
# Expected result: The query should return 0, indicating all User nodes have exactly one `CONTAINS` edge to an OU node.
#
# **Rule 6: Each User node has a `enabled` property with a boolean value**
#
# Description: Each User node should have a `enabled` property with a boolean value.
#
# Cypher Query:
# ```cypher
# MATCH (u:User) WHERE NOT (u.enabled = true OR u.enabled = false) RETURN count(u)
# ```
# Expected result: The query should return 0, indicating all User nodes have a valid `enabled` property.
#
# These consistency rules and Cypher queries can help ensure the accuracy and coherence of the graph data related to the User node.
# After analyzing the provided data, I've identified some patterns and inferred consistency rules related to the `User` node. Here are the rules and their corresponding Cypher queries to check for violations:
#
# **Rule 1: Every User node has a `displayname` property**
#
# * Description: Ensure that every User node has a `displayname` property with a non-empty value.
# * Cypher query: `MATCH (u:User) WHERE u.displayname IS NULL OR u.displayname = "" RETURN u`
#
# **Rule 2: Every User node has a unique `name` property**
#
# * Description: Ensure that every User node has a unique `name` property.
# * Cypher query: `MATCH (u1:User), (u2:User) WHERE u1 <> u2 AND u1.name = u2.name RETURN u1, u2`
#
# **Rule 3: Every User node has a valid `domain` property**
#
# * Description: Ensure that every User node has a `domain` property with a non-empty value, and the value is either "TestCompany.Local" or another valid domain.
# * Cypher query: `MATCH (u:User) WHERE u.domain IS NULL OR u.domain = "" OR NOT u.domain STARTS WITH "TestCompany.Local" RETURN u`
#
# **Rule 4: Every User node has a valid `objectid` property**
#
# * Description: Ensure that every User node has an `objectid` property with a non-empty value, and the value follows the format "S-1-5-21-<numbers>-<numbers>-<numbers>-<number>".
# * Cypher query: `MATCH (u:User) WHERE u.objectid IS NULL OR u.objectid = "" OR NOT u.objectid STARTS WITH "S-1-5-21-" RETURN u`
#
# **Rule 5: Every User node is connected to a Group node with a GENERIC_ALL edge**
#
# * Description: Ensure that every User node is connected to a Group node with a GENERIC_ALL edge.
# * Cypher query: `MATCH (u:User) WHERE NOT (u)-[:GENERIC_ALL]->(:Group) RETURN u`
#
# **Rule 6: Every User node is connected to an OU node with a CONTAINS edge**
#
# * Description: Ensure that every User node is connected to an OU node with a CONTAINS edge.
# * Cypher query: `MATCH (u:User) WHERE NOT (u)-[:CONTAINS]->(:OU) RETURN u`
#
# **Rule 7: Enabled Users should have a valid `pwdlastset` property**
#
# * Description: Ensure that enabled User nodes have a valid `pwdlastset` property with a non-negative value.
# * Cypher query: `MATCH (u:User {enabled: true}) WHERE u.pwdlastset IS NULL OR u.pwdlastset < 0 RETURN u`
#
# These rules and queries can help identify inconsistencies in the graph data and ensure that the schema is followed correctly.
# Based on the provided data, I've identified some patterns and consistency rules related to the `User` node:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property**
#
# Consistency rule: Every `User` node should have a unique `neo4jImportId` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u1:User {neo4jImportId: x}), (u2:User {neo4jImportId: x})
# WHERE u1 <> u2
# RETURN u1, u2
# ```
# **Rule 2: Each User node has a `displayname` property**
#
# Consistency rule: Every `User` node should have a `displayname` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN u
# ```
# **Rule 3: Each User node has a `domain` property with value `TestCompany.Local`**
#
# Consistency rule: Every `User` node should have a `domain` property with value `TestCompany.Local`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE u.domain <> 'TestCompany.Local' RETURN u
# ```
# **Rule 4: Each User node has an `enabled` property with value `True` or `False`**
#
# Consistency rule: Every `User` node should have an `enabled` property with value `True` or `False`.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT (u.enabled = true OR u.enabled = false) RETURN u
# ```
# **Rule 5: Each User node has an `objectid` property**
#
# Consistency rule: Every `User` node should have an `objectid` property.
#
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.objectid) RETURN u
# ```
# ...
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:GENERIC_ALL {roles: {'isacl': True}}]->()) RETURN COUNT(*) AS count_missing_generic_all`
#
# **Rule 8: Every User node is connected to at least one Group node with an edge label `MEMBER_OF`.**
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->()) RETURN COUNT(*) AS count_missing_member_of`
#
# **Rule 9: Every User node is connected to an OU node with an edge label `CONTAINS`.**
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:CONTAINS]->()) RETURN COUNT(*) AS count_missing_ou`
#
# Note that these rules are based on the provided data and might not be exhaustive. Additional rules might be necessary to ensure the accuracy and coherence of the graph data.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `User` node:
#
# **Rules:**
#
# 1. **Each User node has a unique `neo4jImportId`**: Every `User` node has a unique `neo4jImportId` property.
# Cypher query to check for violations:
# ```cypher
# MATCH (u1:User), (u2:User) WHERE u1.neo4jImportId = u2.neo4jImportId AND u1 <> u2 RETURN u1, u2
# ```
# 2. **Each User node has a `displayname` property**: Every `User` node has a `displayname` property.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN u
# ```
# 3. **Each User node has a `domain` property**: Every `User` node has a `domain` property.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.domain) RETURN u
# ```
# 4. **Each User node has an `enabled` property**: Every `User` node has an `enabled` property.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.enabled) RETURN u
# ```
# 5. **Each User node has an `objectid` property**: Every `User` node has an `objectid` property.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS(u.objectid) RETURN u
# ```
# 6. **Each User node is connected to at least one Group node with a MEMBER_OF edge**: Every `User` node is connected to at least one `Group` node with a `MEMBER_OF` edge.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->(:Group)) RETURN u
# ```
# 7. **Each User node is connected to exactly one OU node with a CONTAINS edge**: Every `User` node is connected to exactly one `OU` node with a `CONTAINS` edge.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE size((u)-[:CONTAINS]->(:OU)) <> 1 RETURN u
# ```
# 8. **Each User node has at most one GENERIC_ALL edge to a Group node**: Every `User` node has at most one `GENERIC_ALL` edge to a `Group` node.
# Cypher query to check for violations:
# ```cypher
# MATCH (u:User) WHERE size((u)-[:GENERIC_ALL]->(:Group)) > 1 RETURN u
# ```
#
# These rules can help ensure the accuracy and coherence of the graph data related to `User` nodes.
# Based on the provided data, I've identified several patterns and consistency rules related to the Node [User]:
#
# **Rule 1: Each User node has a unique neo4jImportId**
#
# Description: Each User node should have a unique neo4jImportId property.
#
# Cypher Query: `MATCH (u:User) RETURN count(DISTINCT u.neo4jImportId) = count(u) AS valid`
#
# **Rule 2: Each User node has an enabled property set to True**
#
# Description: Each User node should have an enabled property set to True.
#
# Cypher Query: `MATCH (u:User) WHERE u.enabled = False RETURN count(u) = 0 AS valid`
#
# **Rule 3: Each User node has a domain property set to "TestCompany.Local"**
#
# Description: Each User node should have a domain property set to "TestCompany.Local".
#
# Cypher Query: `MATCH (u:User) WHERE u.domain <> "TestCompany.Local" RETURN count(u) = 0 AS valid`
#
# **Rule 4: Each User node has a generic_all edge to a Group node with id 0**
#
# Description: Each User node should have a generic_all edge to a Group node with id 0.
#
# Cypher Query: `MATCH (u:User) WHERE NOT (u)-[:GENERIC_ALL]->(:Group {id: 0}) RETURN count(u) = 0 AS valid`
#
# **Rule 5: Each User node has at least one MEMBER_OF edge to a Group node**
#
# Description: Each User node should have at least one MEMBER_OF edge to a Group node.
#
# Cypher Query: `MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->(:Group) RETURN count(u) = 0 AS valid`
#
# **Rule 6: Each User node has a CONTAINS edge to an OU node**
#
# Description: Each User node should have a CONTAINS edge to an OU node.
#
# Cypher Query: `MATCH (u:User) WHERE NOT (u)-[:CONTAINS]->(:OU) RETURN count(u) = 0 AS valid`
#
# **Rule 7: Each User node has a HAS_SESSION or EXECUTE_DCOM edge to a Computer node**
#
# Description: Each User node should have a HAS_SESSION or EXECUTE_DCOM edge to a Computer node.
#
# Cypher Query: `MATCH (u:User) WHERE NOT (u)-[:HAS_SESSION|EXECUTE_DCOM]->(:Computer) RETURN count(u) = 0 AS valid`
#
# These rules and queries can help ensure that the graph data is accurate, coherent, and follows the expected schema for User nodes.
# After analyzing the provided data, I've identified some patterns and consistency rules related to the `User` node:
#
# **Consistency Rules:**
#
# 1. **Each User node has a unique `neo4jImportId` property**:
# Cypher query to check for violations: `MATCH (u:User) WHERE NOT(u.neo4jImportId IS UNIQUE) RETURN u`
#
# 2. **Each User node has a `domain` property with a specific format (e.g., "TestCompany.Local")**:
# Cypher query to check for violations: `MATCH (u:User) WHERE NOT(u.domain =~ "^[a-zA-Z0-9.]+\\.[a-zA-Z]{2,}$") RETURN u`
#
# 3. **Each User node has a `name` property with a specific format (e.g., "Username@TestCompany.Local")**:
# Cypher query to check for violations: `MATCH (u:User) WHERE NOT(u.name =~ "^[a-zA-Z0-9._]+@[a-zA-Z0-9.]+$") RETURN u`
#
# 4. **Each User node has an `objectid` property with a specific format (e.g., "S-1-5-21-883232822-274137685-4173207997-1563")**:
# Cypher query to check for violations: `MATCH (u:User) WHERE NOT(u.objectid =~ "S-1-5-[0-9-]+") RETURN u`
#
# 5. **Each User node is connected to at least one Group node with an edge type "GENERIC_ALL"**:
# Cypher query to check for violations: `MATCH (u:User) WHERE NOT(u)-[:GENERIC_ALL]->() RETURN u`
#
# 6. **Each User node is connected to at least one OU node with an edge type "CONTAINS"**:
# Cypher query to check for violations: `MATCH (u:User) WHERE NOT(u)-[:CONTAINS]->() RETURN u`
#
# 7. ** Each User node has either a `pwdlastset` property with a value greater than -1 or a `lastlogon` property with a value greater than -1**:
# Cypher query to check for violations: `MATCH (u:User) WHERE (u.pwdlastset = -1 AND u.lastlogon = -1) RETURN u`
#
# These consistency rules ensure that the data adheres to certain expected formats and structures, which can help maintain data accuracy and coherence.
#
# Please note that these rules might not be exhaustive, and additional rules might be necessary depending on the specific requirements of your graph data.
# Based on the provided data, I've identified some patterns and inferred consistency rules related to the `User` node. For each rule, I've provided a clear description and a corresponding Cypher query to check for violations of that rule in the dataset.
#
# **Rule 1: Each User node has a unique `neo4jImportId` property**
#
# Description: Each User node should have a unique `neo4jImportId` property to identify it uniquely.
#
# Cypher query: `MATCH (u:User) WITH u.neo4jImportId AS id, COUNT(*) AS count WHERE count > 1 RETURN id, count`
#
# **Rule 2: Each User node has a `displayname` property**
#
# Description: Each User node should have a `displayname` property to store the user's display name.
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.displayname) RETURN u.neo4jImportId`
#
# **Rule 3: Each User node has a `domain` property**
#
# Description: Each User node should have a `domain` property to store the user's domain.
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.domain) RETURN u.neo4jImportId`
#
# **Rule 4: Each User node has an `objectid` property**
#
# Description: Each User node should have an `objectid` property to store the user's object ID.
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.objectid) RETURN u.neo4jImportId`
#
# **Rule 5: Each User node is connected to at least one `Group` node with an edge type `MEMBER_OF`**
#
# Description: Each User node should be connected to at least one Group node with an edge type `MEMBER_OF` to represent the user's group membership.
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->(:Group)) RETURN u.neo4jImportId`
#
# **Rule 6: Each User node is connected to at most one `OU` node with an edge type `CONTAINS`**
#
# Description: Each User node should be connected to at most one OU node with an edge type `CONTAINS` to represent the user's organizational unit.
#
# Cypher query: `MATCH (u:User) WITH u, COUNT((u)-[:CONTAINS]->(:OU)) AS count WHERE count > 1 RETURN u.neo4jImportId, count`
#
# **Rule 7: Each User node has a `enabled` property with a value of `True` or `False`**
#
# Description: Each User node should have an `enabled` property with a value of `True` or `False` to indicate whether the user account is enabled or not.
#
# Cypher query: `MATCH (u:User) WHERE NOT EXISTS(u.enabled) OR u.enabled NOT IN [True, False] RETURN u.neo4jImportId`
#
# These consistency rules can help ensure that the graph data is accurate and follows the expected schema. By running these Cypher queries, you can identify any violations of these rules and take corrective action to ensure data consistency.
# Based on the provided data, I've identified some patterns and inferred consistency rules related to node `User`. Here are the rules I've found, along with their corresponding Cypher queries to check for violations:
#
# **Rule 1:** Each `User` node has a unique `neo4jImportId` property.
#
# **Cypher query:** `MATCH (u:User) WITH u.neo4jImportId AS id, COUNT(*) AS count WHERE count > 1 RETURN id`
#
# **Rule 2:** Each `User` node has a `displayname`, `domain`, `name`, and `objectid` property.
#
# **Cypher query:** `MATCH (u:User) WHERE NOT EXISTS(u.displayname) OR NOT EXISTS(u.domain) OR NOT EXISTS(u.name) OR NOT EXISTS(u.objectid) RETURN u`
#
# **Rule 3:** Each `User` node has a `pwdlastset` property, which is either a positive integer or -1.
#
# **Cypher query:** `MATCH (u:User) WHERE NOT (u.pwdlastset IS INTEGER AND u.pwdlastset >= -1) RETURN u`
#
# **Rule 4:** Each `User` node has a `lastlogon` property, which is either a positive integer or -1.
#
# **Cypher query:** `MATCH (u:User) WHERE NOT (u.lastlogon IS INTEGER AND u.lastlogon >= -1) RETURN u`
#
# **Rule 5:** Each `User` node is connected to at least one `Group` node with an `MEMBER_OF` edge.
#
# **Cypher query:** `MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->(:Group)) RETURN u`
#
# **Rule 6:** Each `User` node is connected to at most one `OU` node with a `CONTAINS` edge.
#
# **Cypher query:** `MATCH (u:User) WHERE SIZE((u)-[:CONTAINS]->(:OU)) > 1 RETURN u`
#
# **Rule 7:** Each `User` node is connected to at least one `Computer` node with a `HAS_SESSION` or `ALLOWED_TO_DELEGATE` edge.
#
# **Cypher query:** `MATCH (u:User) WHERE NOT EXISTS((u)-[:HAS_SESSION|ALLOWED_TO_DELEGATE]->(:Computer)) RETURN u`
#
# **Rule 8:** Each `User` node has an `enabled` property with a boolean value.
#
# **Cypher query:** `MATCH (u:User) WHERE NOT (u.enabled IS BOOLEAN) RETURN u`
#
# These rules and queries can help ensure the consistency of the graph data and detect potential errors or inconsistencies in the `User` nodes and their relationships.
# After analyzing the provided data, I identified the following patterns and consistency rules related to node `User`:
#
# **Rule 1: Each User node has a unique `neo4jImportId` property.**
#
# Consistency Rule: Each User node should have a unique `neo4jImportId` property.
#
# Cypher Query:
# ```
# MATCH (u:User) WITH u.neo4jImportId AS id, COUNT(*) AS count
# WHERE count > 1
# RETURN id, count
# ```
# This query checks if there are any duplicate `neo4jImportId` values among User nodes.
#
# **Rule 2: Each User node has a `displayname` property.**
#
# Consistency Rule: Each User node should have a `displayname` property.
#
# Cypher Query:
# ```
# MATCH (u:User) WHERE NOT EXISTS(u.displayname)
# RETURN u
# ```
# This query checks if there are any User nodes without a `displayname` property.
#
# **Rule 3: Each User node has a `domain` property with a specific value (TestCompany.Local).**
#
# Consistency Rule: Each User node should have a `domain` property with the value "TestCompany.Local".
#
# Cypher Query:
# ```
# MATCH (u:User) WHERE u.domain <> "TestCompany.Local"
# RETURN u
# ```
# This query checks if there are any User nodes with a `domain` property value different from "TestCompany.Local".
#
# **Rule 4: Each User node has a `name` property that matches the format `displayName@domain`.**
#
# Consistency Rule: Each User node should have a `name` property that matches the format `displayName@domain`.
#
# Cypher Query:
# ```
# MATCH (u:User) WHERE NOT u.name STARTS WITH u.displayname + "@" + u.domain
# RETURN u
# ```
# This query checks if there are any User nodes with a `name` property that does not match the format `displayName@domain`.
#
# **Rule 5: Each User node is connected to at least one Group node with an edge type MEMBER_OF.**
#
# Consistency Rule: Each User node should be connected to at least one Group node with an edge type MEMBER_OF.
#
# Cypher Query:
# ```
# MATCH (u:User) WHERE NOT EXISTS((u)-[:MEMBER_OF]->())
# RETURN u
# ```
# This query checks if there are any User nodes that are not connected to at least one Group node with an edge type MEMBER_OF.
#
# **Rule 6: Each User node is connected to at most one OU node with an edge type CONTAINS.**
#
# Consistency Rule: Each User node should be connected to at most one OU node with an edge type CONTAINS.
#
# Cypher Query:
# ```
# MATCH (u:User) WITH u, COUNT((u)-[:CONTAINS]->()) AS count
# WHERE count > 1
# RETURN u, count
# ```
# This query checks if there are any User nodes connected to more than one OU node with an edge type CONTAINS.
#
# These consistency rules can help ensure the accuracy and coherence of the graph data related to User nodes.
# After analyzing the data, I've identified several consistency rules related to the node `User`. For each rule, I've provided a clear description and the corresponding Cypher query to check for violations.
#
# **Rule 1: Each User node has a `neo4jImportId` property**
#
# Description: Every `User` node should have a unique `neo4jImportId` property.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT exists(u.neo4jImportId) RETURN u
# ```
# **Rule 2: Each User node has a `domain` property**
#
# Description: Every `User` node should have a `domain` property.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT exists(u.domain) RETURN u
# ```
# **Rule 3: Each User node has an `enabled` property**
#
# Description: Every `User` node should have an `enabled` property.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT exists(u.enabled) RETURN u
# ```
# **Rule 4: Each User node is connected to at least one Group node with a MEMBER_OF edge**
#
# Description: Every `User` node should be connected to at least one `Group` node with a `MEMBER_OF` edge.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT (u)-[:MEMBER_OF]->() RETURN u
# ```
# **Rule 5: Each User node is connected to exactly one OU node with a CONTAINS edge**
#
# Description: Every `User` node should be connected to exactly one `OU` node with a `CONTAINS` edge.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE size((u)-[:CONTAINS]->()) != 1 RETURN u
# ```
# **Rule 6: Each User node has a `displayname` property**
#
# Description: Every `User` node should have a `displayname` property.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT exists(u.displayname) RETURN u
# ```
# **Rule 7: Each User node has a `name` property**
#
# Description: Every `User` node should have a `name` property.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT exists(u.name) RETURN u
# ```
# **Rule 8: Each User node has an `objectid` property**
#
# Description: Every `User` node should have an `objectid` property.
#
# Cypher query:
# ```
# MATCH (u:User) WHERE NOT exists(u.objectid) RETURN u
# ```
# These consistency rules aim to ensure that the graph data is accurate and coherent, and that every `User` node has the expected properties and connections. Running these Cypher queries can help identify any inconsistencies or errors in the data.

# %%
rule_prompt = ""
list_rules = [rules_user, rules_computer, rules_ou, rules_group, rules_gpo, rules_domain]
for rules in list_rules: 
    for rule in rules: 
        rule_prompt += " " + rule

# %%
def generator_clean(encoded_graph, query, model, size):
    # Function to divide the text into smaller chunks
    def chunk_text(text, max_length):
        words = text.split()
        chunks = []
        current_chunk = []
        current_length = 0

        for word in words:
            if current_length + len(word) + 1 > max_length:
                chunks.append(' '.join(current_chunk))
                current_chunk = []
                current_length = 0
            current_chunk.append(word)
            current_length += len(word) + 1

        if current_chunk:
            chunks.append(' '.join(current_chunk))

        return chunks

    # Function to process each chunk
    def process_chunk(chunk):
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": chunk,
                }
            ],
            model= model,
        )

        return chat_completion.choices[0].message.content

    # Split encoded_graph into chunks
    max_chunk_length = size  # Adjust this length based on your needs and model limits
    graph_chunks = chunk_text(encoded_graph, max_chunk_length)

    # Process each chunk of encoded_graph
    processed_graph_parts = [process_chunk(chunk) for chunk in graph_chunks]

    # Combine processed parts back into a single string
    processed_graph = ' '.join(processed_graph_parts)

    # Append query to the processed graph and process the final combined context
    context = processed_graph + "\n" + query
    final_result = process_chunk(context)

    return final_result

# %%
query = "Combine and clean these rules"

# %%
result_1 = generator_clean(rule_prompt[:100000], query, "llama3-70b-8192", 8129)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 result_1 = generator_clean(rule_prompt[:100000], query, "llama3-70b-8192", 8129)
#
# Cell In[53], line 48, in generator_clean(encoded_graph, query, model, size)
#      46 # Append query to the processed graph and process the final combined context
#      47 context = processed_graph + "\n" + query
# ---> 48 final_result = process_chunk(context)
#      50 return final_result
#
# Cell In[53], line 24, in generator_clean.<locals>.process_chunk(chunk)
#      23 def process_chunk(chunk):
# ---> 24     chat_completion = client.chat.completions.create(
#      25         messages=[
#      26             {
#      27                 "role": "user",
#      28                 "content": chunk,
#      29             }
#      30         ],
#      31         model= model,
#      32     )
#      34     return chat_completion.choices[0].message.content
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/resources/chat/completions.py:283, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     145 def create(
#     146     self,
#     147     *,
#    (...)
#     173     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     174 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     175     """
#     176     Creates a model response for the given chat conversation.
#     177
#    (...)
#     281       timeout: Override the client-level default timeout for this request, in seconds
#     282     """
# --> 283     return self._post(
#     284         "/openai/v1/chat/completions",
#     285         body=maybe_transform(
#     286             {
#     287                 "messages": messages,
#     288                 "model": model,
#     289                 "frequency_penalty": frequency_penalty,
#     290                 "function_call": function_call,
#     291                 "functions": functions,
#     292                 "logit_bias": logit_bias,
#     293                 "logprobs": logprobs,
#     294                 "max_tokens": max_tokens,
#     295                 "n": n,
#     296                 "presence_penalty": presence_penalty,
#     297                 "response_format": response_format,
#     298                 "seed": seed,
#     299                 "stop": stop,
#     300                 "stream": stream,
#     301                 "temperature": temperature,
#     302                 "tool_choice": tool_choice,
#     303                 "tools": tools,
#     304                 "top_logprobs": top_logprobs,
#     305                 "top_p": top_p,
#     306                 "user": user,
#     307             },
#     308             completion_create_params.CompletionCreateParams,
#     309         ),
#     310         options=make_request_options(
#     311             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     312         ),
#     313         cast_to=ChatCompletion,
#     314         stream=stream or False,
#     315         stream_cls=Stream[ChatCompletionChunk],
#     316     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01hyvd04xpe3vtmpx59tbpw3cf` on tokens per minute (TPM): Limit 6000, Used 6104, Requested 8161. Please try again in 1m22.654s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
result_2 = generator_clean(rule_prompt[100000:200000], query, "llama3-70b-8192", 8129)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 result_2 = generator_clean(rule_prompt[100000:200000], query, "llama3-70b-8192", 8129)
#
# Cell In[53], line 48, in generator_clean(encoded_graph, query, model, size)
#      46 # Append query to the processed graph and process the final combined context
#      47 context = processed_graph + "\n" + query
# ---> 48 final_result = process_chunk(context)
#      50 return final_result
#
# Cell In[53], line 24, in generator_clean.<locals>.process_chunk(chunk)
#      23 def process_chunk(chunk):
# ---> 24     chat_completion = client.chat.completions.create(
#      25         messages=[
#      26             {
#      27                 "role": "user",
#      28                 "content": chunk,
#      29             }
#      30         ],
#      31         model= model,
#      32     )
#      34     return chat_completion.choices[0].message.content
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/resources/chat/completions.py:283, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     145 def create(
#     146     self,
#     147     *,
#    (...)
#     173     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     174 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     175     """
#     176     Creates a model response for the given chat conversation.
#     177
#    (...)
#     281       timeout: Override the client-level default timeout for this request, in seconds
#     282     """
# --> 283     return self._post(
#     284         "/openai/v1/chat/completions",
#     285         body=maybe_transform(
#     286             {
#     287                 "messages": messages,
#     288                 "model": model,
#     289                 "frequency_penalty": frequency_penalty,
#     290                 "function_call": function_call,
#     291                 "functions": functions,
#     292                 "logit_bias": logit_bias,
#     293                 "logprobs": logprobs,
#     294                 "max_tokens": max_tokens,
#     295                 "n": n,
#     296                 "presence_penalty": presence_penalty,
#     297                 "response_format": response_format,
#     298                 "seed": seed,
#     299                 "stop": stop,
#     300                 "stream": stream,
#     301                 "temperature": temperature,
#     302                 "tool_choice": tool_choice,
#     303                 "tools": tools,
#     304                 "top_logprobs": top_logprobs,
#     305                 "top_p": top_p,
#     306                 "user": user,
#     307             },
#     308             completion_create_params.CompletionCreateParams,
#     309         ),
#     310         options=make_request_options(
#     311             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     312         ),
#     313         cast_to=ChatCompletion,
#     314         stream=stream or False,
#     315         stream_cls=Stream[ChatCompletionChunk],
#     316     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/groq/_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01hyvd04xpe3vtmpx59tbpw3cf` on tokens per minute (TPM): Limit 6000, Used 6202, Requested 6672. Please try again in 1m8.749s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
result_3 = generator_clean(rule_prompt[200000:], query, "llama3-70b-8192", 8129)

# %%
rs_llama = result_1 + "\n" + result_1 + "\n" + result_1
rs_llama_cleaned = generator_clean(rs_llama, query, "llama3-70b-8192", 8129)
